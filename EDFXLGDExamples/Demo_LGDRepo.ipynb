# %% [markdown]
# -----
# # ATTENTION: Before you continue UNDERSTAND:
# ### Moodys Analytics DOES NOT support this code. This code is for assistance and demonstration purposes only.
# ### Licensed Clients should reference https://hub.moodysanalytics.com/products
# ###  and the functional endpoint examples when formatting their exact questions to Moodys support staff.
# ------
#
#
# # Project LGD
#
# #### There is an immediate need to incorporate LGD interoperability between Legacy RiskCalc and EDF-X software systems. In addition, the use of the EDF-X API will allow us to abstract the need for any use of Legacy RiskCalc with respect to unconditional LGD's for our more sophisticated users. Furthermore, when EDFX-API provides LGD calculations for annualized term structures we will also be allowed to bring  our banking clients to the EDFX Platform and EDF-X API full stock.
#
# ## Project Goals:
#
# 1) Leverage EDF-X Portfolio Outputs, the EDFX API, and provide the optionality for users to use LGD Parameters in a manner to recreate the legacy RiskCalc.csv Batch upload file.
# 2) For EDFX-API Only users, provide a seamless workflow for users to receive LGD and LGD Qualitative Overlay outputs.
# 3) Provide Users scripts for high compute tasks/large data pulls.
#
#
# ## Main Use Cases:
#
# ### CASE 1:
#
# #### This case is an edge case.  The assumptions are that a user requires the Unconditional LGD RiskCalc.csv Input file, but the EDFX API is broken.  Everything therefore must be derived from assumptions that the user/solution specialist makes.  This assumes that the user was able to, at the very least, create a portfolio within EDFX using relevant Identifiers (BVDID's for example) and can download the EDFX.CSV file from the EDFX Software.
#
# ### CASE 2:
#
# #### User who would like to use multiple EDFX API endpoints to construct a legacyRiskCalc Unconditional LGD.csv input file.  We provide the ability for the Unconditional LGD RiskCalc.csv Input file to be constructed where the user can either provide a pandas dataframe object of the EDFX.CSV download that they would get from creating a portfolio within the EDFX Software OR the user can pass a vector of  entitiy ID's.  This notebook will go through how this data parsing will be done through both approaches.
#
# ### Case 3:
#
# #### This is the preferred case and most streamlined solution for an EDF-X Only LGD and LGD Scorecard solution via the EDF-X API.  To be clear, within this case, a user prefers to only use the EDFX-API.  The user must be comfortable with applying the Cumulative Term Structures within the EDFX API's LGD calculatons from the Moodys Analytics LossCalc Model.
#
#  ---
#  # ATTENTION ON Asyncio & Aiohttp Python Libraries
#  - ### Users should have at least 300 Mbps internet speed and must turn off settings that would block outgoing calls as this will process the payload extremely fast.
#  - ### Users may also need to Disable AT&T AntiVirus Plus settings when running the client side Asyncio approach.
#
# -----
#
# Please Read LossGivenDefault_ProjectSpecifications.pdf file found on the GitRepo for clarity if you're an internal Solution Specialist or user.
#
# # Project Scope
#
# Our project is complete in the sense that we have accounted for multiple situations between both EDFX and RiskCalc platforms and have attempted to address various edge cases in the event that the EDF-X API is broken or when certain Parts of the API are unresponsive (like Asynchronous requests at the endpoint level).  Requirements will be that a user MUST have their relevant BVDID's within the EDFX Software OR they must possess the relevant entity identifiers.
#
# #### This notebook provides documentation with examples for the use of the LGD Class.  We elected an object oriented approach where LGD class is also inheriting the EDFEndpoints class found within EDFXPrime.py file on the open source repo.  We have taken the liberty to provide robust functionality for users working between EDFX and RiskClac as well as for those users who wish to only use EDFX (case 3).
#
# #### For the users who work with both EDFX and RiskCalc the convenience the LGD class provides is tremendous.  Users now have the ability to use simply a BVDID Identifier (Case 2) or the .csv output file from the EDFX Software (Case 1 OR Case 2) and we can generate the Batch RiskCalc.csv input file with default parameters or user selected parameters within 3 lines of code for entities with existing term structures.   In additon, core LGD class functionality includes the following:
#
# - #### High Compute ability both within Server Side and Client Side approaches.
#     Specifically, if the endpoint within the EDFX-API has an async option (asyncResponse = True), we provide this functionality.  Withing the LGD Class this is provided on the Server Side for PDs Enpoint.
#
#     Regarding Client side requests, in the event that the server side requests are causing difficulties, we have written co-routines within LGD and EDFXEnpoints Classes at the mapping, pds, and LGD endpoints to increase the speed of large data requests.  We demonstrate to users the Compute challenges within this notebook.
#
#     An example of the compute constraint Testing is as follows:  We called pd term structures for 2594 entities from December 2017 to December 2022 with a synchronous run-time (client side basic you could say) of just under 4 hours.  Our Co-routines decreased this speed down to anywhere between 5 and 15 mintues.
#
# - #### Error Handling and Logging
#     Specifically, if there is a case where the BVDid is not returning mapping information or the pd term structure cannot be generated the error is logged and the row is removed allowing for the contruction of the Batch RiskCalc.csv file with no errors.  This also allows us to create the LGD Term-structure with accurate payloads for Case 3
#
# - #### Loan Scoring Flexibility
#     We allow the users to build and adjust specific loan requirements in accordance to their partiuclar loan portfolio.  LossCalc Modles LGD risk at the loan level and as such, the flexibility that we provide users to adjust their specific loan information is easy to do and will help in outputting their most accurate LGD estimates relative to other data vendors.
#
# ## Case 3 Specific
#
# - #### LGD Scorecard Overlay on LGD.
#     We allow Qualitative overlay functionality for users to who wish to apply this feature within EDFX-Only Case 3 applications.
#
# - #### Batch LGD and High Compute Client Side Functionality
#     Users with large LGD requests (10,000 - 20000 rows) will be able to pull large data request through built in co-routines that live within EDFXEnpoints and EDFXLGD classes from the EDFX API Mapping, PD, and LGD enpoints.
# ---------------

# %% [markdown]
# ### Helper functions
# These are to show the helper functions created as Methods within EDFXEnpoints and EDFXLGD classes.
#
# - format_PDpayload ==> EDFXPrime.py
#
# - split_list ==> EDFXPrime.py  (A helpful Generator for iterations)
#
# - SynchronousBatchMVP ==> EDFXPrime.py (A useful Batching function for the pds' endpoint both for co-routines and for regular endpoints)
#
# - BatchingBatchSearch ==> EDFXPrime. (A useful Batching Function for the mappings endpoint function for co-routines.)
#
# - All Industry Mappers ==> LGD.py
#
# - map_description_vectorized ==> LGD.py
#
# - EDFXBatchEntitySearch_async ==> EDFXPrime.py  (A useful Batching Function for the mappings endpoint function for co-routines.)
#
# #### CoRoutines for PDs, Mapping, and LGD endpoints
#
# - _post_async ==> EDFXPrime.py (pds)
# - _post_batch ==> EDFXPrime.py (pds)
# - _post_async ==> EDFXPrime.py (mapping)
# - _post_batch ==> EDFXPrime.py (mapping)
#
# BatchingBatchSearch_async ==> EDFXPrime.py
#
# - _post_async ==> EDFXLGD.py
# - _post_batch ==> EDFXLGD.py

# %%
path = r"YourPath"
# Add parent dir to path so we can import from it
import sys
sys.path.append(f'{path}')
import os
import asyncio
import time
import pandas as pd
import numpy as np
import moodys_keys as mk
import matplotlib.pyplot as plt
from datetime import datetime
import seaborn as sns
import urllib.parse as urllib_parse

from loguru import logger
from EDFXAuthentication import EDFXClient
from EDFXLGD import LGD, loan_scorecard
from EDFXPrime import EDFXEndpoints,OutputFormat,FinancialTemplate


EDFXPortfolioOutput = r"C:\PathYouHave\BryanNewBulkdDemo.csv"
bvdIDColumns= r"C:\PathYouHave\EDFXLGDExamples\demo_bvdid.csv"

credentials = mk.EDF_X()
# print(os.path.exists(EDFXPortfolioPathCase1))
#instantiate endpoints class
endpoints = EDFXEndpoints(credentials['Client'], credentials['Client_Secret'])

# %%
#Mac OR linux Only: You can't use this in Windows OS.
# import uvloop
# asyncio.set_event_loop_policy(uvloop.EventLoopPolicy())

# %% [markdown]
# ___
# # CASE 1:
#
# #### This case is an edge case.  The assumptions are that a user requires the Unconditional LGD RiskCalc.csv Input file, but the EDFX API is broken.
# #### This implies that the DataFrame is the only option that is available and that passing a vector of entities is not feasible. Case 1 DOES NOT allow for the passing of an entitis ID Vector
#
# Everything therefore must be derived from assumptions that the user/solution specialist makes.
#
#  Of course, this assumes that the user was able to, at the very least, create a portfolio within EDFX using relevant Identifiers (BVDID's for example) and can download the EDFX.CSV file from the EDFX Software.  The below examples will be shown:
#
#     i) Low Compute Parse
#     ii) High Compute Parse
#
# ### Case 1| Low Compute | Full Dataframe fed

# %%
# This would be the test case 1 situation in low compute
df = pd.read_csv(EDFXPortfolioOutput)
df_lowcompute = df.iloc[0:8]
# -----------------------------------CASE 1 in practice is performed as below--------------------------------------------
# UNDERSTAND: YOU HAVE TO DO NDY in CASE 1.
LGDclassInstantiation = LGD(api_publickey=credentials['Client'],api_privatekey= credentials['Client_Secret'], case=1,df=df_lowcompute,
                            IndustryClassification = "NDY")
# THIS IS case one IN PRACTICE: here you CAN use InputDateMonth and InputDateYear CASE 1 ONLY Otherwise PD Term asOFdate mapes to the InputdateMonth and InputDateYear in RiskCalc software
LGDCase1Ex1dictionary = LGDclassInstantiation.RiskCalcLoanSpecification(DebtSeniority= "JuniorSubordinateBond",CapitalStructure= "HasDebtAbove" ,Case1InputDateMonth="12", Case1InputDateYear="2020",
                                                              RecoveryForecastType="PostDefaultPrice",Bankruptcy = 'Yes', Bailout= 'No')
LGDCase1Ex1dictionary['cleaned_df'].head()
# Out:
# 2024-02-27 09:15:37.642 | INFO     | EDFXLGD:__init__:162 - ATTENTION: To provide your Loan Specific Inputs you MUST USE RiskCalcLoanSpecification method to output the values in the RiskCalc.csv file.
# 2024-02-27 09:15:37.654 | INFO     | EDFXLGD:PDTermStructureCheck:412 - No NaN values found in the specified columns.
#                                   Company Name Private/Public  \
# Reference ID
# US186798081L              Bayport Credit Union        Private
# BG201230426                             Borica        Private
# INFEB23404                       YES BANK LTD.         Public
# DEFEB26649              Verifone Payments GmbH        Private
# HR23057039320  Erste & Steiermarkische Bank dd        Private
#
#               Risk Determinant Type   PID  User PD 1 User PD 2 User PD 3  \
# Reference ID
# US186798081L                     PD  None     2.1896       NaN       NaN
# BG201230426                      PD  None     0.1862       NaN       NaN
# INFEB23404                       PD  None     0.3613       NaN       NaN
# DEFEB26649                       PD  None     1.3238       NaN       NaN
# HR23057039320                    PD  None     0.0658       NaN       NaN
#
#               User PD 4 User PD 5 Assets  ... Location Type Location Code  \
# Reference ID                              ...
# US186798081L        NaN       NaN   None  ...           ISO           USA
# BG201230426         NaN       NaN   None  ...           ISO           BGR
# INFEB23404          NaN       NaN   None  ...           ISO           IND
# DEFEB26649          NaN       NaN   None  ...           ISO           DEU
# HR23057039320       NaN       NaN   None  ...           ISO           HRV
#
#               Industry Classification Industry Code       Debt / Seniority  \
# Reference ID
# US186798081L                      NDY           N06  JuniorSubordinateBond
# BG201230426                       NDY           N62  JuniorSubordinateBond
# INFEB23404                        NDY           N06  JuniorSubordinateBond
# DEFEB26649                        NDY           N32  JuniorSubordinateBond
# HR23057039320                     NDY           N06  JuniorSubordinateBond
#
#               Capital Structure Bankruptcy Bailout Recovery Forecast Type  \
# Reference ID
# US186798081L       HasDebtAbove        Yes      No       PostDefaultPrice
# BG201230426        HasDebtAbove        Yes      No       PostDefaultPrice
# INFEB23404         HasDebtAbove        Yes      No       PostDefaultPrice
# DEFEB26649         HasDebtAbove        Yes      No       PostDefaultPrice
# HR23057039320      HasDebtAbove        Yes      No       PostDefaultPrice
#
#               index
# Reference ID
# US186798081L    0.0
# BG201230426     1.0
# INFEB23404      2.0
# DEFEB26649      3.0
# HR23057039320   4.0
#
# [5 rows x 23 columns]

# %%
# All 8 bvdid's work.
LGDCase1Ex1dictionary['BVDIDErrors']
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### CASE 1: RealWorld Application | Flexibility with Loan Information| High Compute

# %%
EDFXdf_highcompute = pd.read_csv(EDFXPortfolioOutput)
print(f"The shape of the df: {EDFXdf_highcompute.shape}")
# -----------------------------------CASE 1 in practice is performed as below--------------------------------------------
# lets show a bit more practical example of case 1: YOU HAVE TO DO NDY in CASE 1.
LGDclassInstantiation = LGD(api_publickey=credentials['Client'],api_privatekey= credentials['Client_Secret'], case=1,df=EDFXdf_highcompute,
                            IndustryClassification = "NDY")
# THIS IS case one IN PRACTICE: here you CAN use InputDateMonth and InputDateYear CASE 1 ONLY Otherwise PD Term asOFdate mapes to the InputdateMonth and InputDateYear in RiskCalc software
LGDCase1Ex1dictionary = LGDclassInstantiation.RiskCalcLoanSpecification(DebtSeniority= "JuniorSubordinateBond",CapitalStructure= "HasDebtAbove" ,Case1InputDateMonth="12", Case1InputDateYear="2020",
                                                              RecoveryForecastType="PostDefaultPrice",Bankruptcy = 'Yes', Bailout= 'No')
LGDCase1Ex1dictionary['cleaned_df'].head()
# Out:
# 2024-02-27 09:15:46.716 | INFO     | EDFXLGD:__init__:162 - ATTENTION: To provide your Loan Specific Inputs you MUST USE RiskCalcLoanSpecification method to output the values in the RiskCalc.csv file.
# 2024-02-27 09:15:46.729 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 114 with Reference ID KV810485145. Removing this row.
# 2024-02-27 09:15:46.731 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 129 with Reference ID GB06337638. Removing this row.
# 2024-02-27 09:15:46.732 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 136 with Reference ID US660573723. Removing this row.
# 2024-02-27 09:15:46.733 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 277 with Reference ID HK0014036219. Removing this row.
# 2024-02-27 09:15:46.734 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 477 with Reference ID AO100020094. Removing this row.
# 2024-02-27 09:15:46.737 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 521 with Reference ID US341111088. Removing this row.
# 2024-02-27 09:15:46.739 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 539 with Reference ID US391094963L. Removing this row.
# 2024-02-27 09:15:46.740 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 618 with Reference ID US390066965L. Removing this row.
# 2024-02-27 09:15:46.742 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 658 with Reference ID US349492547L. Removing this row.
# 2024-02-27 09:15:46.743 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 664 with Reference ID US310738296. Removing this row.
# 2024-02-27 09:15:46.744 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 693 with Reference ID CA133460243L. Removing this row.
# 2024-02-27 09:15:46.744 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 790 with Reference ID LY0000031769. Removing this row.
# 2024-02-27 09:15:46.745 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 857 with Reference ID US132870657L. Removing this row.
# 2024-02-27 09:15:46.745 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 959 with Reference ID AO100010483. Removing this row.
# 2024-02-27 09:15:46.746 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 1113 with Reference ID MUFEB25806. Removing this row.
# 2024-02-27 09:15:46.747 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 1261 with Reference ID KV810485864. Removing this row.
# 2024-02-27 09:15:46.748 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 1322 with Reference ID FR841033970. Removing this row.
# 2024-02-27 09:15:46.749 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 1497 with Reference ID UA00039002. Removing this row.
# 2024-02-27 09:15:46.750 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 1608 with Reference ID HK0026649831. Removing this row.
# 2024-02-27 09:15:46.751 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 1614 with Reference ID LY0000029572. Removing this row.
# The shape of the df: (1635, 19)
#                                   Company Name Private/Public  \
# Reference ID
# US186798081L              Bayport Credit Union        Private
# BG201230426                             Borica        Private
# INFEB23404                       YES BANK LTD.         Public
# DEFEB26649              Verifone Payments GmbH        Private
# HR23057039320  Erste & Steiermarkische Bank dd        Private
#
#               Risk Determinant Type   PID  User PD 1 User PD 2 User PD 3  \
# Reference ID
# US186798081L                     PD  None     2.1896       NaN       NaN
# BG201230426                      PD  None     0.1862       NaN       NaN
# INFEB23404                       PD  None     0.3613       NaN       NaN
# DEFEB26649                       PD  None     1.3238       NaN       NaN
# HR23057039320                    PD  None     0.0658       NaN       NaN
#
#               User PD 4 User PD 5 Assets  ... Location Type Location Code  \
# Reference ID                              ...
# US186798081L        NaN       NaN   None  ...           ISO           USA
# BG201230426         NaN       NaN   None  ...           ISO           BGR
# INFEB23404          NaN       NaN   None  ...           ISO           IND
# DEFEB26649          NaN       NaN   None  ...           ISO           DEU
# HR23057039320       NaN       NaN   None  ...           ISO           HRV
#
#               Industry Classification Industry Code       Debt / Seniority  \
# Reference ID
# US186798081L                      NDY           N06  JuniorSubordinateBond
# BG201230426                       NDY           N62  JuniorSubordinateBond
# INFEB23404                        NDY           N06  JuniorSubordinateBond
# DEFEB26649                        NDY           N32  JuniorSubordinateBond
# HR23057039320                     NDY           N06  JuniorSubordinateBond
#
#               Capital Structure Bankruptcy Bailout Recovery Forecast Type  \
# Reference ID
# US186798081L       HasDebtAbove        Yes      No       PostDefaultPrice
# BG201230426        HasDebtAbove        Yes      No       PostDefaultPrice
# INFEB23404         HasDebtAbove        Yes      No       PostDefaultPrice
# DEFEB26649         HasDebtAbove        Yes      No       PostDefaultPrice
# HR23057039320      HasDebtAbove        Yes      No       PostDefaultPrice
#
#               index
# Reference ID
# US186798081L    0.0
# BG201230426     1.0
# INFEB23404      2.0
# DEFEB26649      3.0
# HR23057039320   4.0
#
# [5 rows x 23 columns]

# %%
#missing values list
LGDCase1Ex1dictionary['BVDIDErrors']
# Out:
#      BVDIDs Erroring
# 114      KV810485145
# 129       GB06337638
# 136      US660573723
# 277     HK0014036219
# 477      AO100020094
# 521      US341111088
# 539     US391094963L
# 618     US390066965L
# 658     US349492547L
# 664      US310738296
# 693     CA133460243L
# 790     LY0000031769
# 857     US132870657L
# 959      AO100010483
# 1113      MUFEB25806
# 1261     KV810485864
# 1322     FR841033970
# 1497      UA00039002
# 1608    HK0026649831
# 1614    LY0000029572

# %%
print(LGDCase1Ex1dictionary['cleaned_df'].shape)
# Out:
# (1615, 23)

# %% [markdown]
# -------
#
# # CASE 2:
#
# ### Case 2 | Low Compute | Client Side
#
# Withing the LGD Clase Frame
#
#
#
# #### User who would like to use multiple EDFX API endpoints to construct a legacyRiskCalc Unconditional LGD.csv input file.  We provide the ability for the Unconditional LGD RiskCalc.csv Input file to be constructed where the user can do either of the following:
#
# #### 1) Provide a pandas dataframe object of the EDFX.CSV download that they would get from creating a portfolio within the EDFX Software
#
# #### 2) The user can pass a vector of entitiy ID's.
#
# This notebook will go through how this data parsing will be done through both approaches AND how the payloads will be formatted to be correctly fed through the class.

# %% [markdown]
# ### CASE 2 | Entity Payload | Low Compute Example
#
# Continuing with Case 2, we show how to use the EDFXLGD Class to format and entity payload from a vector of entity IDs and then we feed into the EDFXLGD Class to output the Legacy RiskCalc.csv File.
#
# We have two options to clean a vector to get a relvant payload.
# 1) Since the LGD Class uses inheritance from EDFXEnpionts, we can use the LGD instantiated class above to access the format_PDpayload method
# 2) We can instantiate a new EDFXEnpoints class object and use this directly.
#
# We show both approaches for clarity.

# %%
# Step 1 lets just get a low compute example.
EDFXdf_highcompute = pd.read_csv(bvdIDColumns)
EDFXdf_lowcompute = EDFXdf_highcompute.iloc[:20]
print(EDFXdf_lowcompute[['BvD ID']])

# we can  just instantiate a new endpoints class object to format the above 
endpoints = EDFXEndpoints(credentials['Client'], credentials['Client_Secret'])
entityPayload = endpoints.format_PDpayload(EDFXdf_lowcompute['BvD ID'])
entityPayload
# Out:
#           BvD ID
# 0   US312829931L
# 1   USLEI1829438
# 2   CA311699759L
# 3   US371433329L
# 4   US371871671L
# 5   US365194457L
# 6   US129492230L
# 7     GB03127814
# 8   US369301934L
# 9   US372202361L
# 10     CA30926NC
# 11  US382854914L
# 12  CA150316071L
# 13    GB03208093
# 14   US420234980
# 15    GBRS007741
# 16   US133668640
# 17   US133668640
# 18   US113412575
# 19  US134659519L
# [{'entityId': 'US312829931L'},
#  {'entityId': 'USLEI1829438'},
#  {'entityId': 'CA311699759L'},
#  {'entityId': 'US371433329L'},
#  {'entityId': 'US371871671L'},
#  {'entityId': 'US365194457L'},
#  {'entityId': 'US129492230L'},
#  {'entityId': 'GB03127814'},
#  {'entityId': 'US369301934L'},
#  {'entityId': 'US372202361L'},
#  {'entityId': 'CA30926NC'},
#  {'entityId': 'US382854914L'},
#  {'entityId': 'CA150316071L'},
#  {'entityId': 'GB03208093'},
#  {'entityId': 'US420234980'},
#  {'entityId': 'GBRS007741'},
#  {'entityId': 'US133668640'},
#  {'entityId': 'US133668640'},
#  {'entityId': 'US113412575'},
#  {'entityId': 'US134659519L'}]

# %%
#We can also Instantiate the LGD Class
LGDinstantiation = LGD(api_publickey=credentials['Client'],api_privatekey= credentials['Client_Secret'], case=2,df=EDFXdf_lowcompute,IndustryClassification = "NDY")
# Use the LGD class already instantiated to formate the payload
entityPayload = LGDinstantiation.format_PDpayload(EDFXdf_lowcompute['BvD ID'])
entityPayload
# Out:
# 2024-02-27 09:16:05.975 | INFO     | EDFXLGD:__init__:162 - ATTENTION: To provide your Loan Specific Inputs you MUST USE RiskCalcLoanSpecification method to output the values in the RiskCalc.csv file.
# [{'entityId': 'US312829931L'},
#  {'entityId': 'USLEI1829438'},
#  {'entityId': 'CA311699759L'},
#  {'entityId': 'US371433329L'},
#  {'entityId': 'US371871671L'},
#  {'entityId': 'US365194457L'},
#  {'entityId': 'US129492230L'},
#  {'entityId': 'GB03127814'},
#  {'entityId': 'US369301934L'},
#  {'entityId': 'US372202361L'},
#  {'entityId': 'CA30926NC'},
#  {'entityId': 'US382854914L'},
#  {'entityId': 'CA150316071L'},
#  {'entityId': 'GB03208093'},
#  {'entityId': 'US420234980'},
#  {'entityId': 'GBRS007741'},
#  {'entityId': 'US133668640'},
#  {'entityId': 'US133668640'},
#  {'entityId': 'US113412575'},
#  {'entityId': 'US134659519L'}]

# %% [markdown]
# ### CASE 2: RealWorld Application | Flexibility with Loan Information| Low Compute
#
# #### Important with Parameters:
#
# #### InputDateMonth and InputDateYear are set via the pd term structure. DO NOT FEED THEM in LGDLoanspecific Method for case 2 or case 3. They should only be used for case 1 applications.
#
# This is what most users would do in a situation where they need the legacy RiskCalc.csv LGD Input File and they have the entity IDs after they format the payload as described above.

# %%
start_time = datetime.now()

LGDinstantiation = LGD(api_publickey=credentials['Client'],api_privatekey= credentials['Client_Secret'], entities= entityPayload)

# RiskCalcLoanSpecification is the method used to put your loan information on the Legacy RiskCalc model.
Cleandf = LGDinstantiation.RiskCalcLoanSpecification(DebtSeniority= "SecuredTermLoan",CapitalStructure= "HasDebtAbove" ,RecoveryForecastType="PostDefaultPrice",
                                                     Bankruptcy = 'Yes', Bailout= 'No')
# the start date and the end date will be the InputDate Month and InputDate Year within the LGD RiskCalc.csv upload File.
case2Dictionary= LGDinstantiation.LGDClientSideEDFXPDTermStructures(CleanedDF=Cleandf, RiskCalcEndDate= "2024-01-01", RiskCalchistoryFrequency= 'annual')
case2df = case2Dictionary['cleaned_df']
end_time = datetime.now()
print('Duration:', end_time - start_time)
case2df.head()
# Out:
# 2024-02-27 09:16:12.398 | INFO     | EDFXLGD:__init__:162 - ATTENTION: To provide your Loan Specific Inputs you MUST USE RiskCalcLoanSpecification method to output the values in the RiskCalc.csv file.
# 2024-02-27 09:16:13.380 | INFO     | EDFXAuthentication:get_bearer_token:63 - Security token has been generated.
# C:\Users\martyb\OneDrive - moodys.com\Documents\Development\EDF_X_Development\EDFXAPI_OOP\EDFXLGD.py:562: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   EDFXDFSearchEndpoint["Private/Public"] = EDFXDFSearchEndpoint['isPublic'].apply(lambda x: 'Public' if x else 'Private')
# 2024-02-27 09:16:36.772 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 10 with Reference ID CA30926NC. Removing this row.
# 2024-02-27 09:16:36.775 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 11 with Reference ID US382854914L. Removing this row.
# Duration: 0:00:24.380444
#    Reference ID                                      Company Name  \
# 0  US312829931L                  Northfield Mountain Holdings LLC
# 1  USLEI1829438  TCW Direct Lending Structured Solutions 2019 LLC
# 2  CA311699759L                     Northern Courier Pipeline LTD
# 3  US371433329L                      NET Health Acquisition Corp.
# 4  US371871671L                                 Mcpf Holdings LLC
#
#   Private/Public Risk Determinant Type   PID  User PD 1  User PD 2  User PD 3  \
# 0        Private                    PD  None     1.2428     1.3233     1.3727
# 1        Private                    PD  None     1.4898     1.4844     1.4812
# 2        Private                    PD  None     9.2973     7.1860     6.1731
# 3        Private                    PD  None     2.8045     2.5562     2.4212
# 4        Private                    PD  None     3.0323     2.7416     2.5845
#
#    User PD 4  User PD 5  ... Input Date Year Location Type  Location Code  \
# 0     1.4089     1.4377  ...          2024.0           ISO            USA
# 1     1.4790     1.4773  ...          2024.0           ISO            USA
# 2     5.5395     5.0920  ...          2024.0           ISO            CAN
# 3     2.3297     2.2610  ...          2024.0           ISO            USA
# 4     2.4785     2.3992  ...          2024.0           ISO            USA
#
#    Industry Classification Industry Code Debt / Seniority Capital Structure  \
# 0                      NDY           N59  SecuredTermLoan      HasDebtAbove
# 1                      NDY           N57  SecuredTermLoan      HasDebtAbove
# 2                      NDY           N09  SecuredTermLoan      HasDebtAbove
# 3                      NDY           N57  SecuredTermLoan      HasDebtAbove
# 4                      NDY           N09  SecuredTermLoan      HasDebtAbove
#
#   Bankruptcy Bailout Recovery Forecast Type
# 0        Yes      No       PostDefaultPrice
# 1        Yes      No       PostDefaultPrice
# 2        Yes      No       PostDefaultPrice
# 3        Yes      No       PostDefaultPrice
# 4        Yes      No       PostDefaultPrice
#
# [5 rows x 23 columns]

# %% [markdown]
# ### What about the BVDID'S that didn't work?

# %%
case2Dictionary['BVDIDErrors']
# Out:
#    BVDIDs Erroring
# 10       CA30926NC
# 11    US382854914L

# %% [markdown]
# ### CASE 2: High Compute | Client Side Approach | Flexible Loan Scenario | Entity Payload
#
# Here we demonstrate the Speed of a Client side approach that employs co-routines within processing EDFX-API's Mapping and PD's endpoints to output the Legacy RiskCalc.CSV input File.

# %%
#Importing a simple VECTOR of bvdid's
EDFXdf_highcompute = pd.read_csv(bvdIDColumns).drop_duplicates()
largePayload = endpoints.format_PDpayload(EDFXdf_highcompute['BvD ID'])
# High Compute Case
start_time = datetime.now()
LGDinstantiation = LGD(api_publickey=credentials['Client'],api_privatekey= credentials['Client_Secret'], entities= largePayload, TTCPD=False)
Cleandf = LGDinstantiation.RiskCalcLoanSpecification(DebtSeniority= "SecuredTermLoan",CapitalStructure= "HasDebtAbove",
                                                    RecoveryForecastType="UltimateRecovery",Bankruptcy = 'Yes', Bailout= 'No')
#store dictionary and bvdid's that are not valid
datadictionary2 = LGDinstantiation.LGDClientSideEDFXPDTermStructures(CleanedDF=Cleandf, RiskCalcStartDate= "2017-12-01", RiskCalcEndDate= "2022-12-01",
                                                                     RiskCalchistoryFrequency = 'annual', semaphore=600)

#STORE data
BVDIDSBAD = datadictionary2['BVDIDErrors']
case2df = datadictionary2['cleaned_df']

end_time = datetime.now()
print('Duration:', end_time - start_time)
# Out:
# 2024-02-27 09:16:54.052 | INFO     | EDFXLGD:__init__:162 - ATTENTION: To provide your Loan Specific Inputs you MUST USE RiskCalcLoanSpecification method to output the values in the RiskCalc.csv file.
# 2024-02-27 09:16:54.052 | INFO     | EDFXLGD:EDFXCSVClean:552 - Co-routines to be employed at mapping endpoint
# 2024-02-27 09:16:54.878 | INFO     | EDFXAuthentication:get_bearer_token:63 - Security token has been generated.
# C:\Users\martyb\OneDrive - moodys.com\Documents\Development\EDF_X_Development\EDFXAPI_OOP\EDFXLGD.py:562: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   EDFXDFSearchEndpoint["Private/Public"] = EDFXDFSearchEndpoint['isPublic'].apply(lambda x: 'Public' if x else 'Private')
# 2024-02-27 09:17:02.947 | INFO     | EDFXLGD:LGDClientSideEDFXPDTermStructures:835 - Co-routines to be employed at PDs endpoint.
# 2024-02-27 09:17:34.835 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': '2017-12-01', 'endDate': '2022-12-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'VN0100686174-110'}, {'entityId': 'GB06928422'}]}
# 2024-02-27 09:17:34.838 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': '2017-12-01', 'endDate': '2022-12-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'US371137676L'}, {'entityId': 'US311309339L'}]}
# 2024-02-27 09:17:34.841 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': '2017-12-01', 'endDate': '2022-12-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'US560132040'}, {'entityId': 'US350885381'}]}
# 2024-02-27 09:17:34.845 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': '2017-12-01', 'endDate': '2022-12-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'CYESCBMFI8482'}, {'entityId': 'ZM120170006643'}]}
# 2024-02-27 09:17:34.846 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': '2017-12-01', 'endDate': '2022-12-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'FRFEB10708'}, {'entityId': 'US160426523'}]}
# 2024-02-27 09:17:34.846 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': '2017-12-01', 'endDate': '2022-12-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'US129470331L'}, {'entityId': 'GB12705414'}]}
# 2024-02-27 09:17:34.846 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': '2017-12-01', 'endDate': '2022-12-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'IN30405FI'}, {'entityId': 'US250659306'}]}
# 2024-02-27 09:17:34.846 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': '2017-12-01', 'endDate': '2022-12-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'SE5020077862'}, {'entityId': 'GB07143703'}]}
# 2024-02-27 09:17:34.846 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': '2017-12-01', 'endDate': '2022-12-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'AR33-53718600-9'}, {'entityId': 'BG175325806'}]}
# 2024-02-27 09:17:34.865 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': '2017-12-01', 'endDate': '2022-12-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'IT02224410023'}, {'entityId': 'PL000013037'}]}
# 2024-02-27 09:17:34.868 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': '2017-12-01', 'endDate': '2022-12-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'US231928421'}, {'entityId': 'MTC2833'}]}
# 2024-02-27 09:17:34.871 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': '2017-12-01', 'endDate': '2022-12-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'BR10640964000158'}, {'entityId': 'US870239728'}]}
# 2024-02-27 09:17:34.875 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': '2017-12-01', 'endDate': '2022-12-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'INFEB31483'}, {'entityId': 'DOFEB40658'}]}
# 2024-02-27 09:17:34.880 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': '2017-12-01', 'endDate': '2022-12-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'IT02437530823'}, {'entityId': 'BY40158OB'}]}
# 2024-02-27 09:17:34.884 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': '2017-12-01', 'endDate': '2022-12-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'KWFEB30937'}, {'entityId': 'BG130598160'}]}
# 2024-02-27 09:17:34.887 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': '2017-12-01', 'endDate': '2022-12-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'PY80013884-8'}, {'entityId': 'PA714633RPP'}]}
# 2024-02-27 09:17:34.890 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': '2017-12-01', 'endDate': '2022-12-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'CAFEB33407'}, {'entityId': 'US130056290L'}]}
# 2024-02-27 09:17:34.892 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': '2017-12-01', 'endDate': '2022-12-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'HK0024252008'}, {'entityId': 'SG201422465R'}]}
# 2024-02-27 09:17:34.894 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': '2017-12-01', 'endDate': '2022-12-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'KR1101110346901'}, {'entityId': 'US560706163'}]}
# 2024-02-27 09:17:34.895 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': '2017-12-01', 'endDate': '2022-12-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'US010024610'}, {'entityId': 'ATFEB28950'}]}
# 2024-02-27 09:17:34.897 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': '2017-12-01', 'endDate': '2022-12-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'US731332918'}, {'entityId': 'US610156616'}]}
# 2024-02-27 09:17:34.899 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': '2017-12-01', 'endDate': '2022-12-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'US221032860'}, {'entityId': 'US720452899'}]}
# 2024-02-27 09:17:34.902 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': '2017-12-01', 'endDate': '2022-12-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'US990073437'}, {'entityId': 'UY214702410015'}]}
# 2024-02-27 09:17:34.902 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': '2017-12-01', 'endDate': '2022-12-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'BR43788065000156'}, {'entityId': 'FI27898877'}]}
# 2024-02-27 09:17:34.902 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': '2017-12-01', 'endDate': '2022-12-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'HR*110182985625'}, {'entityId': 'AE0000422883'}]}
# 2024-02-27 09:17:34.902 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': '2017-12-01', 'endDate': '2022-12-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'US810669576'}, {'entityId': 'JP5010001008813'}]}
# 2024-02-27 09:17:34.902 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': '2017-12-01', 'endDate': '2022-12-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'NZ9429040797410'}, {'entityId': 'TGFEB21798'}]}
# 2024-02-27 09:17:34.902 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': '2017-12-01', 'endDate': '2022-12-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'US751745500'}, {'entityId': 'BO00013168'}]}
# 2024-02-27 09:17:34.902 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': '2017-12-01', 'endDate': '2022-12-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'US149096660L'}, {'entityId': 'US405370685L'}]}
# 2024-02-27 09:17:34.914 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': '2017-12-01', 'endDate': '2022-12-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'US470803224'}, {'entityId': 'BR27098060000145'}]}
# 2024-02-27 09:17:34.921 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': '2017-12-01', 'endDate': '2022-12-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'INFEB42270'}, {'entityId': 'USFEB62679'}]}
# 2024-02-27 09:17:36.747 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': '2017-12-01', 'endDate': '2022-12-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'USFR708164'}, {'entityId': 'US592979916'}]}
# 2024-02-27 09:17:36.747 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': '2017-12-01', 'endDate': '2022-12-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'US123796165L'}, {'entityId': 'AEFEB31277'}]}
# 2024-02-27 09:17:36.762 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': '2017-12-01', 'endDate': '2022-12-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'BR16581207000137'}, {'entityId': 'LYFEB52134'}]}
# 2024-02-27 09:17:36.763 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': '2017-12-01', 'endDate': '2022-12-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'ATFEB44715'}, {'entityId': 'IS5006830589'}]}
# 2024-02-27 09:17:36.763 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': '2017-12-01', 'endDate': '2022-12-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'TW97172648'}, {'entityId': 'BDFEB43446'}]}
# 2024-02-27 09:17:36.763 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': '2017-12-01', 'endDate': '2022-12-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'BDFEB46385'}, {'entityId': 'US341300434'}]}
# 2024-02-27 09:17:36.763 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': '2017-12-01', 'endDate': '2022-12-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'BR01852137000137'}, {'entityId': 'US135266470'}]}
# 2024-02-27 09:17:36.763 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': '2017-12-01', 'endDate': '2022-12-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'PHCS200413056'}, {'entityId': 'US111814791'}]}
# 2024-02-27 09:17:36.775 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': '2017-12-01', 'endDate': '2022-12-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'US128824290L'}, {'entityId': 'US061798488'}]}
# 2024-02-27 09:17:36.777 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': '2017-12-01', 'endDate': '2022-12-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'RU17538910'}, {'entityId': 'GI108217'}]}
# 2024-02-27 09:17:36.778 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': '2017-12-01', 'endDate': '2022-12-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'IT09722490969'}, {'entityId': 'TRFEB35795'}]}
# 2024-02-27 09:17:36.779 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': '2017-12-01', 'endDate': '2022-12-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'USLEI446699'}, {'entityId': 'US130510992L'}]}
# 2024-02-27 09:17:36.780 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': '2017-12-01', 'endDate': '2022-12-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'AU615852376'}, {'entityId': 'US184357587L'}]}
# 2024-02-27 09:17:36.782 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': '2017-12-01', 'endDate': '2022-12-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'US232041671L'}, {'entityId': 'US193243344L'}]}
# 2024-02-27 09:17:36.783 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': '2017-12-01', 'endDate': '2022-12-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'US369980219L'}, {'entityId': 'US951243678'}]}
# 2024-02-27 09:17:36.784 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': '2017-12-01', 'endDate': '2022-12-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'TZFEB15676'}, {'entityId': 'GI113151'}]}
# 2024-02-27 09:17:36.785 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': '2017-12-01', 'endDate': '2022-12-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'NL33006580'}, {'entityId': 'US183043731L'}]}
# 2024-02-27 09:17:36.785 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': '2017-12-01', 'endDate': '2022-12-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'US431302908'}, {'entityId': 'BG831558413'}]}
# 2024-02-27 09:17:36.785 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': '2017-12-01', 'endDate': '2022-12-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'NG94524R'}, {'entityId': 'US391990426'}]}
# 2024-02-27 09:17:36.785 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': '2017-12-01', 'endDate': '2022-12-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'US042314232'}, {'entityId': 'US520684204'}]}
# 2024-02-27 09:17:36.785 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': '2017-12-01', 'endDate': '2022-12-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'AR33-99924210-9'}, {'entityId': 'GB07297722'}]}
# 2024-02-27 09:17:36.785 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': '2017-12-01', 'endDate': '2022-12-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'GT380344237342'}, {'entityId': 'MRFEB51949'}]}
# 2024-02-27 09:17:36.785 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': '2017-12-01', 'endDate': '2022-12-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'LBFEB31125'}, {'entityId': 'US710415188'}]}
# 2024-02-27 09:17:36.785 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': '2017-12-01', 'endDate': '2022-12-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'PHCS201806696'}, {'entityId': 'BR03323840000183'}]}
# 2024-02-27 09:17:36.785 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': '2017-12-01', 'endDate': '2022-12-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'US381495887L'}, {'entityId': 'US390066965L'}]}
# 2024-02-27 09:17:36.795 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': '2017-12-01', 'endDate': '2022-12-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'CMM129600008006J'}, {'entityId': 'ESFR3032600'}]}
# 2024-02-27 09:17:36.796 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': '2017-12-01', 'endDate': '2022-12-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'GB01026167'}, {'entityId': 'US910462347'}]}
# 2024-02-27 09:17:36.797 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': '2017-12-01', 'endDate': '2022-12-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'GB09356276'}, {'entityId': 'US410517445'}]}
# 2024-02-27 09:17:36.798 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': '2017-12-01', 'endDate': '2022-12-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'KWFEB30298'}, {'entityId': 'US350885388'}]}
# 2024-02-27 09:17:36.799 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': '2017-12-01', 'endDate': '2022-12-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'LYFEB18885'}, {'entityId': 'GB05941947'}]}
# 2024-02-27 09:17:36.800 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': '2017-12-01', 'endDate': '2022-12-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'USFR219343'}, {'entityId': 'BE0434197536'}]}
# 2024-02-27 09:17:36.802 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': '2017-12-01', 'endDate': '2022-12-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'TRFEB36863'}, {'entityId': 'CAFEB33410'}]}
# 2024-02-27 09:17:36.803 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': '2017-12-01', 'endDate': '2022-12-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'US116014903'}, {'entityId': 'US952023588'}]}
# 2024-02-27 09:17:36.804 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': '2017-12-01', 'endDate': '2022-12-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'GB08037323'}, {'entityId': 'KR1101115505354'}]}
# 2024-02-27 09:17:36.805 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': '2017-12-01', 'endDate': '2022-12-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'CVFEB29131'}, {'entityId': 'CN*L000001226112'}]}
# 2024-02-27 09:17:36.806 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': '2017-12-01', 'endDate': '2022-12-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'HNFEB43087'}, {'entityId': 'PHCS201710492'}]}
# 2024-02-27 09:17:36.807 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': '2017-12-01', 'endDate': '2022-12-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'HK0021968321'}, {'entityId': 'KIFEB47762'}]}
# 2024-02-27 09:17:36.808 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': '2017-12-01', 'endDate': '2022-12-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'TH*BBB00142'}, {'entityId': 'BR30306294000145'}]}
# 2024-02-27 09:17:36.809 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': '2017-12-01', 'endDate': '2022-12-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'AFFEB27114'}, {'entityId': 'INFEB31489'}]}
# 2024-02-27 09:17:36.811 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': '2017-12-01', 'endDate': '2022-12-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'US590153930'}, {'entityId': 'US042188463'}]}
# 2024-02-27 09:17:36.812 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': '2017-12-01', 'endDate': '2022-12-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'LK0000123639'}, {'entityId': 'IE638771'}]}
# 2024-02-27 09:17:36.814 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': '2017-12-01', 'endDate': '2022-12-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'LV000355106'}, {'entityId': 'SG201524528H'}]}
# 2024-02-27 09:17:36.815 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': '2017-12-01', 'endDate': '2022-12-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'US381250516'}, {'entityId': 'USFR2047504'}]}
# 2024-02-27 09:17:36.816 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': '2017-12-01', 'endDate': '2022-12-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'US941347393'}, {'entityId': 'CAFEB54199'}]}
# 2024-02-27 09:17:36.818 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': '2017-12-01', 'endDate': '2022-12-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'US946069237'}, {'entityId': 'CNFEB38203'}]}
# 2024-02-27 09:17:43.247 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': '2017-12-01', 'endDate': '2022-12-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'IN0004790549'}, {'entityId': 'LT304686884'}]}
# 2024-02-27 09:17:43.249 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': '2017-12-01', 'endDate': '2022-12-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'USFR33754'}, {'entityId': 'LY0000031769'}]}
# 2024-02-27 09:17:43.251 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': '2017-12-01', 'endDate': '2022-12-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'RS07654812'}, {'entityId': 'ZA196500670606'}]}
# 2024-02-27 09:17:43.251 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': '2017-12-01', 'endDate': '2022-12-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'CL769657371'}, {'entityId': 'MXBII000814L34'}]}
# 2024-02-27 09:17:43.251 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': '2017-12-01', 'endDate': '2022-12-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'PG1-10989'}, {'entityId': 'LV000304323'}]}
# 2024-02-27 09:17:43.251 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': '2017-12-01', 'endDate': '2022-12-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'US279712214L'}, {'entityId': 'US480409930'}]}
# 2024-02-27 09:17:43.256 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': '2017-12-01', 'endDate': '2022-12-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'EC0190155722001'}, {'entityId': 'KNFEB93625'}]}
# 2024-02-27 09:17:43.258 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': '2017-12-01', 'endDate': '2022-12-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'US352537672'}, {'entityId': 'US630260951'}]}
# 2024-02-27 09:17:43.258 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': '2017-12-01', 'endDate': '2022-12-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'US311490955'}, {'entityId': 'US640202970'}]}
# 2024-02-27 09:17:43.258 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': '2017-12-01', 'endDate': '2022-12-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'NZ9429041687628'}, {'entityId': 'MXBPS121217FS6'}]}
# 2024-02-27 09:17:43.258 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': '2017-12-01', 'endDate': '2022-12-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'TRFEB46367'}, {'entityId': 'SK00151653'}]}
# 2024-02-27 09:17:43.263 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': '2017-12-01', 'endDate': '2022-12-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'AU103575042'}, {'entityId': 'TH0105544095999'}]}
# 2024-02-27 09:17:43.265 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': '2017-12-01', 'endDate': '2022-12-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'US430616804'}, {'entityId': 'US610523393'}]}
# ...
# 2024-02-27 09:18:54.220 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 1582 with Reference ID DEFEB13093. Removing this row.
# 2024-02-27 09:18:54.220 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 1598 with Reference ID DEFEB14028. Removing this row.
# 2024-02-27 09:18:54.220 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 1604 with Reference ID DEFEB14781. Removing this row.
# 2024-02-27 09:18:54.220 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 1790 with Reference ID EC1790368718001. Removing this row.
# 2024-02-27 09:18:54.220 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 1883 with Reference ID EGFEB47093. Removing this row.
# 2024-02-27 09:18:54.220 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 1884 with Reference ID EGFEB47093. Removing this row.
# 2024-02-27 09:18:54.228 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 1885 with Reference ID EGFEB47093. Removing this row.
# 2024-02-27 09:18:54.229 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 1950 with Reference ID ESA86507092. Removing this row.
# 2024-02-27 09:18:54.230 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 2378 with Reference ID GB06029941. Removing this row.
# 2024-02-27 09:18:54.232 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 2406 with Reference ID GB07095500. Removing this row.
# 2024-02-27 09:18:54.233 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 2407 with Reference ID GB07095500. Removing this row.
# 2024-02-27 09:18:54.234 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 2408 with Reference ID GB07095500. Removing this row.
# 2024-02-27 09:18:54.234 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 2414 with Reference ID GB07143703. Removing this row.
# 2024-02-27 09:18:54.234 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 2431 with Reference ID GB07400104. Removing this row.
# 2024-02-27 09:18:54.234 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 2570 with Reference ID GB10485907. Removing this row.
# 2024-02-27 09:18:54.234 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 2610 with Reference ID GBFC008874. Removing this row.
# 2024-02-27 09:18:54.234 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 2611 with Reference ID GBFC008874. Removing this row.
# 2024-02-27 09:18:54.234 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 2612 with Reference ID GBFC008874. Removing this row.
# 2024-02-27 09:18:54.234 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 2613 with Reference ID GBFC008874. Removing this row.
# 2024-02-27 09:18:54.244 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 2614 with Reference ID GBFC008874. Removing this row.
# 2024-02-27 09:18:54.245 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 2615 with Reference ID GBFC008874. Removing this row.
# 2024-02-27 09:18:54.246 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 2616 with Reference ID GBFC022861. Removing this row.
# 2024-02-27 09:18:54.247 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 2617 with Reference ID GBFC022861. Removing this row.
# 2024-02-27 09:18:54.247 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 2618 with Reference ID GBFC022861. Removing this row.
# 2024-02-27 09:18:54.248 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 2619 with Reference ID GBFC023527. Removing this row.
# 2024-02-27 09:18:54.250 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 2620 with Reference ID GBFC023527. Removing this row.
# 2024-02-27 09:18:54.250 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 2621 with Reference ID GBFC023527. Removing this row.
# 2024-02-27 09:18:54.252 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 2703 with Reference ID GHFEB36970. Removing this row.
# 2024-02-27 09:18:54.253 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 2704 with Reference ID GHFEB43837. Removing this row.
# 2024-02-27 09:18:54.253 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 2752 with Reference ID GR999984630-B0001. Removing this row.
# 2024-02-27 09:18:54.254 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 2896 with Reference ID HR97326283154. Removing this row.
# 2024-02-27 09:18:54.255 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 3077 with Reference ID IL51-447-9211. Removing this row.
# 2024-02-27 09:18:54.256 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 3201 with Reference ID INFEB42651. Removing this row.
# 2024-02-27 09:18:54.258 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 3252 with Reference ID IS6601071180. Removing this row.
# 2024-02-27 09:18:54.259 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 3372 with Reference ID JM91090L. Removing this row.
# 2024-02-27 09:18:54.261 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 3489 with Reference ID JP3120001077312. Removing this row.
# 2024-02-27 09:18:54.262 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 3490 with Reference ID JP3120001077312. Removing this row.
# 2024-02-27 09:18:54.263 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 3491 with Reference ID JP3120001077312. Removing this row.
# 2024-02-27 09:18:54.264 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 3492 with Reference ID JP3120001077312. Removing this row.
# 2024-02-27 09:18:54.265 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 3550 with Reference ID JP6010401061386. Removing this row.
# 2024-02-27 09:18:54.267 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 3775 with Reference ID KV810485145. Removing this row.
# 2024-02-27 09:18:54.271 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 3776 with Reference ID KV810485864. Removing this row.
# 2024-02-27 09:18:54.273 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 3824 with Reference ID KZ930940000164. Removing this row.
# 2024-02-27 09:18:54.278 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 3839 with Reference ID KZ950740000130. Removing this row.
# 2024-02-27 09:18:54.280 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 3864 with Reference ID KZFEB19013. Removing this row.
# 2024-02-27 09:18:54.280 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 4001 with Reference ID LT112029270. Removing this row.
# 2024-02-27 09:18:54.282 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 4050 with Reference ID LULB30764B1254100. Removing this row.
# 2024-02-27 09:18:54.282 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 4255 with Reference ID MK4065549. Removing this row.
# 2024-02-27 09:18:54.284 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 4289 with Reference ID MK5538041. Removing this row.
# 2024-02-27 09:18:54.286 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 4344 with Reference ID MTC2833. Removing this row.
# 2024-02-27 09:18:54.286 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 4375 with Reference ID MU0000063321. Removing this row.
# 2024-02-27 09:18:54.288 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 4376 with Reference ID MUFEB10256. Removing this row.
# 2024-02-27 09:18:54.289 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 4384 with Reference ID MUFEB25806. Removing this row.
# 2024-02-27 09:18:54.290 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 4415 with Reference ID MXBAF060524EV6. Removing this row.
# 2024-02-27 09:18:54.313 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 4416 with Reference ID MXBAF060524EV6. Removing this row.
# 2024-02-27 09:18:54.333 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 4417 with Reference ID MXBAF060524EV6. Removing this row.
# 2024-02-27 09:18:54.340 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 4526 with Reference ID MXFEB44940. Removing this row.
# 2024-02-27 09:18:54.342 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 4671 with Reference ID NG1259460R. Removing this row.
# 2024-02-27 09:18:54.343 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 4778 with Reference ID NL30076284. Removing this row.
# 2024-02-27 09:18:54.346 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 4858 with Reference ID NZ9429039073440. Removing this row.
# 2024-02-27 09:18:54.347 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 5022 with Reference ID PE20259702411. Removing this row.
# 2024-02-27 09:18:54.349 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 5060 with Reference ID PH0000024221. Removing this row.
# 2024-02-27 09:18:54.350 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 5244 with Reference ID PSFEB11431. Removing this row.
# 2024-02-27 09:18:54.352 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 5245 with Reference ID PSFEB18459. Removing this row.
# 2024-02-27 09:18:54.352 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 5246 with Reference ID PSFEB44478. Removing this row.
# 2024-02-27 09:18:54.352 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 5282 with Reference ID PT503016160. Removing this row.
# 2024-02-27 09:18:54.355 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 5339 with Reference ID QA22788. Removing this row.
# 2024-02-27 09:18:54.357 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 5371 with Reference ID RO11007551. Removing this row.
# 2024-02-27 09:18:54.358 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 5472 with Reference ID RS17356917. Removing this row.
# 2024-02-27 09:18:54.359 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 5503 with Reference ID RU09301192. Removing this row.
# 2024-02-27 09:18:54.360 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 5862 with Reference ID SI5026024. Removing this row.
# 2024-02-27 09:18:54.363 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 6021 with Reference ID TH0107536001401. Removing this row.
# 2024-02-27 09:18:54.365 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 6052 with Reference ID TN0000221M. Removing this row.
# 2024-02-27 09:18:54.366 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 6218 with Reference ID TZFEB39044. Removing this row.
# 2024-02-27 09:18:54.367 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 6245 with Reference ID UA00039002. Removing this row.
# 2024-02-27 09:18:54.369 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 6442 with Reference ID US050495490. Removing this row.
# 2024-02-27 09:18:54.369 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 6958 with Reference ID US221865454. Removing this row.
# 2024-02-27 09:18:54.371 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 6992 with Reference ID US230581420. Removing this row.
# 2024-02-27 09:18:54.372 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 7184 with Reference ID US273973786. Removing this row.
# 2024-02-27 09:18:54.373 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 7242 with Reference ID US310738296. Removing this row.
# 2024-02-27 09:18:54.375 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 7333 with Reference ID US330830202. Removing this row.
# 2024-02-27 09:18:54.376 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 7360 with Reference ID US341111088. Removing this row.
# 2024-02-27 09:18:54.377 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 7483 with Reference ID US351118182. Removing this row.
# 2024-02-27 09:18:54.378 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 7835 with Reference ID US382854914L. Removing this row.
# 2024-02-27 09:18:54.379 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 7837 with Reference ID US389265437L. Removing this row.
# 2024-02-27 09:18:54.381 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 7839 with Reference ID US390066965L. Removing this row.
# 2024-02-27 09:18:54.382 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 7869 with Reference ID US391094963L. Removing this row.
# 2024-02-27 09:18:54.382 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 8402 with Reference ID US591387466. Removing this row.
# 2024-02-27 09:18:54.384 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 8599 with Reference ID US660573723. Removing this row.
# 2024-02-27 09:18:54.385 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 9108 with Reference ID US930412056. Removing this row.
# 2024-02-27 09:18:54.387 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 9216 with Reference ID US951687284. Removing this row.
# 2024-02-27 09:18:54.388 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 9318 with Reference ID USFEB18697. Removing this row.
# 2024-02-27 09:18:54.390 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 9321 with Reference ID USFEB47530. Removing this row.
# 2024-02-27 09:18:54.392 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 9324 with Reference ID USFEB60085. Removing this row.
# 2024-02-27 09:18:54.393 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 9351 with Reference ID USFEB62868. Removing this row.
# 2024-02-27 09:18:54.394 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 9444 with Reference ID USFR150576. Removing this row.
# 2024-02-27 09:18:54.397 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 9458 with Reference ID USFR2047504. Removing this row.
# 2024-02-27 09:18:54.398 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 9473 with Reference ID USFR2575155. Removing this row.
# 2024-02-27 09:18:54.400 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 9587 with Reference ID USFR854520. Removing this row.
# 2024-02-27 09:18:54.401 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 9800 with Reference ID ZA196500670606. Removing this row.
# Duration: 0:02:00.429848

# %%
# Hurray! in this case we captured all the entities that we could.
print(case2df.shape)
case2df.head()
# Out:
# (9686, 23)
#       Reference ID                            Company Name Private/Public  \
# 0  AD*110344726656                           Vall Banc, SA        Private
# 1  AD*110344726656                           Vall Banc, SA        Private
# 2  AD*110344726656                           Vall Banc, SA        Private
# 3       ADFEB18424  Andorra Banc Agricol Reig SA - AndBank        Private
# 4       ADFEB18424  Andorra Banc Agricol Reig SA - AndBank        Private
#
#   Risk Determinant Type   PID  User PD 1  User PD 2  User PD 3  User PD 4  \
# 0                    PD  None     3.8997     3.2955     2.9857     2.7835
# 1                    PD  None     3.0536     2.7761     2.6254     2.5234
# 2                    PD  None     5.3270     4.2699     3.7496     3.4187
# 3                    PD  None     0.0168     0.0300     0.0423     0.0538
# 4                    PD  None     0.0281     0.0442     0.0577     0.0696
#
#    User PD 5  ... Input Date Year Location Type  Location Code  \
# 0     2.6360  ...          2020.0           ISO            AND
# 1     2.4470  ...          2021.0           ISO            AND
# 2     3.1819  ...          2022.0           ISO            AND
# 3     0.0649  ...          2017.0           ISO            AND
# 4     0.0805  ...          2018.0           ISO            AND
#
#    Industry Classification Industry Code Debt / Seniority Capital Structure  \
# 0                      NDY           N57  SecuredTermLoan      HasDebtAbove
# 1                      NDY           N57  SecuredTermLoan      HasDebtAbove
# 2                      NDY           N57  SecuredTermLoan      HasDebtAbove
# 3                      NDY           N31  SecuredTermLoan      HasDebtAbove
# 4                      NDY           N31  SecuredTermLoan      HasDebtAbove
#
#   Bankruptcy Bailout Recovery Forecast Type
# 0        Yes      No       UltimateRecovery
# 1        Yes      No       UltimateRecovery
# 2        Yes      No       UltimateRecovery
# 3        Yes      No       UltimateRecovery
# 4        Yes      No       UltimateRecovery
#
# [5 rows x 23 columns]

# %% [markdown]
# ## Entities that could not be pulled can be stored and investigated Below.
# - Since this is a Time Series, you would need to Check those BVDID'S at all points in time to ensure that they exist in all points of time the API called.
# - In addition, For BVDIDs within this dictionary, they were attempted to be called at least five times with the relevant Parameters and they were unable to be pulled.
# - There should be a product specific or Economic reason as to why these identifiers were not called that 'makes sense.'

# %%
# BVDIDSBAD.to_csv("bvdidPITnotcaptured.csv")
print(BVDIDSBAD.shape)
BVDIDSBAD
# Out:
# (129, 1)
#      BVDIDs Erroring
# 39       AE22664211B
# 111      AO100020094
# 436       AZFEB47325
# 459       BDFEB18501
# 460       BDFEB33521
# ...              ...
# 9444      USFR150576
# 9458     USFR2047504
# 9473     USFR2575155
# 9587      USFR854520
# 9800  ZA196500670606
#
# [129 rows x 1 columns]

# %% [markdown]
# ## There could be BVDID'S we missed with this approach that can still be called. No Problem.
#
# - 99% of the time this will not be an issue.  You will know if it is, A new .csvfile will appear in your local machine with a path name liken to the pathname in the below example.
#
# ## Moodys Open Repo has attempted to error handle for this occurance.
# For those where information is just not able to be pulled due to an Internal Service error ONLY, we store this data in your ErrorLog and also create a
# .csv file for you to retry.  Lets work through the retry call one would use.
#
# - Lets upload the failed params .csv to pandas dataframe ==> Format the payload ==> Resend and see if we can get the rest of the data.
# - Failed Params CSV with asyncio library will be BVDID's that could work.
# - BVDID's in Error however most likely has some Product Specific or Rational reason that the Software is not returning Data

# %%
failedparamspath = "YourPath/12:49:53.914839_FailedParams.csv"
faieldparams = pd.read_csv(failedparamspath)
smallPayload = endpoints.format_PDpayload(faieldparams['12:49:53.914839_FailedParams'])
# Now we just Re Run with the EXACT SAME PARAMS THE FORMATTED ENTITIES
LGDinstantiation = LGD(api_publickey=credentials['Client'],api_privatekey= credentials['Client_Secret'], entities= smallPayload, TTCPD=False)
Cleandf = LGDinstantiation.RiskCalcLoanSpecification(DebtSeniority= "SecuredTermLoan",CapitalStructure= "HasDebtAbove",
                                            RecoveryForecastType="UltimateRecovery",Bankruptcy = 'Yes', Bailout= 'No')
datadictionary2 = LGDinstantiation.LGDClientSideEDFXPDTermStructures(CleanedDF=Cleandf, RiskCalcStartDate= "2018-12-01", RiskCalcEndDate= "2023-12-01",
                                                            RiskCalchistoryFrequency = 'annual')
BVDIDSBAD_RETRY = datadictionary2['BVDIDErrors']
case2dfRETRY = datadictionary2['cleaned_df']
end_time = datetime.now()
case2dfRETRY.head()

# %%
# one that we just can't get
BVDIDSBAD_RETRY

# %% [markdown]
# ----
# # API Hub Asynch Guidance
#
# ## Best Estimate PD
# Access our best estimate PD for a given ID. It is recommended that you use this endpoint unless you are an advanced user or use an existing product.
#
# ## Using in Asynchronous Mode
# If the number of entities you are retrieving is large (>10,000), it might be easier to use the asynchronous process. Enable by setting the asyncResponse parameter to true. The response returned is a processId. You can use asynchronous mode along with processes endpoints to access the status and results after the request has been processed.
#
#
#
#
# ### CASE 2 | Sychronous Approach | Server Side
#
# ### IMPORTANT:
#
# #### Using ASynchronous Server Side approach with the EDFXLGD Class you must realize the PD term structure dates will map to your InputDate Month and InputDate Year Values in Case 2 & Case 3 for you Loan Dates of origination.
#
# #### Within LGDServerSidePDAsynchronousEDFXAPIData method we feed the loan paramaters once you get a processed processID BUT YOU DO NOT feed inputDate Month or InputDate Year because for case 2 and case 3 this information is captured within the startDate and endDate parameters of the pds endpoint.
#
# ---
#
# Since we use AWS Lambda you will have 15 minutes to have your processIds fill.  If not your response will keep running.  For a pds Endpoint and a full term strucure I have had success with batches as large as 700.
#
# In addition, within the Server side methods we feed the loan information all at once when we have a successful process returned

# %% [markdown]
# ### Run this Async Server using functions
# - Bryan TO DO

# %%
EDFXdf_highcompute = pd.read_csv(EDFXPortfolioOutput)
entityPayload = endpoints.format_PDpayload(EDFXdf_highcompute['Entity Id'])
# entityPayload is a list
batch_size = 500
batches = [entityPayload[i:i + batch_size] for i in range(0, len(entityPayload), batch_size)]
# Print the length of each batch to verify
for index, batch in enumerate(batches):
    print(f"Batch {index + 1} length: {len(batch)}")
# Out:
# Batch 1 length: 500
# Batch 2 length: 500
# Batch 3 length: 500
# Batch 4 length: 135

# %%
batch1 = batches[0] # this will be 700*5 = 3500 payloads
batch2 = batches[1]
batch3 = batches[2]
batch4 = batches[3]


# High Compute Case
start_time = datetime.now()
# This is like saying Create Loans for these entityIDs at 2017, December through 2022 December (5 for entityID if the entityID exists)
LGDinstantiation = LGD(api_publickey=credentials['Client'],api_privatekey= credentials['Client_Secret'], entities= batch1)
processid = LGDinstantiation.LGDServerSidePDAsynchronousEDFXAPIData(RiskCalcStartDate= "2017-12-01", RiskCalcEndDate= "2022-12-01",
                                                                    RiskCalchistoryFrequency= 'annual', asyncResponse=True)
end_time = datetime.now()
print('Duration:', end_time - start_time)


print(f"The processing id for this run is as follows: {processid}\n")
while True:
    if LGDinstantiation.LGDProcessing(processID=processid):
        status = LGDinstantiation.EDFXModelInputsGetStatus(processID=processid)
        print(f"Process is running and will wait 3 minutes before checking. Current status: {status['status']}")
        time.sleep(180)
    else:
        status = LGDinstantiation.EDFXModelInputsGetStatus(processID=processid)
        print(f"Process completed. Final status: {status['status']}")
        break
    
#this is a dictionary
RiskCalcServerSide1 = LGDinstantiation.LGDServerSidePDAsynchronousEDFXAPIData(processID=processid, DebtSeniority= "JuniorSubordinateBond",CapitalStructure= "HasDebtAbove",
                                                                             RecoveryForecastType="PostDefaultPrice",Bankruptcy = 'Yes', Bailout= 'No')

RiskCalcServerSide1['cleaned_df']
# Out:
# 2024-02-23 10:15:10.285 | INFO     | LGDBryan:__init__:157 - ATTENTION: To provide your Loan Specific Inputs you MUST USE RiskCalcLoanSpecification method to output the values in the RiskCalc.csv file.
# 2024-02-23 10:15:11.638 | INFO     | EDFXAuthentication:get_bearer_token:63 - Security token has been generated.
# Duration: 0:00:04.849832
# The processing id for this run is as follows: a7c5744a-b2b2-47c5-845c-8f8e89d35b40
#
# {'status': 'Requested'}
# {'status': 'Processing'}
# Process is running and will wait 3 minutes before checking. Current status: Processing
# {'status': 'Processing'}
# {'status': 'Processing'}
# Process is running and will wait 3 minutes before checking. Current status: Processing
# {'status': 'Completed'}
# {'status': 'Completed'}
# Process completed. Final status: Completed
# 2024-02-23 10:21:30.852 | INFO     | LGDBryan:EDFXCSVClean:546 - Co-routines to be employed at mapping endpoint
# C:\Users\martyb\OneDrive - moodys.com\Documents\Development\EDF_X_Development\EDFXAPI_OOP\LGDBryan.py:556: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   EDFXDFSearchEndpoint["Private/Public"] = EDFXDFSearchEndpoint['isPublic'].apply(lambda x: 'Public' if x else 'Private')
# 2024-02-23 10:21:34.974 | ERROR    | LGDBryan:PDTermStructureCheck:401 - Alert: NaN value found at index 17 with Reference ID AO100020094. Removing this row.
# 2024-02-23 10:21:34.974 | ERROR    | LGDBryan:PDTermStructureCheck:401 - Alert: NaN value found at index 121 with Reference ID BDFEB18501. Removing this row.
# 2024-02-23 10:21:34.974 | ERROR    | LGDBryan:PDTermStructureCheck:401 - Alert: NaN value found at index 122 with Reference ID BDFEB46600. Removing this row.
# 2024-02-23 10:21:34.974 | ERROR    | LGDBryan:PDTermStructureCheck:401 - Alert: NaN value found at index 123 with Reference ID BDFEB49474. Removing this row.
# 2024-02-23 10:21:34.974 | ERROR    | LGDBryan:PDTermStructureCheck:401 - Alert: NaN value found at index 124 with Reference ID BDFEB49943. Removing this row.
# 2024-02-23 10:21:34.974 | ERROR    | LGDBryan:PDTermStructureCheck:401 - Alert: NaN value found at index 139 with Reference ID BE0712624257. Removing this row.
# 2024-02-23 10:21:34.974 | ERROR    | LGDBryan:PDTermStructureCheck:401 - Alert: NaN value found at index 276 with Reference ID BR34098442000134. Removing this row.
# 2024-02-23 10:21:34.974 | ERROR    | LGDBryan:PDTermStructureCheck:401 - Alert: NaN value found at index 277 with Reference ID BR34098442000134. Removing this row.
# 2024-02-23 10:21:34.974 | ERROR    | LGDBryan:PDTermStructureCheck:401 - Alert: NaN value found at index 278 with Reference ID BR34098442000134. Removing this row.
# 2024-02-23 10:21:34.974 | ERROR    | LGDBryan:PDTermStructureCheck:401 - Alert: NaN value found at index 350 with Reference ID CAFEB21757. Removing this row.
# 2024-02-23 10:21:34.974 | ERROR    | LGDBryan:PDTermStructureCheck:401 - Alert: NaN value found at index 516 with Reference ID DEFEB14781. Removing this row.
# 2024-02-23 10:21:34.974 | ERROR    | LGDBryan:PDTermStructureCheck:401 - Alert: NaN value found at index 583 with Reference ID EC1790368718001. Removing this row.
# 2024-02-23 10:21:34.974 | ERROR    | LGDBryan:PDTermStructureCheck:401 - Alert: NaN value found at index 803 with Reference ID GBFC008874. Removing this row.
# 2024-02-23 10:21:34.974 | ERROR    | LGDBryan:PDTermStructureCheck:401 - Alert: NaN value found at index 804 with Reference ID GBFC008874. Removing this row.
# 2024-02-23 10:21:34.974 | ERROR    | LGDBryan:PDTermStructureCheck:401 - Alert: NaN value found at index 805 with Reference ID GBFC008874. Removing this row.
# 2024-02-23 10:21:34.989 | ERROR    | LGDBryan:PDTermStructureCheck:401 - Alert: NaN value found at index 806 with Reference ID GBFC008874. Removing this row.
# 2024-02-23 10:21:34.989 | ERROR    | LGDBryan:PDTermStructureCheck:401 - Alert: NaN value found at index 807 with Reference ID GBFC008874. Removing this row.
# 2024-02-23 10:21:34.989 | ERROR    | LGDBryan:PDTermStructureCheck:401 - Alert: NaN value found at index 808 with Reference ID GBFC008874. Removing this row.
# 2024-02-23 10:21:34.989 | ERROR    | LGDBryan:PDTermStructureCheck:401 - Alert: NaN value found at index 825 with Reference ID GHFEB36970. Removing this row.
# 2024-02-23 10:21:34.989 | ERROR    | LGDBryan:PDTermStructureCheck:401 - Alert: NaN value found at index 826 with Reference ID GHFEB43837. Removing this row.
# 2024-02-23 10:21:34.994 | ERROR    | LGDBryan:PDTermStructureCheck:401 - Alert: NaN value found at index 883 with Reference ID HR97326283154. Removing this row.
# 2024-02-23 10:21:34.994 | ERROR    | LGDBryan:PDTermStructureCheck:401 - Alert: NaN value found at index 975 with Reference ID INFEB42651. Removing this row.
# 2024-02-23 10:21:34.995 | ERROR    | LGDBryan:PDTermStructureCheck:401 - Alert: NaN value found at index 999 with Reference ID IS6601071180. Removing this row.
# 2024-02-23 10:21:34.996 | ERROR    | LGDBryan:PDTermStructureCheck:401 - Alert: NaN value found at index 1020 with Reference ID JM91090L. Removing this row.
# 2024-02-23 10:21:34.997 | ERROR    | LGDBryan:PDTermStructureCheck:401 - Alert: NaN value found at index 1059 with Reference ID JP3120001077312. Removing this row.
# 2024-02-23 10:21:34.998 | ERROR    | LGDBryan:PDTermStructureCheck:401 - Alert: NaN value found at index 1060 with Reference ID JP3120001077312. Removing this row.
# 2024-02-23 10:21:34.999 | ERROR    | LGDBryan:PDTermStructureCheck:401 - Alert: NaN value found at index 1061 with Reference ID JP3120001077312. Removing this row.
# 2024-02-23 10:21:34.999 | ERROR    | LGDBryan:PDTermStructureCheck:401 - Alert: NaN value found at index 1062 with Reference ID JP3120001077312. Removing this row.
# 2024-02-23 10:21:34.999 | ERROR    | LGDBryan:PDTermStructureCheck:401 - Alert: NaN value found at index 1090 with Reference ID JP6010401061386. Removing this row.
# 2024-02-23 10:21:34.999 | ERROR    | LGDBryan:PDTermStructureCheck:401 - Alert: NaN value found at index 1147 with Reference ID KV810485145. Removing this row.
# 2024-02-23 10:21:34.999 | ERROR    | LGDBryan:PDTermStructureCheck:401 - Alert: NaN value found at index 1148 with Reference ID KZ930940000164. Removing this row.
# 2024-02-23 10:21:34.999 | ERROR    | LGDBryan:PDTermStructureCheck:401 - Alert: NaN value found at index 1210 with Reference ID LULB30764B1254100. Removing this row.
# 2024-02-23 10:21:35.004 | ERROR    | LGDBryan:PDTermStructureCheck:401 - Alert: NaN value found at index 1276 with Reference ID MK4065549. Removing this row.
# 2024-02-23 10:21:35.004 | ERROR    | LGDBryan:PDTermStructureCheck:401 - Alert: NaN value found at index 1385 with Reference ID MXFEB44940. Removing this row.
# 2024-02-23 10:21:35.004 | ERROR    | LGDBryan:PDTermStructureCheck:401 - Alert: NaN value found at index 1574 with Reference ID PH0000024221. Removing this row.
# 2024-02-23 10:21:35.004 | ERROR    | LGDBryan:PDTermStructureCheck:401 - Alert: NaN value found at index 1634 with Reference ID PSFEB11431. Removing this row.
# 2024-02-23 10:21:35.004 | ERROR    | LGDBryan:PDTermStructureCheck:401 - Alert: NaN value found at index 1706 with Reference ID RU09301192. Removing this row.
# 2024-02-23 10:21:35.004 | ERROR    | LGDBryan:PDTermStructureCheck:401 - Alert: NaN value found at index 1893 with Reference ID TH0107536001401. Removing this row.
# 2024-02-23 10:21:35.004 | ERROR    | LGDBryan:PDTermStructureCheck:401 - Alert: NaN value found at index 1961 with Reference ID TZFEB39044. Removing this row.
# 2024-02-23 10:21:35.004 | ERROR    | LGDBryan:PDTermStructureCheck:401 - Alert: NaN value found at index 2108 with Reference ID US221865454. Removing this row.
# 2024-02-23 10:21:35.011 | ERROR    | LGDBryan:PDTermStructureCheck:401 - Alert: NaN value found at index 2194 with Reference ID US351118182. Removing this row.
# 2024-02-23 10:21:35.012 | ERROR    | LGDBryan:PDTermStructureCheck:401 - Alert: NaN value found at index 2454 with Reference ID US660573723. Removing this row.
# 2024-02-23 10:21:35.013 | ERROR    | LGDBryan:PDTermStructureCheck:401 - Alert: NaN value found at index 2636 with Reference ID US951687284. Removing this row.
# 2024-02-23 10:21:35.014 | ERROR    | LGDBryan:PDTermStructureCheck:401 - Alert: NaN value found at index 2730 with Reference ID USFR2047504. Removing this row.
# 2024-02-23 10:21:35.014 | ERROR    | LGDBryan:PDTermStructureCheck:401 - Alert: NaN value found at index 2733 with Reference ID USFR2575155. Removing this row.
# 2024-02-23 10:21:35.015 | ERROR    | LGDBryan:PDTermStructureCheck:401 - Alert: NaN value found at index 2773 with Reference ID USFR854520. Removing this row.
# {'cleaned_df':         Reference ID                Company Name Private/Public  \
#  0         AEFEB16394  Mawarid Finance (P J S C )        Private
#  1         AEFEB16394  Mawarid Finance (P J S C )        Private
#  2         AEFEB16394  Mawarid Finance (P J S C )        Private
#  3         AEFEB16394  Mawarid Finance (P J S C )        Private
#  4         AEFEB16394  Mawarid Finance (P J S C )        Private
#  ...              ...                         ...            ...
#  2798  ZA195100000906                 Nedbank LTD        Private
#  2799  ZA195100000906                 Nedbank LTD        Private
#  2800  ZA195100000906                 Nedbank LTD        Private
#  2801  ZA195100000906                 Nedbank LTD        Private
#  2802  ZA195100000906                 Nedbank LTD        Private
#
#       Risk Determinant Type   PID  User PD 1  User PD 2  User PD 3  User PD 4  \
#  0                       PD  None     4.2782     2.8152     2.2010     1.8476
#  1                       PD  None     1.2585     0.8853     0.7204     0.6224
#  2                       PD  None     1.1152     0.7880     0.6430     0.5565
#  3                       PD  None     1.5805     1.2135     1.0396     0.9314
#  4                       PD  None     0.1473     0.1606     0.1689     0.1750
#  ...                    ...   ...        ...        ...        ...        ...
#  2798                    PD  None     0.3334     0.3481     0.3570     0.3635
#  2799                    PD  None     1.5473     1.2067     1.0431     0.9407
#  2800                    PD  None     1.5473     1.2067     1.0431     0.9407
#  2801                    PD  None     0.4309     0.3902     0.3682     0.3533
#  2802                    PD  None     0.4302     0.3788     0.3517     0.3336
#
#        User PD 5  ... Input Date Year Location Type  Location Code  \
#  0        1.6127  ...          2017.0           ISO            ARE
#  1        0.5556  ...          2018.0           ISO            ARE
#  2        0.4975  ...          2019.0           ISO            ARE
#  3        0.8553  ...          2020.0           ISO            ARE
#  4        0.1799  ...          2021.0           ISO            ARE
#  ...         ...  ...             ...           ...            ...
#  2798     0.3685  ...          2019.0           ISO            ZAF
#  2799     0.8681  ...          2020.0           ISO            ZAF
#  2800     0.8681  ...          2020.0           ISO            ZAF
#  2801     0.3422  ...          2021.0           ISO            ZAF
#  2802     0.3202  ...          2022.0           ISO            ZAF
#
#        Industry Classification Industry Code       Debt / Seniority  \
#  0                         NDY           N06  JuniorSubordinateBond
#  1                         NDY           N06  JuniorSubordinateBond
#  2                         NDY           N06  JuniorSubordinateBond
#  3                         NDY           N06  JuniorSubordinateBond
#  4                         NDY           N06  JuniorSubordinateBond
#  ...                       ...           ...                    ...
#  2798                      NDY           N06  JuniorSubordinateBond
#  2799                      NDY           N06  JuniorSubordinateBond
#  2800                      NDY           N06  JuniorSubordinateBond
#  2801                      NDY           N06  JuniorSubordinateBond
#  2802                      NDY           N06  JuniorSubordinateBond
#
#       Capital Structure Bankruptcy Bailout Recovery Forecast Type
#  0         HasDebtAbove        Yes      No       PostDefaultPrice
#  1         HasDebtAbove        Yes      No       PostDefaultPrice
#  2         HasDebtAbove        Yes      No       PostDefaultPrice
#  3         HasDebtAbove        Yes      No       PostDefaultPrice
#  4         HasDebtAbove        Yes      No       PostDefaultPrice
#  ...                ...        ...     ...                    ...
#  2798      HasDebtAbove        Yes      No       PostDefaultPrice
#  2799      HasDebtAbove        Yes      No       PostDefaultPrice
#  2800      HasDebtAbove        Yes      No       PostDefaultPrice
#  2801      HasDebtAbove        Yes      No       PostDefaultPrice
#  2802      HasDebtAbove        Yes      No       PostDefaultPrice
#
#  [2803 rows x 23 columns],
#  'BVDIDErrors':         BVDIDs Erroring
#  17          AO100020094
#  121          BDFEB18501
#  122          BDFEB46600
#  123          BDFEB49474
#  124          BDFEB49943
#  139        BE0712624257
#  276    BR34098442000134
#  277    BR34098442000134
#  278    BR34098442000134
#  350          CAFEB21757
#  516          DEFEB14781
#  583     EC1790368718001
#  803          GBFC008874
#  804          GBFC008874
#  805          GBFC008874
#  806          GBFC008874
#  807          GBFC008874
#  808          GBFC008874
#  825          GHFEB36970
#  826          GHFEB43837
#  883       HR97326283154
#  975          INFEB42651
#  999        IS6601071180
#  1020           JM91090L
#  1059    JP3120001077312
#  1060    JP3120001077312
#  1061    JP3120001077312
#  1062    JP3120001077312
#  1090    JP6010401061386
#  1147        KV810485145
#  1148     KZ930940000164
#  1210  LULB30764B1254100
#  1276          MK4065549
#  1385         MXFEB44940
#  1574       PH0000024221
#  1634         PSFEB11431
#  1706         RU09301192
#  1893    TH0107536001401
#  1961         TZFEB39044
#  2108        US221865454
#  2194        US351118182
#  2454        US660573723
#  2636        US951687284
#  2730        USFR2047504
#  2733        USFR2575155
#  2773         USFR854520}

# %%
# -------------Batch2----------------------------
# High Compute Case
start_time = datetime.now()
# This is like saying Create Loans for these entityIDs at 2017, December through 2022 December (5 for entityID if the entityID exists)
LGDinstantiation = LGD(api_publickey=credentials['Client'],api_privatekey= credentials['Client_Secret'], entities= batch2)
processid = LGDinstantiation.LGDServerSidePDAsynchronousEDFXAPIData(RiskCalcStartDate= "2017-12-01", RiskCalcEndDate= "2022-12-01",
                                                                    RiskCalchistoryFrequency= 'annual', asyncResponse=True)
end_time = datetime.now()
print('Duration:', end_time - start_time)
### processes----

print(f"The processing id for this run is as follows: {processid}\n")
while True:
    if LGDinstantiation.LGDProcessing(processID=processid):
        status = LGDinstantiation.EDFXModelInputsGetStatus(processID=processid)
        print(f"Process is running and will wait 3 minutes before checking. Current status: {status['status']}")
        time.sleep(180)
    else:
        status = LGDinstantiation.EDFXModelInputsGetStatus(processID=processid)
        print(f"Process completed. Final status: {status['status']}")
        break

RiskCalcServerSide2 = LGDinstantiation.LGDServerSidePDAsynchronousEDFXAPIData(processID=processid, DebtSeniority= "JuniorSubordinateBond",CapitalStructure= "HasDebtAbove",
                                                                             RecoveryForecastType="PostDefaultPrice",Bankruptcy = 'Yes', Bailout= 'No')

RiskCalcServerSide2['cleaned_df']
# Out:
# 2024-02-23 10:24:03.582 | INFO     | LGDBryan:__init__:157 - ATTENTION: To provide your Loan Specific Inputs you MUST USE RiskCalcLoanSpecification method to output the values in the RiskCalc.csv file.
# 2024-02-23 10:24:04.476 | INFO     | EDFXAuthentication:get_bearer_token:63 - Security token has been generated.
# Duration: 0:00:03.944799
# The processing id for this run is as follows: 6f38fb30-5c72-49ff-951f-9a27cd71669b
#
# {'status': 'Requested'}
# {'status': 'Processing'}
# Process is running and will wait 3 minutes before checking. Current status: Processing
# {'status': 'Processing'}
# {'status': 'Processing'}
# Process is running and will wait 3 minutes before checking. Current status: Processing
# {'status': 'Completed'}
# {'status': 'Completed'}
# Process completed. Final status: Completed
# 2024-02-23 10:30:24.836 | INFO     | LGDBryan:EDFXCSVClean:546 - Co-routines to be employed at mapping endpoint
# C:\Users\martyb\OneDrive - moodys.com\Documents\Development\EDF_X_Development\EDFXAPI_OOP\LGDBryan.py:556: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   EDFXDFSearchEndpoint["Private/Public"] = EDFXDFSearchEndpoint['isPublic'].apply(lambda x: 'Public' if x else 'Private')
# 2024-02-23 10:30:28.705 | ERROR    | LGDBryan:PDTermStructureCheck:401 - Alert: NaN value found at index 14 with Reference ID AE22664211B. Removing this row.
# 2024-02-23 10:30:28.705 | ERROR    | LGDBryan:PDTermStructureCheck:401 - Alert: NaN value found at index 103 with Reference ID BDFEB33521. Removing this row.
# 2024-02-23 10:30:28.705 | ERROR    | LGDBryan:PDTermStructureCheck:401 - Alert: NaN value found at index 104 with Reference ID BDFEB37556. Removing this row.
# 2024-02-23 10:30:28.705 | ERROR    | LGDBryan:PDTermStructureCheck:401 - Alert: NaN value found at index 105 with Reference ID BDFEB46385. Removing this row.
# 2024-02-23 10:30:28.705 | ERROR    | LGDBryan:PDTermStructureCheck:401 - Alert: NaN value found at index 106 with Reference ID BDFEB46948. Removing this row.
# 2024-02-23 10:30:28.720 | ERROR    | LGDBryan:PDTermStructureCheck:401 - Alert: NaN value found at index 153 with Reference ID BG831686320. Removing this row.
# 2024-02-23 10:30:28.720 | ERROR    | LGDBryan:PDTermStructureCheck:401 - Alert: NaN value found at index 250 with Reference ID CA247295150L. Removing this row.
# 2024-02-23 10:30:28.720 | ERROR    | LGDBryan:PDTermStructureCheck:401 - Alert: NaN value found at index 280 with Reference ID CHCHE113422612. Removing this row.
# 2024-02-23 10:30:28.720 | ERROR    | LGDBryan:PDTermStructureCheck:401 - Alert: NaN value found at index 344 with Reference ID CYC72376. Removing this row.
# 2024-02-23 10:30:28.720 | ERROR    | LGDBryan:PDTermStructureCheck:401 - Alert: NaN value found at index 553 with Reference ID GB07095500. Removing this row.
# 2024-02-23 10:30:28.720 | ERROR    | LGDBryan:PDTermStructureCheck:401 - Alert: NaN value found at index 554 with Reference ID GB07095500. Removing this row.
# 2024-02-23 10:30:28.720 | ERROR    | LGDBryan:PDTermStructureCheck:401 - Alert: NaN value found at index 555 with Reference ID GB07095500. Removing this row.
# 2024-02-23 10:30:28.720 | ERROR    | LGDBryan:PDTermStructureCheck:401 - Alert: NaN value found at index 561 with Reference ID GB07143703. Removing this row.
# 2024-02-23 10:30:28.720 | ERROR    | LGDBryan:PDTermStructureCheck:401 - Alert: NaN value found at index 606 with Reference ID GBFC022861. Removing this row.
# 2024-02-23 10:30:28.720 | ERROR    | LGDBryan:PDTermStructureCheck:401 - Alert: NaN value found at index 607 with Reference ID GBFC022861. Removing this row.
# 2024-02-23 10:30:28.720 | ERROR    | LGDBryan:PDTermStructureCheck:401 - Alert: NaN value found at index 608 with Reference ID GBFC022861. Removing this row.
# 2024-02-23 10:30:28.720 | ERROR    | LGDBryan:PDTermStructureCheck:401 - Alert: NaN value found at index 609 with Reference ID GBFC023527. Removing this row.
# 2024-02-23 10:30:28.720 | ERROR    | LGDBryan:PDTermStructureCheck:401 - Alert: NaN value found at index 610 with Reference ID GBFC023527. Removing this row.
# 2024-02-23 10:30:28.731 | ERROR    | LGDBryan:PDTermStructureCheck:401 - Alert: NaN value found at index 611 with Reference ID GBFC023527. Removing this row.
# 2024-02-23 10:30:28.731 | ERROR    | LGDBryan:PDTermStructureCheck:401 - Alert: NaN value found at index 939 with Reference ID KZFEB19013. Removing this row.
# 2024-02-23 10:30:28.732 | ERROR    | LGDBryan:PDTermStructureCheck:401 - Alert: NaN value found at index 962 with Reference ID LT112029270. Removing this row.
# 2024-02-23 10:30:28.732 | ERROR    | LGDBryan:PDTermStructureCheck:401 - Alert: NaN value found at index 1038 with Reference ID MK5538041. Removing this row.
# 2024-02-23 10:30:28.733 | ERROR    | LGDBryan:PDTermStructureCheck:401 - Alert: NaN value found at index 1061 with Reference ID MTC2833. Removing this row.
# 2024-02-23 10:30:28.735 | ERROR    | LGDBryan:PDTermStructureCheck:401 - Alert: NaN value found at index 1073 with Reference ID MU0000063321. Removing this row.
# 2024-02-23 10:30:28.735 | ERROR    | LGDBryan:PDTermStructureCheck:401 - Alert: NaN value found at index 1074 with Reference ID MUFEB10256. Removing this row.
# 2024-02-23 10:30:28.737 | ERROR    | LGDBryan:PDTermStructureCheck:401 - Alert: NaN value found at index 1082 with Reference ID MXBAF060524EV6. Removing this row.
# 2024-02-23 10:30:28.738 | ERROR    | LGDBryan:PDTermStructureCheck:401 - Alert: NaN value found at index 1083 with Reference ID MXBAF060524EV6. Removing this row.
# 2024-02-23 10:30:28.739 | ERROR    | LGDBryan:PDTermStructureCheck:401 - Alert: NaN value found at index 1084 with Reference ID MXBAF060524EV6. Removing this row.
# 2024-02-23 10:30:28.740 | ERROR    | LGDBryan:PDTermStructureCheck:401 - Alert: NaN value found at index 1162 with Reference ID NG1259460R. Removing this row.
# 2024-02-23 10:30:28.741 | ERROR    | LGDBryan:PDTermStructureCheck:401 - Alert: NaN value found at index 1335 with Reference ID PT503016160. Removing this row.
# 2024-02-23 10:30:28.741 | ERROR    | LGDBryan:PDTermStructureCheck:401 - Alert: NaN value found at index 1345 with Reference ID RO11007551. Removing this row.
# 2024-02-23 10:30:28.742 | ERROR    | LGDBryan:PDTermStructureCheck:401 - Alert: NaN value found at index 1873 with Reference ID US273973786. Removing this row.
# 2024-02-23 10:30:28.743 | ERROR    | LGDBryan:PDTermStructureCheck:401 - Alert: NaN value found at index 1891 with Reference ID US310738296. Removing this row.
# 2024-02-23 10:30:28.743 | ERROR    | LGDBryan:PDTermStructureCheck:401 - Alert: NaN value found at index 1931 with Reference ID US330830202. Removing this row.
# 2024-02-23 10:30:28.744 | ERROR    | LGDBryan:PDTermStructureCheck:401 - Alert: NaN value found at index 1949 with Reference ID US341111088. Removing this row.
# 2024-02-23 10:30:28.745 | ERROR    | LGDBryan:PDTermStructureCheck:401 - Alert: NaN value found at index 2092 with Reference ID US390066965L. Removing this row.
# 2024-02-23 10:30:28.746 | ERROR    | LGDBryan:PDTermStructureCheck:401 - Alert: NaN value found at index 2109 with Reference ID US391094963L. Removing this row.
# 2024-02-23 10:30:28.747 | ERROR    | LGDBryan:PDTermStructureCheck:401 - Alert: NaN value found at index 2585 with Reference ID ZA196500670606. Removing this row.
#         Reference ID                               Company Name  \
# 0       AE0000054963                Network International L.L.C
# 1       AE0000054963                Network International L.L.C
# 2       AE0000054963                Network International L.L.C
# 3       AE0000054963                Network International L.L.C
# 4       AE0000422883                              Lari Exchange
# ...              ...                                        ...
# 2557  ZA201600382007                    Zero Research (PTY) LTD
# 2558  ZM120170006643  Zambia Industrial Commercial Bank Limited
# 2559  ZM120170006643  Zambia Industrial Commercial Bank Limited
# 2560  ZM120170006643  Zambia Industrial Commercial Bank Limited
# 2561  ZM120170006643  Zambia Industrial Commercial Bank Limited
#
#      Private/Public Risk Determinant Type   PID  User PD 1  User PD 2  \
# 0           Private                    PD  None     0.9018     1.0365
# 1           Private                    PD  None     1.1624     1.2203
# 2           Private                    PD  None     1.1605     1.2188
# 3           Private                    PD  None     1.8935     1.7220
# 4           Private                    PD  None     0.9285     1.0144
# ...             ...                   ...   ...        ...        ...
# 2557        Private                    PD  None     2.9841     2.6788
# 2558        Private                    PD  None     1.3709     1.0349
# 2559        Private                    PD  None     0.8742     0.7401
# 2560        Private                    PD  None     0.0933     0.1041
# 2561        Private                    PD  None     0.0238     0.0378
#
#       User PD 3  User PD 4  User PD 5  ... Input Date Year Location Type  \
# 0        1.1245     1.1914     1.2459  ...          2019.0           ISO
# 1        1.2554     1.2809     1.3011  ...          2020.0           ISO
# 2        1.2543     1.2801     1.3005  ...          2021.0           ISO
# 3        1.6289     1.5659     1.5187  ...          2022.0           ISO
# 4        1.0682     1.1081     1.1401  ...          2017.0           ISO
# ...         ...        ...        ...  ...             ...           ...
# 2557     2.5147     2.4043     2.3220  ...          2022.0           ISO
# 2558     0.8778     0.7810     0.7132  ...          2019.0           ISO
# 2559     0.6714     0.6265     0.5938  ...          2020.0           ISO
# 2560     0.1110     0.1162     0.1204  ...          2021.0           ISO
# 2561     0.0496     0.0600     0.0697  ...          2022.0           ISO
#
#       Location Code  Industry Classification Industry Code  \
# 0               ARE                      NDY           N18
# 1               ARE                      NDY           N18
# 2               ARE                      NDY           N18
# 3               ARE                      NDY           N18
# 4               ARE                      NDY           N31
# ...             ...                      ...           ...
# 2557            ZAF                      NDY           N16
# 2558            ZMB                      NDY           N06
# 2559            ZMB                      NDY           N06
# 2560            ZMB                      NDY           N06
# 2561            ZMB                      NDY           N06
#
#            Debt / Seniority Capital Structure Bankruptcy Bailout  \
# 0     JuniorSubordinateBond      HasDebtAbove        Yes      No
# 1     JuniorSubordinateBond      HasDebtAbove        Yes      No
# 2     JuniorSubordinateBond      HasDebtAbove        Yes      No
# 3     JuniorSubordinateBond      HasDebtAbove        Yes      No
# 4     JuniorSubordinateBond      HasDebtAbove        Yes      No
# ...                     ...               ...        ...     ...
# 2557  JuniorSubordinateBond      HasDebtAbove        Yes      No
# 2558  JuniorSubordinateBond      HasDebtAbove        Yes      No
# 2559  JuniorSubordinateBond      HasDebtAbove        Yes      No
# 2560  JuniorSubordinateBond      HasDebtAbove        Yes      No
# 2561  JuniorSubordinateBond      HasDebtAbove        Yes      No
#
#      Recovery Forecast Type
# 0          PostDefaultPrice
# 1          PostDefaultPrice
# 2          PostDefaultPrice
# 3          PostDefaultPrice
# 4          PostDefaultPrice
# ...                     ...
# 2557       PostDefaultPrice
# 2558       PostDefaultPrice
# 2559       PostDefaultPrice
# 2560       PostDefaultPrice
# 2561       PostDefaultPrice
#
# [2562 rows x 23 columns]

# %%
# -------------Batch3----------------------------
# High Compute Case
start_time = datetime.now()
# This is like saying Create Loans for these entityIDs at 2017, December through 2022 December (5 for entityID if the entityID exists)
LGDinstantiation = LGD(api_publickey=credentials['Client'],api_privatekey= credentials['Client_Secret'], entities= batch3)
processid = LGDinstantiation.LGDServerSidePDAsynchronousEDFXAPIData(RiskCalcStartDate= "2017-12-01", RiskCalcEndDate= "2022-12-01",
                                                                    RiskCalchistoryFrequency= 'annual', asyncResponse=True)
end_time = datetime.now()
print('Duration:', end_time - start_time)
### processes----

print(f"The processing id for this run is as follows: {processid}\n")
while True:
    if LGDinstantiation.LGDProcessing(processID=processid):
        status = LGDinstantiation.EDFXModelInputsGetStatus(processID=processid)
        print(f"Process is running and will wait 3 minutes before checking. Current status: {status['status']}")
        time.sleep(180)
    else:
        status = LGDinstantiation.EDFXModelInputsGetStatus(processID=processid)
        print(f"Process completed. Final status: {status['status']}")
        break

RiskCalcServerSide3 = LGDinstantiation.LGDServerSidePDAsynchronousEDFXAPIData(processID=processid, DebtSeniority= "JuniorSubordinateBond",CapitalStructure= "HasDebtAbove",
                                                                             RecoveryForecastType="PostDefaultPrice",Bankruptcy = 'Yes', Bailout= 'No')

RiskCalcServerSide3['cleaned_df']
# Out:
# 2024-02-23 10:43:52.333 | INFO     | LGDBryan:__init__:157 - ATTENTION: To provide your Loan Specific Inputs you MUST USE RiskCalcLoanSpecification method to output the values in the RiskCalc.csv file.
# 2024-02-23 10:43:53.341 | INFO     | EDFXAuthentication:get_bearer_token:63 - Security token has been generated.
# Duration: 0:00:04.240440
# The processing id for this run is as follows: e8f5b7d3-270a-4936-9998-582ee8f53fb3
#
# {'status': 'Requested'}
# {'status': 'Requested'}
# Process is running and will wait 3 minutes before checking. Current status: Requested
# {'status': 'Processing'}
# {'status': 'Processing'}
# Process is running and will wait 3 minutes before checking. Current status: Processing
# {'status': 'Completed'}
# {'status': 'Completed'}
# Process completed. Final status: Completed
# 2024-02-23 10:50:13.167 | INFO     | LGDBryan:EDFXCSVClean:546 - Co-routines to be employed at mapping endpoint
# C:\Users\martyb\OneDrive - moodys.com\Documents\Development\EDF_X_Development\EDFXAPI_OOP\LGDBryan.py:556: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   EDFXDFSearchEndpoint["Private/Public"] = EDFXDFSearchEndpoint['isPublic'].apply(lambda x: 'Public' if x else 'Private')
# 2024-02-23 10:50:17.192 | ERROR    | LGDBryan:PDTermStructureCheck:401 - Alert: NaN value found at index 142 with Reference ID AZFEB47325. Removing this row.
# 2024-02-23 10:50:17.193 | ERROR    | LGDBryan:PDTermStructureCheck:401 - Alert: NaN value found at index 149 with Reference ID BDFEB43446. Removing this row.
# 2024-02-23 10:50:17.194 | ERROR    | LGDBryan:PDTermStructureCheck:401 - Alert: NaN value found at index 150 with Reference ID BDFEB49475. Removing this row.
# 2024-02-23 10:50:17.195 | ERROR    | LGDBryan:PDTermStructureCheck:401 - Alert: NaN value found at index 175 with Reference ID BG813071350. Removing this row.
# 2024-02-23 10:50:17.197 | ERROR    | LGDBryan:PDTermStructureCheck:401 - Alert: NaN value found at index 273 with Reference ID BR71371686000175. Removing this row.
# 2024-02-23 10:50:17.197 | ERROR    | LGDBryan:PDTermStructureCheck:401 - Alert: NaN value found at index 274 with Reference ID BR71371686000175. Removing this row.
# 2024-02-23 10:50:17.197 | ERROR    | LGDBryan:PDTermStructureCheck:401 - Alert: NaN value found at index 275 with Reference ID BR71371686000175. Removing this row.
# 2024-02-23 10:50:17.200 | ERROR    | LGDBryan:PDTermStructureCheck:401 - Alert: NaN value found at index 376 with Reference ID CL970240004. Removing this row.
# 2024-02-23 10:50:17.200 | ERROR    | LGDBryan:PDTermStructureCheck:401 - Alert: NaN value found at index 508 with Reference ID DEFEB14028. Removing this row.
# 2024-02-23 10:50:17.200 | ERROR    | LGDBryan:PDTermStructureCheck:401 - Alert: NaN value found at index 568 with Reference ID EGFEB47093. Removing this row.
# 2024-02-23 10:50:17.200 | ERROR    | LGDBryan:PDTermStructureCheck:401 - Alert: NaN value found at index 569 with Reference ID EGFEB47093. Removing this row.
# 2024-02-23 10:50:17.200 | ERROR    | LGDBryan:PDTermStructureCheck:401 - Alert: NaN value found at index 570 with Reference ID EGFEB47093. Removing this row.
# 2024-02-23 10:50:17.200 | ERROR    | LGDBryan:PDTermStructureCheck:401 - Alert: NaN value found at index 599 with Reference ID ESA86507092. Removing this row.
# 2024-02-23 10:50:17.200 | ERROR    | LGDBryan:PDTermStructureCheck:401 - Alert: NaN value found at index 713 with Reference ID GB06029941. Removing this row.
# 2024-02-23 10:50:17.200 | ERROR    | LGDBryan:PDTermStructureCheck:401 - Alert: NaN value found at index 716 with Reference ID GB07400104. Removing this row.
# 2024-02-23 10:50:17.200 | ERROR    | LGDBryan:PDTermStructureCheck:401 - Alert: NaN value found at index 775 with Reference ID GB10485907. Removing this row.
# 2024-02-23 10:50:17.200 | ERROR    | LGDBryan:PDTermStructureCheck:401 - Alert: NaN value found at index 835 with Reference ID GR999984630-B0001. Removing this row.
# 2024-02-23 10:50:17.209 | ERROR    | LGDBryan:PDTermStructureCheck:401 - Alert: NaN value found at index 943 with Reference ID IL51-447-9211. Removing this row.
# 2024-02-23 10:50:17.210 | ERROR    | LGDBryan:PDTermStructureCheck:401 - Alert: NaN value found at index 1181 with Reference ID KV810485864. Removing this row.
# 2024-02-23 10:50:17.211 | ERROR    | LGDBryan:PDTermStructureCheck:401 - Alert: NaN value found at index 1393 with Reference ID MUFEB25806. Removing this row.
# 2024-02-23 10:50:17.212 | ERROR    | LGDBryan:PDTermStructureCheck:401 - Alert: NaN value found at index 1529 with Reference ID NL30076284. Removing this row.
# 2024-02-23 10:50:17.213 | ERROR    | LGDBryan:PDTermStructureCheck:401 - Alert: NaN value found at index 1575 with Reference ID PE20259702411. Removing this row.
# 2024-02-23 10:50:17.213 | ERROR    | LGDBryan:PDTermStructureCheck:401 - Alert: NaN value found at index 1636 with Reference ID PSFEB18459. Removing this row.
# 2024-02-23 10:50:17.214 | ERROR    | LGDBryan:PDTermStructureCheck:401 - Alert: NaN value found at index 1682 with Reference ID QA22788. Removing this row.
# 2024-02-23 10:50:17.215 | ERROR    | LGDBryan:PDTermStructureCheck:401 - Alert: NaN value found at index 1724 with Reference ID RS17356917. Removing this row.
# 2024-02-23 10:50:17.217 | ERROR    | LGDBryan:PDTermStructureCheck:401 - Alert: NaN value found at index 1824 with Reference ID SI5026024. Removing this row.
# 2024-02-23 10:50:17.218 | ERROR    | LGDBryan:PDTermStructureCheck:401 - Alert: NaN value found at index 1903 with Reference ID TN0000221M. Removing this row.
# 2024-02-23 10:50:17.219 | ERROR    | LGDBryan:PDTermStructureCheck:401 - Alert: NaN value found at index 1969 with Reference ID UA00039002. Removing this row.
# 2024-02-23 10:50:17.219 | ERROR    | LGDBryan:PDTermStructureCheck:401 - Alert: NaN value found at index 2028 with Reference ID US050495490. Removing this row.
# 2024-02-23 10:50:17.220 | ERROR    | LGDBryan:PDTermStructureCheck:401 - Alert: NaN value found at index 2149 with Reference ID US230581420. Removing this row.
# 2024-02-23 10:50:17.222 | ERROR    | LGDBryan:PDTermStructureCheck:401 - Alert: NaN value found at index 2498 with Reference ID US591387466. Removing this row.
# 2024-02-23 10:50:17.223 | ERROR    | LGDBryan:PDTermStructureCheck:401 - Alert: NaN value found at index 2729 with Reference ID US930412056. Removing this row.
# 2024-02-23 10:50:17.223 | ERROR    | LGDBryan:PDTermStructureCheck:401 - Alert: NaN value found at index 2774 with Reference ID USFEB18697. Removing this row.
# 2024-02-23 10:50:17.225 | ERROR    | LGDBryan:PDTermStructureCheck:401 - Alert: NaN value found at index 2777 with Reference ID USFEB47530. Removing this row.
# 2024-02-23 10:50:17.226 | ERROR    | LGDBryan:PDTermStructureCheck:401 - Alert: NaN value found at index 2786 with Reference ID USFEB62868. Removing this row.
#           Reference ID                                       Company Name  \
# 0           ADFEB18424             Andorra Banc Agricol Reig SA - AndBank
# 1           ADFEB18424             Andorra Banc Agricol Reig SA - AndBank
# 2           ADFEB18424             Andorra Banc Agricol Reig SA - AndBank
# 3           ADFEB18424             Andorra Banc Agricol Reig SA - AndBank
# 4           ADFEB18424             Andorra Banc Agricol Reig SA - AndBank
# ...                ...                                                ...
# 2835  VN1800278630-090  Sai Gon - Ha Noi Commercial Joint Stock Bank, ...
# 2836  VN1800278630-090  Sai Gon - Ha Noi Commercial Joint Stock Bank, ...
# 2837    VU*A0029818055                                       BRED Vanuatu
# 2838    VU*A0029818055                                       BRED Vanuatu
# 2839    VU*A0029818055                                       BRED Vanuatu
#
#      Private/Public Risk Determinant Type   PID  User PD 1  User PD 2  \
# 0           Private                    PD  None     0.0168     0.0300
# 1           Private                    PD  None     0.0281     0.0442
# 2           Private                    PD  None     0.0204     0.0349
# 3           Private                    PD  None     0.0237     0.0389
# 4           Private                    PD  None     0.0315     0.0487
# ...             ...                   ...   ...        ...        ...
# 2835        Private                    PD  None     0.6659     0.8216
# 2836        Private                    PD  None     1.6487     1.5122
# 2837        Private                    PD  None     4.1940     3.6109
# 2838        Private                    PD  None     4.1377     3.5411
# 2839        Private                    PD  None     5.6326     4.4672
#
#       User PD 3  User PD 4  User PD 5  ... Input Date Year Location Type  \
# 0        0.0423     0.0538     0.0649  ...          2017.0           ISO
# 1        0.0577     0.0696     0.0805  ...          2018.0           ISO
# 2        0.0477     0.0595     0.0707  ...          2019.0           ISO
# 3        0.0520     0.0638     0.0748  ...          2020.0           ISO
# 4        0.0630     0.0755     0.0869  ...          2021.0           ISO
# ...         ...        ...        ...  ...             ...           ...
# 2835     0.9290     1.0135     1.0843  ...          2021.0           ISO
# 2836     1.4376     1.3869     1.3488  ...          2022.0           ISO
# 2837     3.3075     3.1076     2.9607  ...          2020.0           ISO
# 2838     3.2322     3.0292     2.8804  ...          2021.0           ISO
# 2839     3.8983     3.5384     3.2818  ...          2022.0           ISO
#
#       Location Code  Industry Classification Industry Code  \
# 0               AND                      NDY           N31
# 1               AND                      NDY           N31
# 2               AND                      NDY           N31
# 3               AND                      NDY           N31
# 4               AND                      NDY           N31
# ...             ...                      ...           ...
# 2835            VNM                      NDY           N06
# 2836            VNM                      NDY           N06
# 2837            VUT                      NDY           N57
# 2838            VUT                      NDY           N57
# 2839            VUT                      NDY           N57
#
#            Debt / Seniority Capital Structure Bankruptcy Bailout  \
# 0     JuniorSubordinateBond      HasDebtAbove        Yes      No
# 1     JuniorSubordinateBond      HasDebtAbove        Yes      No
# 2     JuniorSubordinateBond      HasDebtAbove        Yes      No
# 3     JuniorSubordinateBond      HasDebtAbove        Yes      No
# 4     JuniorSubordinateBond      HasDebtAbove        Yes      No
# ...                     ...               ...        ...     ...
# 2835  JuniorSubordinateBond      HasDebtAbove        Yes      No
# 2836  JuniorSubordinateBond      HasDebtAbove        Yes      No
# 2837  JuniorSubordinateBond      HasDebtAbove        Yes      No
# 2838  JuniorSubordinateBond      HasDebtAbove        Yes      No
# 2839  JuniorSubordinateBond      HasDebtAbove        Yes      No
#
#      Recovery Forecast Type
# 0          PostDefaultPrice
# 1          PostDefaultPrice
# 2          PostDefaultPrice
# 3          PostDefaultPrice
# 4          PostDefaultPrice
# ...                     ...
# 2835       PostDefaultPrice
# 2836       PostDefaultPrice
# 2837       PostDefaultPrice
# 2838       PostDefaultPrice
# 2839       PostDefaultPrice
#
# [2840 rows x 23 columns]

# %%
# -------------Batch4----------------------------
# High Compute Case
start_time = datetime.now()
# This is like saying Create Loans for these entityIDs at 2017, December through 2022 December (5 for entityID if the entityID exists)
LGDinstantiation = LGD(api_publickey=credentials['Client'],api_privatekey= credentials['Client_Secret'], entities= batch4)
processid = LGDinstantiation.LGDServerSidePDAsynchronousEDFXAPIData(RiskCalcStartDate= "2017-12-01", RiskCalcEndDate= "2022-12-01",
                                                                    RiskCalchistoryFrequency= 'annual', asyncResponse=True)
end_time = datetime.now()
print('Duration:', end_time - start_time)
### processes----

print(f"The processing id for this run is as follows: {processid}\n")
while True:
    if LGDinstantiation.LGDProcessing(processID=processid):
        status = LGDinstantiation.EDFXModelInputsGetStatus(processID=processid)
        print(f"Process is running and will wait 3 minutes before checking. Current status: {status['status']}")
        time.sleep(180)
    else:
        status = LGDinstantiation.EDFXModelInputsGetStatus(processID=processid)
        print(f"Process completed. Final status: {status['status']}")
        break

RiskCalcServerSide4 = LGDinstantiation.LGDServerSidePDAsynchronousEDFXAPIData(processID=processid, DebtSeniority= "JuniorSubordinateBond",CapitalStructure= "HasDebtAbove",
                                                                             RecoveryForecastType="PostDefaultPrice",Bankruptcy = 'Yes', Bailout= 'No')

RiskCalcServerSide4['cleaned_df']
# Out:
# 2024-02-23 10:50:17.268 | INFO     | LGDBryan:__init__:157 - ATTENTION: To provide your Loan Specific Inputs you MUST USE RiskCalcLoanSpecification method to output the values in the RiskCalc.csv file.
# 2024-02-23 10:50:18.130 | INFO     | EDFXAuthentication:get_bearer_token:63 - Security token has been generated.
# Duration: 0:00:03.037217
# The processing id for this run is as follows: 6f3dd4ae-5e44-44b0-bfde-38a3b2e65663
#
# {'status': 'Requested'}
# {'status': 'Processing'}
# Process is running and will wait 3 minutes before checking. Current status: Processing
# {'status': 'Completed'}
# {'status': 'Completed'}
# Process completed. Final status: Completed
# 2024-02-23 10:53:28.803 | INFO     | LGDBryan:EDFXCSVClean:546 - Co-routines to be employed at mapping endpoint
# C:\Users\martyb\OneDrive - moodys.com\Documents\Development\EDF_X_Development\EDFXAPI_OOP\LGDBryan.py:556: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   EDFXDFSearchEndpoint["Private/Public"] = EDFXDFSearchEndpoint['isPublic'].apply(lambda x: 'Public' if x else 'Private')
# 2024-02-23 10:53:31.687 | ERROR    | LGDBryan:PDTermStructureCheck:401 - Alert: NaN value found at index 66 with Reference ID BDFEB44327. Removing this row.
# 2024-02-23 10:53:31.687 | ERROR    | LGDBryan:PDTermStructureCheck:401 - Alert: NaN value found at index 107 with Reference ID BWFEB44664. Removing this row.
# 2024-02-23 10:53:31.687 | ERROR    | LGDBryan:PDTermStructureCheck:401 - Alert: NaN value found at index 160 with Reference ID DEFEB13093. Removing this row.
# 2024-02-23 10:53:31.697 | ERROR    | LGDBryan:PDTermStructureCheck:401 - Alert: NaN value found at index 324 with Reference ID KZ950740000130. Removing this row.
# 2024-02-23 10:53:31.697 | ERROR    | LGDBryan:PDTermStructureCheck:401 - Alert: NaN value found at index 376 with Reference ID NZ9429039073440. Removing this row.
# 2024-02-23 10:53:31.697 | ERROR    | LGDBryan:PDTermStructureCheck:401 - Alert: NaN value found at index 399 with Reference ID PSFEB44478. Removing this row.
# 2024-02-23 10:53:31.700 | ERROR    | LGDBryan:PDTermStructureCheck:401 - Alert: NaN value found at index 698 with Reference ID USFEB60085. Removing this row.
# 2024-02-23 10:53:31.701 | ERROR    | LGDBryan:PDTermStructureCheck:401 - Alert: NaN value found at index 710 with Reference ID USFR150576. Removing this row.
#         Reference ID                                Company Name  \
# 0    AD*110344726656                               Vall Banc, SA
# 1    AD*110344726656                               Vall Banc, SA
# 2    AD*110344726656                               Vall Banc, SA
# 3         AEFEB31277  Arab Bank FOR Investment and Foreign Trade
# 4         AEFEB31277  Arab Bank FOR Investment and Foreign Trade
# ..               ...                                         ...
# 725     VN0301232798                     HSBC Bank (Vietnam) Ltd
# 726     VN0301232798                     HSBC Bank (Vietnam) Ltd
# 727       VUFEB39788                  ANZ Bank (Vanuatu) Limited
# 728       VUFEB39788                  ANZ Bank (Vanuatu) Limited
# 729       VUFEB39788                  ANZ Bank (Vanuatu) Limited
#
#     Private/Public Risk Determinant Type   PID  User PD 1  User PD 2  \
# 0          Private                    PD  None     3.8997     3.2955
# 1          Private                    PD  None     3.0536     2.7761
# 2          Private                    PD  None     5.3270     4.2699
# 3          Private                    PD  None     0.2544     0.2910
# 4          Private                    PD  None     0.1381     0.1643
# ..             ...                   ...   ...        ...        ...
# 725        Private                    PD  None     0.0393     0.0536
# 726        Private                    PD  None     0.0762     0.0882
# 727        Private                    PD  None     1.4130     1.4358
# 728        Private                    PD  None     1.2943     1.3564
# 729        Private                    PD  None     5.6326     4.4672
#
#      User PD 3  User PD 4  User PD 5  ... Input Date Year Location Type  \
# 0       2.9857     2.7835     2.6360  ...          2020.0           ISO
# 1       2.6254     2.5234     2.4470  ...          2021.0           ISO
# 2       3.7496     3.4187     3.1819  ...          2022.0           ISO
# 3       0.3149     0.3330     0.3477  ...          2017.0           ISO
# 4       0.1819     0.1955     0.2067  ...          2018.0           ISO
# ..         ...        ...        ...  ...             ...           ...
# 725     0.0643     0.0731     0.0808  ...          2021.0           ISO
# 726     0.0960     0.1020     0.1069  ...          2022.0           ISO
# 727     1.4493     1.4589     1.4665  ...          2020.0           ISO
# 728     1.3940     1.4214     1.4430  ...          2021.0           ISO
# 729     3.8983     3.5384     3.2818  ...          2022.0           ISO
#
#      Location Code  Industry Classification Industry Code  \
# 0              AND                      NDY           N57
# 1              AND                      NDY           N57
# 2              AND                      NDY           N57
# 3              ARE                      NDY           N06
# 4              ARE                      NDY           N06
# ..             ...                      ...           ...
# 725            VNM                      NDY           N06
# 726            VNM                      NDY           N06
# 727            VUT                      NDY           N06
# 728            VUT                      NDY           N06
# 729            VUT                      NDY           N06
#
#           Debt / Seniority Capital Structure Bankruptcy Bailout  \
# 0    JuniorSubordinateBond      HasDebtAbove        Yes      No
# 1    JuniorSubordinateBond      HasDebtAbove        Yes      No
# 2    JuniorSubordinateBond      HasDebtAbove        Yes      No
# 3    JuniorSubordinateBond      HasDebtAbove        Yes      No
# 4    JuniorSubordinateBond      HasDebtAbove        Yes      No
# ..                     ...               ...        ...     ...
# 725  JuniorSubordinateBond      HasDebtAbove        Yes      No
# 726  JuniorSubordinateBond      HasDebtAbove        Yes      No
# 727  JuniorSubordinateBond      HasDebtAbove        Yes      No
# 728  JuniorSubordinateBond      HasDebtAbove        Yes      No
# 729  JuniorSubordinateBond      HasDebtAbove        Yes      No
#
#     Recovery Forecast Type
# 0         PostDefaultPrice
# 1         PostDefaultPrice
# 2         PostDefaultPrice
# 3         PostDefaultPrice
# 4         PostDefaultPrice
# ..                     ...
# 725       PostDefaultPrice
# 726       PostDefaultPrice
# 727       PostDefaultPrice
# 728       PostDefaultPrice
# 729       PostDefaultPrice
#
# [730 rows x 23 columns]

# %%
# example of how to concat
# One would continue this process for Batch 3, 4, 5, and 6
RiskCalcdf = pd.concat([RiskCalcServerSide1['cleaned_df'],RiskCalcServerSide2['cleaned_df'],RiskCalcServerSide3['cleaned_df'],RiskCalcServerSide4['cleaned_df']])
RiskCalcdf.head()
# Out:
#   Reference ID                Company Name Private/Public  \
# 0   AEFEB16394  Mawarid Finance (P J S C )        Private
# 1   AEFEB16394  Mawarid Finance (P J S C )        Private
# 2   AEFEB16394  Mawarid Finance (P J S C )        Private
# 3   AEFEB16394  Mawarid Finance (P J S C )        Private
# 4   AEFEB16394  Mawarid Finance (P J S C )        Private
#
#   Risk Determinant Type   PID  User PD 1  User PD 2  User PD 3  User PD 4  \
# 0                    PD  None     4.2782     2.8152     2.2010     1.8476
# 1                    PD  None     1.2585     0.8853     0.7204     0.6224
# 2                    PD  None     1.1152     0.7880     0.6430     0.5565
# 3                    PD  None     1.5805     1.2135     1.0396     0.9314
# 4                    PD  None     0.1473     0.1606     0.1689     0.1750
#
#    User PD 5  ... Input Date Year Location Type  Location Code  \
# 0     1.6127  ...          2017.0           ISO            ARE
# 1     0.5556  ...          2018.0           ISO            ARE
# 2     0.4975  ...          2019.0           ISO            ARE
# 3     0.8553  ...          2020.0           ISO            ARE
# 4     0.1799  ...          2021.0           ISO            ARE
#
#    Industry Classification Industry Code       Debt / Seniority  \
# 0                      NDY           N06  JuniorSubordinateBond
# 1                      NDY           N06  JuniorSubordinateBond
# 2                      NDY           N06  JuniorSubordinateBond
# 3                      NDY           N06  JuniorSubordinateBond
# 4                      NDY           N06  JuniorSubordinateBond
#
#   Capital Structure Bankruptcy Bailout Recovery Forecast Type
# 0      HasDebtAbove        Yes      No       PostDefaultPrice
# 1      HasDebtAbove        Yes      No       PostDefaultPrice
# 2      HasDebtAbove        Yes      No       PostDefaultPrice
# 3      HasDebtAbove        Yes      No       PostDefaultPrice
# 4      HasDebtAbove        Yes      No       PostDefaultPrice
#
# [5 rows x 23 columns]

# %%
RiskCalcdf.shape
# Out:
# (8935, 23)

# %% [markdown]
# # CASE 3 | EDFX-API Exclusive| EntityIDs Or Provide a EDFX.Csv Dataframe
#
# - For Brevity we show entities Example
# - We always specify the loan paramaters at instantiation of the LGD Class for the case 3 approach.
# - CASE 3 means we use everything from the EDFX-API.
# - We provide the ability to use co-routines for Mapping, Pds, and LGD endpoints
# - We also provide parsing and the LGD Scorecard example with this Example.
#
#
# ### Important Difference for Evaluating LGD through Time in Case 3.
#
# - If you have a loan, and you would like to see how the LGD term structure evolved you have several options.
#
#     You can set LGDPDEndDate to the year you want to see historically, for example, 2022-01-01 and then match that date with the LGDAsOfDate = 2022-01-01 so you will have the LGD Term structure of the entity for the 2022-01-01 period matched with the 2022-01-01 LGD Macro overlay for the same time period.  You would do the same thing for 2023-01-01 = Case3LGDPDEndDate = Case3LGDasOfDate and so on.  I would recommend writing a function for simplicity.
#
# ### Key Point:
#
# Understand the LGDPDStartDate and LGDPDEndDate are simply pulling the pd term structures needed for the LGD Payload at that time period.  If you apply them like we applied them in the high compute cases for CASE 2, RiskCalcStartDate= "2017-12-01", RiskCalcEndDate= "2022-12-01" , then you would be pulling the term structure as ==> Case3LGDPDStartDate =  "2017-12-01" & Case3LGDPDEndDate =  "2022-12-01". Thus, you would be pulling the LGD Term Structure each year until 2022 HOWEVER you'd be maintaining the same Case3LGDasOfDate = "YYYY-MM-DD".  Thus you'd be applying the 2017-12-01 LGD PD annual term structure with a fixed YYYY-MM-DD LGD Macro Overlay.  You can do this If and only IF you suspect that time period for the macro LGD Overlay is a representative of the Macro overlay for the time period.

# %%
endpoints = EDFXEndpoints(credentials['Client'], credentials['Client_Secret'])
EDFXdf_highcompute = pd.read_csv(bvdIDColumns).drop_duplicates()
EDFXdf_highcompute
HighPayload = endpoints.format_PDpayload(EDFXdf_highcompute['BvD ID'])
len(HighPayload)
# Out:
# 1841

# %%
#LGD Instantiation: Notice in case 3 we set all loan variables for the LGD payload in the LGD Class instantiation
LGDinstantiation = LGD(
    api_publickey=credentials['Client'],
    api_privatekey=credentials['Client_Secret'],
    case=3,
    entities=HighPayload,
    Case3LGDCountry='USA',
    Case3LGDInstrumentType="Senior Bond",
    IndustryClassification="NDY",
    Case3LGDasOfDate="2024-01-01",
    Case3LGDSecuredUnsecured="Unsecured",
    Case3LGDRecoveryCalculationMode="Ultimate Recovery",
    Case3LGDMaturityDate="2028-01-01",
    Case3LGDExposure=10000000,
    # PULL THE term structure to align entity information with macro overlay date of 2024-01-01
    Case3LGDPDEndDate= "2024-01-01",
    case3LGDOriginationDate= "2023-01-01",
    Case3LGDhistoryFrequency='annual')


# case 3 Methods
dicitonary3 = LGDinstantiation.LGDCase3datadictionary()
df = dicitonary3['cleaned_df']
LGDFinal = LGDinstantiation.EDFXLGDFinal(df, use_loan_scorecard=True)
LGDFinal
# Out:
# 2024-02-27 09:26:17.518 | INFO     | EDFXLGD:EDFXCSVClean:552 - Co-routines to be employed at mapping endpoint
# 2024-02-27 09:26:18.436 | INFO     | EDFXAuthentication:get_bearer_token:63 - Security token has been generated.
# C:\Users\martyb\OneDrive - moodys.com\Documents\Development\EDF_X_Development\EDFXAPI_OOP\EDFXLGD.py:562: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   EDFXDFSearchEndpoint["Private/Public"] = EDFXDFSearchEndpoint['isPublic'].apply(lambda x: 'Public' if x else 'Private')
# 2024-02-27 09:26:25.844 | INFO     | EDFXLGD:LGDClientSideEDFXPDTermStructures:835 - Co-routines to be employed at PDs endpoint.
# 2024-02-27 09:26:49.386 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': None, 'endDate': '2024-01-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'ILFEB46222'}, {'entityId': 'US951068595'}]}
# 2024-02-27 09:26:49.389 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': None, 'endDate': '2024-01-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'TW03077208'}, {'entityId': 'US141136850'}]}
# 2024-02-27 09:26:49.394 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': None, 'endDate': '2024-01-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'US610549795'}, {'entityId': 'LIFL00025772037'}]}
# 2024-02-27 09:26:49.398 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': None, 'endDate': '2024-01-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'GB06029941'}, {'entityId': 'BR04184779000101'}]}
# 2024-02-27 09:26:49.400 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': None, 'endDate': '2024-01-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'US030213411'}, {'entityId': 'US520627367'}]}
# 2024-02-27 09:26:49.403 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': None, 'endDate': '2024-01-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'OM1152878'}, {'entityId': 'USFEB78170'}]}
# 2024-02-27 09:26:49.405 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': None, 'endDate': '2024-01-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'RU11448761N'}, {'entityId': 'KR1101110377203'}]}
# 2024-02-27 09:26:49.414 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': None, 'endDate': '2024-01-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'US940490050'}, {'entityId': 'PHFEB31513'}]}
# 2024-02-27 09:26:49.417 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': None, 'endDate': '2024-01-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'US124015543L'}, {'entityId': 'MY2192-K'}]}
# 2024-02-27 09:26:49.420 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': None, 'endDate': '2024-01-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'FR334270071'}, {'entityId': 'US126007538L'}]}
# 2024-02-27 09:26:49.423 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': None, 'endDate': '2024-01-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'IT06874351007'}, {'entityId': 'US390671465'}]}
# 2024-02-27 09:26:49.427 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': None, 'endDate': '2024-01-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'US389265437L'}, {'entityId': 'US930295215'}]}
# 2024-02-27 09:26:49.430 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': None, 'endDate': '2024-01-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'RO10318789'}, {'entityId': 'JP6480001000061'}]}
# 2024-02-27 09:26:49.433 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': None, 'endDate': '2024-01-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'SE5164019878'}, {'entityId': 'MXBBA940707IE1'}]}
# 2024-02-27 09:26:49.436 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': None, 'endDate': '2024-01-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'US232041671L'}, {'entityId': 'US193243344L'}]}
# 2024-02-27 09:26:49.438 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': None, 'endDate': '2024-01-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'PY80013884-8'}, {'entityId': 'PA714633RPP'}]}
# 2024-02-27 09:26:49.440 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': None, 'endDate': '2024-01-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'LBFEB46093'}, {'entityId': 'CN*Z00056076'}]}
# 2024-02-27 09:26:49.443 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': None, 'endDate': '2024-01-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'RU09807684'}, {'entityId': 'AU006434162'}]}
# 2024-02-27 09:26:49.445 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': None, 'endDate': '2024-01-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'US365503526L'}, {'entityId': 'US352306493L'}]}
# 2024-02-27 09:26:49.447 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': None, 'endDate': '2024-01-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'TR259652F'}, {'entityId': 'SN000015314'}]}
# 2024-02-27 09:26:49.449 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': None, 'endDate': '2024-01-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'SG201000378D'}, {'entityId': 'KZ080940010300'}]}
# 2024-02-27 09:26:49.450 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': None, 'endDate': '2024-01-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'US128824290L'}, {'entityId': 'US061798488'}]}
# 2024-02-27 09:26:49.452 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': None, 'endDate': '2024-01-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'DE8171219741'}, {'entityId': 'US249556526L'}]}
# 2024-02-27 09:26:49.454 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': None, 'endDate': '2024-01-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'ATFEB43719'}, {'entityId': 'FR*110340303633'}]}
# 2024-02-27 09:26:49.455 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': None, 'endDate': '2024-01-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'US256315817L'}, {'entityId': 'US149118920L'}]}
# 2024-02-27 09:26:49.456 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': None, 'endDate': '2024-01-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'US113412575'}, {'entityId': 'US134659519L'}]}
# 2024-02-27 09:26:49.458 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': None, 'endDate': '2024-01-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'US581493818'}, {'entityId': 'US363783644'}]}
# 2024-02-27 09:26:49.459 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': None, 'endDate': '2024-01-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'MY6463-H'}, {'entityId': 'USFR2760102'}]}
# 2024-02-27 09:26:49.461 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': None, 'endDate': '2024-01-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'GB09092149'}, {'entityId': 'ME02096099'}]}
# 2024-02-27 09:26:51.779 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': None, 'endDate': '2024-01-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'US325861373L'}, {'entityId': 'US250155275L'}]}
# 2024-02-27 09:26:51.784 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': None, 'endDate': '2024-01-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'DE6070428742'}, {'entityId': 'CWFEB49968'}]}
# 2024-02-27 09:26:51.784 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': None, 'endDate': '2024-01-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'MXEMS080307J21'}, {'entityId': 'TH0107544000078'}]}
# 2024-02-27 09:26:51.786 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': None, 'endDate': '2024-01-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'UA21133352'}, {'entityId': 'SE5565746624'}]}
# 2024-02-27 09:26:51.789 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': None, 'endDate': '2024-01-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'US410191495'}, {'entityId': 'ILFEB32681'}]}
# 2024-02-27 09:26:51.793 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': None, 'endDate': '2024-01-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'US460119480'}, {'entityId': 'US610153605'}]}
# 2024-02-27 09:26:51.796 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': None, 'endDate': '2024-01-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'PHCS200413056'}, {'entityId': 'US111814791'}]}
# 2024-02-27 09:26:51.797 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': None, 'endDate': '2024-01-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'US940755684'}, {'entityId': 'US060655031'}]}
# 2024-02-27 09:26:51.799 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': None, 'endDate': '2024-01-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'US135250676L'}, {'entityId': 'US360263228L'}]}
# 2024-02-27 09:26:51.799 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': None, 'endDate': '2024-01-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'CO8600323303'}, {'entityId': 'BY100429079'}]}
# 2024-02-27 09:26:51.801 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': None, 'endDate': '2024-01-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'US420794732'}, {'entityId': 'US420670685'}]}
# 2024-02-27 09:26:51.802 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': None, 'endDate': '2024-01-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'US421410409'}, {'entityId': 'BR*110348759797'}]}
# 2024-02-27 09:26:51.806 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': None, 'endDate': '2024-01-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'US381495887L'}, {'entityId': 'US390066965L'}]}
# 2024-02-27 09:26:51.809 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': None, 'endDate': '2024-01-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'US316034826'}, {'entityId': 'LULB109476'}]}
# 2024-02-27 09:26:51.811 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': None, 'endDate': '2024-01-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'US390275675L'}, {'entityId': 'US389399039L'}]}
# 2024-02-27 09:26:51.813 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': None, 'endDate': '2024-01-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'ADFEB18424'}, {'entityId': 'US942387524'}]}
# 2024-02-27 09:26:51.815 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': None, 'endDate': '2024-01-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'US116014903'}, {'entityId': 'US952023588'}]}
# 2024-02-27 09:26:51.817 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': None, 'endDate': '2024-01-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'US127532358L'}, {'entityId': 'US126335371L'}]}
# 2024-02-27 09:26:51.818 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': None, 'endDate': '2024-01-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'INFEB34197'}, {'entityId': 'CDFEB32648'}]}
# 2024-02-27 09:26:51.819 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': None, 'endDate': '2024-01-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'US127691572L'}, {'entityId': 'US320617826L'}]}
# 2024-02-27 09:26:51.820 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': None, 'endDate': '2024-01-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'CNFEB33572'}, {'entityId': 'TTFEB42313'}]}
# 2024-02-27 09:26:51.821 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': None, 'endDate': '2024-01-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'US257627963L'}, {'entityId': 'US370726751L'}]}
# 2024-02-27 09:26:51.824 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': None, 'endDate': '2024-01-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'US390160244L'}, {'entityId': 'US368222738L'}]}
# 2024-02-27 09:26:51.826 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': None, 'endDate': '2024-01-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'USFR542649'}, {'entityId': 'AOFEB39009'}]}
# 2024-02-27 09:26:51.828 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': None, 'endDate': '2024-01-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'PA16183RPP'}, {'entityId': 'US720210640'}]}
# 2024-02-27 09:26:51.830 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': None, 'endDate': '2024-01-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'DO16972SDQ'}, {'entityId': 'PSFEB18459'}]}
# 2024-02-27 09:26:51.844 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': None, 'endDate': '2024-01-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'US257995886L'}, {'entityId': 'US69923NU'}]}
# 2024-02-27 09:26:51.847 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': None, 'endDate': '2024-01-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'GB00929027'}, {'entityId': 'MAFEB94523'}]}
# 2024-02-27 09:26:51.848 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': None, 'endDate': '2024-01-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'US343430270L'}, {'entityId': 'US374781902L'}]}
# 2024-02-27 09:26:51.850 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': None, 'endDate': '2024-01-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'US123796165L'}, {'entityId': 'AEFEB31277'}]}
# 2024-02-27 09:26:51.851 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': None, 'endDate': '2024-01-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'US460403712'}, {'entityId': 'USFR2654818'}]}
# 2024-02-27 09:26:51.854 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': None, 'endDate': '2024-01-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'US134478091L'}, {'entityId': 'US371469119L'}]}
# 2024-02-27 09:26:51.855 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': None, 'endDate': '2024-01-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'BH0048415410'}, {'entityId': 'JP6010401141832'}]}
# 2024-02-27 09:26:51.856 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': None, 'endDate': '2024-01-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'GB12672104'}, {'entityId': 'US367247576L'}]}
# 2024-02-27 09:26:51.862 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': None, 'endDate': '2024-01-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'KG02910198910019'}, {'entityId': 'US850113445'}]}
# 2024-02-27 09:26:51.865 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': None, 'endDate': '2024-01-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'US251094822'}, {'entityId': 'US020163906'}]}
# 2024-02-27 09:26:51.868 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': None, 'endDate': '2024-01-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'US341746771'}, {'entityId': 'US941562490'}]}
# 2024-02-27 09:26:51.870 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': None, 'endDate': '2024-01-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'US540314870'}, {'entityId': 'US250974214'}]}
# 2024-02-27 09:26:51.872 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': None, 'endDate': '2024-01-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'US010024610'}, {'entityId': 'ATFEB28950'}]}
# 2024-02-27 09:26:51.894 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': None, 'endDate': '2024-01-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'USFR2023478'}, {'entityId': 'RS17335677'}]}
# 2024-02-27 09:26:51.921 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': None, 'endDate': '2024-01-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'GB13197669'}, {'entityId': 'US390729431L'}]}
# 2024-02-27 09:26:51.926 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': None, 'endDate': '2024-01-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'AZ1300017201'}, {'entityId': 'FI21937564'}]}
# 2024-02-27 09:26:55.011 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': None, 'endDate': '2024-01-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'MY6175-W'}, {'entityId': 'US741185010'}]}
# 2024-02-27 09:26:55.016 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': None, 'endDate': '2024-01-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'LVFEB33715'}, {'entityId': 'KH00015794'}]}
# 2024-02-27 09:26:55.018 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': None, 'endDate': '2024-01-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'BE0404453574'}, {'entityId': 'US954110181'}]}
# 2024-02-27 09:26:55.021 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': None, 'endDate': '2024-01-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'US361060230'}, {'entityId': 'US911609689'}]}
# 2024-02-27 09:26:55.024 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': None, 'endDate': '2024-01-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'US751447986'}, {'entityId': 'SE5561587634'}]}
# 2024-02-27 09:26:55.029 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': None, 'endDate': '2024-01-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'FR519135255'}, {'entityId': 'USLEI112224'}]}
# 2024-02-27 09:26:55.032 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': None, 'endDate': '2024-01-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'LKFEB44194'}, {'entityId': 'MD1002600005347'}]}
# 2024-02-27 09:26:55.034 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': None, 'endDate': '2024-01-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'UY210465260012'}, {'entityId': 'RU34236369'}]}
# 2024-02-27 09:26:55.036 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': None, 'endDate': '2024-01-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'IE612228'}, {'entityId': 'USFR879532'}]}
# 2024-02-27 09:26:55.037 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': None, 'endDate': '2024-01-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'RU17538910'}, {'entityId': 'GI108217'}]}
# 2024-02-27 09:26:55.043 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': None, 'endDate': '2024-01-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'EC1790283380001'}, {'entityId': 'US582661919'}]}
# 2024-02-27 09:26:55.044 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': None, 'endDate': '2024-01-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'AU010831722'}, {'entityId': 'SE5561581041'}]}
# 2024-02-27 09:26:55.047 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': None, 'endDate': '2024-01-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'CAFEB14783'}, {'entityId': 'PA629823RPP'}]}
# 2024-02-27 09:26:55.049 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': None, 'endDate': '2024-01-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'US340746485'}, {'entityId': 'NZ9429046715470'}]}
# 2024-02-27 09:26:55.050 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': None, 'endDate': '2024-01-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'ME02085020'}, {'entityId': 'CNFEB17425'}]}
# 2024-02-27 09:26:55.052 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': None, 'endDate': '2024-01-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'US250964885'}, {'entityId': 'US374995151L'}]}
# 2024-02-27 09:26:55.054 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': None, 'endDate': '2024-01-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'US365866850L'}, {'entityId': 'GB10241368'}]}
# 2024-02-27 09:26:55.056 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': None, 'endDate': '2024-01-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'US322022252L'}, {'entityId': 'US130612970'}]}
# 2024-02-27 09:26:55.058 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': None, 'endDate': '2024-01-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'INFEB31483'}, {'entityId': 'DOFEB40658'}]}
# 2024-02-27 09:26:55.060 | ERROR    | EDFXPrime:_post_async:657 - Server Response {'detail': 'Internal service not working. Contact Support.'}
#  params for the failedentity is: {'startDate': None, 'endDate': '2024-01-01', 'historyFrequency': 'annual', 'asyncResponse': False, 'asReported': False, 'modelParameters': {'fso': False}, 'includeDetail': {'resultDetail': True, 'inputDetail': False, 'modelDetail': False, 'includeTermStructure': True}, 'entities': [{'entityId': 'NG103022R'}, {'entityId': 'AU070887679'}]}
# ...
# 2024-02-27 09:31:46.658 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 857 with Reference ID KNFEB93625. Removing this row.
# 2024-02-27 09:31:46.661 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 869 with Reference ID US540301610. Removing this row.
# 2024-02-27 09:31:46.665 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 874 with Reference ID US134149421. Removing this row.
# 2024-02-27 09:31:46.668 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 886 with Reference ID RS17356917. Removing this row.
# 2024-02-27 09:31:46.669 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 894 with Reference ID KV810485864. Removing this row.
# 2024-02-27 09:31:46.671 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 902 with Reference ID GB06029941. Removing this row.
# 2024-02-27 09:31:46.677 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 920 with Reference ID DEFEB14028. Removing this row.
# 2024-02-27 09:31:46.681 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 944 with Reference ID IL51-447-9211. Removing this row.
# 2024-02-27 09:31:46.685 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 956 with Reference ID SI5026024. Removing this row.
# 2024-02-27 09:31:46.692 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 964 with Reference ID CHCHE105884494. Removing this row.
# 2024-02-27 09:31:46.693 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 993 with Reference ID AZFEB47325. Removing this row.
# 2024-02-27 09:31:46.700 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 994 with Reference ID UA00039002. Removing this row.
# 2024-02-27 09:31:46.702 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 995 with Reference ID BG813071350. Removing this row.
# 2024-02-27 09:31:46.720 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 1001 with Reference ID US930412056. Removing this row.
# 2024-02-27 09:31:46.721 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 1007 with Reference ID PE20259702411. Removing this row.
# 2024-02-27 09:31:46.724 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 1016 with Reference ID QA22788. Removing this row.
# 2024-02-27 09:31:46.725 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 1029 with Reference ID EGFEB47093. Removing this row.
# 2024-02-27 09:31:46.730 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 1047 with Reference ID GB10485907. Removing this row.
# 2024-02-27 09:31:46.734 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 1057 with Reference ID USFR2575155. Removing this row.
# 2024-02-27 09:31:46.738 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 1058 with Reference ID US046017803. Removing this row.
# 2024-02-27 09:31:46.739 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 1085 with Reference ID JM91090L. Removing this row.
# 2024-02-27 09:31:46.745 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 1091 with Reference ID HK0014036219. Removing this row.
# 2024-02-27 09:31:46.784 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 1098 with Reference ID US941532380. Removing this row.
# 2024-02-27 09:31:46.819 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 1102 with Reference ID SAFEB30906. Removing this row.
# 2024-02-27 09:31:46.826 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 1103 with Reference ID USFR854520. Removing this row.
# 2024-02-27 09:31:46.830 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 1115 with Reference ID CAFEB21757. Removing this row.
# 2024-02-27 09:31:46.832 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 1152 with Reference ID GBFC008874. Removing this row.
# 2024-02-27 09:31:46.833 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 1156 with Reference ID US951687284. Removing this row.
# 2024-02-27 09:31:46.835 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 1183 with Reference ID RU09301192. Removing this row.
# 2024-02-27 09:31:46.838 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 1198 with Reference ID TH0107536001401. Removing this row.
# 2024-02-27 09:31:46.840 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 1207 with Reference ID BR34098442000134. Removing this row.
# 2024-02-27 09:31:46.842 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 1232 with Reference ID BE0712624257. Removing this row.
# 2024-02-27 09:31:46.843 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 1236 with Reference ID JO0071329323. Removing this row.
# 2024-02-27 09:31:46.845 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 1240 with Reference ID US351118182. Removing this row.
# 2024-02-27 09:31:46.848 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 1259 with Reference ID BG831558413. Removing this row.
# 2024-02-27 09:31:46.850 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 1267 with Reference ID USFR2047504. Removing this row.
# 2024-02-27 09:31:46.854 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 1282 with Reference ID AO100020094. Removing this row.
# 2024-02-27 09:31:46.857 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 1285 with Reference ID GBFC022861. Removing this row.
# 2024-02-27 09:31:46.858 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 1304 with Reference ID NL30076284. Removing this row.
# 2024-02-27 09:31:46.860 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 1314 with Reference ID US341111088. Removing this row.
# 2024-02-27 09:31:46.864 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 1330 with Reference ID US221865454. Removing this row.
# 2024-02-27 09:31:46.867 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 1335 with Reference ID KZFEB19013. Removing this row.
# 2024-02-27 09:31:46.869 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 1349 with Reference ID US273973786. Removing this row.
# 2024-02-27 09:31:46.871 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 1352 with Reference ID CHCHE113422612. Removing this row.
# 2024-02-27 09:31:46.938 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 1363 with Reference ID US930593084. Removing this row.
# 2024-02-27 09:31:46.940 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 1365 with Reference ID LY0000031769. Removing this row.
# 2024-02-27 09:31:46.944 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 1374 with Reference ID BH46348. Removing this row.
# 2024-02-27 09:31:46.947 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 1376 with Reference ID AE22664211B. Removing this row.
# 2024-02-27 09:31:46.950 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 1377 with Reference ID PT503016160. Removing this row.
# 2024-02-27 09:31:46.952 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 1388 with Reference ID US330830202. Removing this row.
# 2024-02-27 09:31:46.954 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 1403 with Reference ID US310738296. Removing this row.
# 2024-02-27 09:31:46.955 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 1408 with Reference ID SAFEB31637. Removing this row.
# 2024-02-27 09:31:46.958 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 1425 with Reference ID MU0000063321. Removing this row.
# 2024-02-27 09:31:46.960 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 1430 with Reference ID BG831686320. Removing this row.
# 2024-02-27 09:31:46.961 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 1467 with Reference ID GB07143703. Removing this row.
# 2024-02-27 09:31:46.963 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 1473 with Reference ID LT112029270. Removing this row.
# 2024-02-27 09:31:46.965 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 1476 with Reference ID GBFC023527. Removing this row.
# 2024-02-27 09:31:46.967 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 1477 with Reference ID AO100010483. Removing this row.
# 2024-02-27 09:31:46.968 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 1485 with Reference ID ZA196500670606. Removing this row.
# 2024-02-27 09:31:46.970 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 1529 with Reference ID CA133460243L. Removing this row.
# 2024-02-27 09:31:46.971 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 1540 with Reference ID RO11007551. Removing this row.
# 2024-02-27 09:31:46.973 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 1583 with Reference ID US230581420. Removing this row.
# 2024-02-27 09:31:46.975 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 1599 with Reference ID USFEB62868. Removing this row.
# 2024-02-27 09:31:46.978 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 1660 with Reference ID KZ930940000164. Removing this row.
# 2024-02-27 09:31:46.982 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 1671 with Reference ID DEFEB14781. Removing this row.
# 2024-02-27 09:31:46.983 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 1676 with Reference ID MXFEB44940. Removing this row.
# 2024-02-27 09:31:46.985 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 1678 with Reference ID IS6601071180. Removing this row.
# 2024-02-27 09:31:46.987 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 1708 with Reference ID US660573723. Removing this row.
# 2024-02-27 09:31:46.988 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 1715 with Reference ID KV810485145. Removing this row.
# 2024-02-27 09:31:46.990 | ERROR    | EDFXLGD:PDTermStructureCheck:407 - Alert: NaN value found at index 1723 with Reference ID PL141334039. Removing this row.
#                                             entityId  longRunLgd  \
# 0                   Northfield Mountain Holdings LLC    0.255777
# 1   TCW Direct Lending Structured Solutions 2019 LLC    0.516037
# 0                      Northern Courier Pipeline LTD    0.516037
# 1                       NET Health Acquisition Corp.    0.516037
# 0                                  Mcpf Holdings LLC    0.516037
# ..                                               ...         ...
# 0                                       Redbanc S.A.    0.626780
# 1                                           Azerpost    0.516037
# 0                                  Credit du Nord SA    0.516037
# 1                               Twisto payments a.s.    0.516037
# 0                  Jordan Dubai Islamic Bank Company    0.516037
#
#     longRunRecovery    tenor        pd  expectedLossAmount  \
# 0          0.744223  4.00274  0.055218        1.449086e+05
# 1          0.483963  4.00274  0.057898        3.203175e+05
# 0          0.483963  4.00274  0.203913        1.153651e+06
# 1          0.483963  4.00274  0.090030        5.001383e+05
# 0          0.483963  4.00274  0.095565        5.312199e+05
# ..              ...      ...       ...                 ...
# 0          0.373220  4.00274  0.056387        3.554114e+05
# 1          0.483963  4.00274  0.092586        4.713094e+05
# 0          0.483963  4.00274  0.031798        1.527021e+05
# 1          0.483963  4.00274  0.494638        2.789681e+06
# 0          0.483963  4.00274  0.089021        4.952890e+05
#
#     expectedLossPercent expectedLossRating  annualizedRecovery1Y  \
# 0              0.014491               Baa3              0.732385
# 1              0.032032                Ba3              0.425247
# 0              0.115365              Caa-C              0.414380
# 1              0.050014                 B1              0.423417
# 0              0.053122                 B1              0.423100
# ..                  ...                ...                   ...
# 0              0.035541                Ba3              0.359210
# 1              0.047131                 B1              0.480645
# 0              0.015270                Ba1              0.518821
# 1              0.278968              Caa-C              0.419286
# 0              0.049529                 B1              0.423009
#
#     annualizedRecovery2Y  ...  cumulativePd1Y  cumulativePd2Y  cumulativePd3Y  \
# 0               0.736633  ...        0.012428        0.026291        0.040619
# 1               0.446313  ...        0.014898        0.029468        0.043782
# 0               0.439345  ...        0.092973        0.138557        0.173995
# 1               0.445140  ...        0.028045        0.050471        0.070891
# 0               0.444936  ...        0.030323        0.054081        0.075549
# ..                   ...  ...             ...             ...             ...
# 0               0.364237  ...        0.015178        0.029345        0.043031
# 1               0.481836  ...        0.029727        0.052694        0.073361
# 0               0.506314  ...        0.009548        0.017448        0.024792
# 1               0.442490  ...        0.321512        0.402170        0.454933
# 0               0.444878  ...        0.030975        0.052709        0.071689
#
#     cumulativePd4Y  cumulativePd5Y  cumulativePd6Y  cumulativePd7Y  \
# 0         0.055177        0.069845        0.084286        0.098502
# 1         0.057860        0.071713        0.085361        0.098810
# 0         0.203840        0.229960        0.255223        0.279658
# 1         0.089980        0.108054        0.125768        0.143131
# 0         0.095513        0.114339        0.132773        0.150823
# ..             ...             ...             ...             ...
# 0         0.056351        0.069358        0.082186        0.094838
# 1         0.092536        0.110591        0.128287        0.145630
# 0         0.031780        0.038503        0.045180        0.051811
# 1         0.494548        0.526325        0.556104        0.584011
# 0         0.088977        0.105045        0.120830        0.136337
#
#     cumulativePd8Y  cumulativePd9Y  cumulativePd10Y
# 0         0.112498        0.126276         0.139840
# 1         0.112060        0.125115         0.137979
# 0         0.303290        0.326147         0.348255
# 1         0.160149        0.176829         0.193178
# 0         0.168498        0.185804         0.202751
# ..             ...             ...              ...
# 0         0.107315        0.119620         0.131755
# 1         0.162629        0.179289         0.195618
# 0         0.058395        0.064934         0.071428
# 1         0.610164        0.634672         0.657640
# 0         0.151570        0.166535         0.181235
#
# [1669 rows x 81 columns]

# %% [markdown]
# # CASE 3 | EDFX-API Exclusive| LGD ScoreCard

# %%
# This cell shows how to add user defined loan scorecard with Case 3
endpoints = EDFXEndpoints(credentials['Client'], credentials['Client_Secret'])
EDFXdf_highcompute = pd.read_csv(bvdIDColumns)
smallPayload = endpoints.format_PDpayload(EDFXdf_highcompute['BvD ID'])[:5]
len(smallPayload)

#LGD Instantiation
LGDinstantiation = LGD(
    api_publickey=credentials['Client'],
    api_privatekey=credentials['Client_Secret'],
    case=3,
    entities=smallPayload,
    Case3LGDCountry='USA',
    Case3LGDInstrumentType="Senior Bond",
    IndustryClassification="NDY",
    Case3LGDasOfDate="2024-01-01",
    Case3LGDSecuredUnsecured="Unsecured",
    Case3LGDRecoveryCalculationMode="Ultimate Recovery",
    Case3LGDMaturityDate="2028-01-01",
    Case3LGDExposure=10000000,
    Case3LGDPDEndDate= "2023-01-01",
    Case3LGDhistoryFrequency='annual')

# ATTENTION:  THIS IS A DATACLASS
# HERE WE BUILD OUT the loan scoreard.  These are all class objects
my_loan_scorecard = loan_scorecard.LoanScorecard(
    loanScorecardId="2b77f0d7-b0e4-4dbc-844d-aabb4376a688",
    blanketLien=loan_scorecard.LoanScorecardParameterValues.NO,
    collateral=[
        loan_scorecard.Collateral(
            customCollateralId="123",
            loanId="123",
            collateralType=loan_scorecard.CollateralTypes.ACCOUNTS_RECEIVABLE,
            amount=10000,
            questionAnswers=[
                loan_scorecard.CollateralQuestionAnswer(name=loan_scorecard.CollateralQuestions.STANDARD_PAYMENT_TERMS,
                                        value=loan_scorecard.CollateralAnswers.NOT_AVAILABLE),
                loan_scorecard.CollateralQuestionAnswer(name=loan_scorecard.CollateralQuestions.CUSTOMER_CONCENTRATION,
                                        value=loan_scorecard.CollateralAnswers.HIGH),
                loan_scorecard.CollateralQuestionAnswer(name=loan_scorecard.CollateralQuestions.CUSTOMER_CREDIT_QUALITY,
                                        value=loan_scorecard.CollateralAnswers.EXCELLENT),
            ]
        )
    ],
)

# case 3 Methods
dicitonary3 = LGDinstantiation.LGDCase3datadictionary()
df = dicitonary3['cleaned_df']
# NOTICE We put the my_loan_scorecard class object as the paramter for user_defined_loan_scorecard
LGDFinal = LGDinstantiation.EDFXLGDFinal(df, use_loan_scorecard=True, user_defined_loan_scorecard=my_loan_scorecard)
LGDFinal
# Out:
# 2024-02-27 09:35:40.124 | INFO     | EDFXAuthentication:get_bearer_token:63 - Security token has been generated.
# C:\Users\martyb\OneDrive - moodys.com\Documents\Development\EDF_X_Development\EDFXAPI_OOP\EDFXLGD.py:562: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   EDFXDFSearchEndpoint["Private/Public"] = EDFXDFSearchEndpoint['isPublic'].apply(lambda x: 'Public' if x else 'Private')
# 2024-02-27 09:35:47.292 | INFO     | EDFXLGD:PDTermStructureCheck:412 - No NaN values found in the specified columns.
#                                            entityId  longRunLgd  \
# 0                  Northfield Mountain Holdings LLC    0.255777
# 1  TCW Direct Lending Structured Solutions 2019 LLC    0.516037
# 2                     Northern Courier Pipeline LTD    0.516037
# 3                      NET Health Acquisition Corp.    0.516037
# 4                                 Mcpf Holdings LLC    0.516037
#
#    longRunRecovery    tenor        pd  expectedLossAmount  \
# 0         0.744223  5.00274  0.067388        1.763454e+05
# 1         0.483963  5.00274  0.069271        3.804094e+05
# 2         0.483963  5.00274  0.271242        1.540927e+06
# 3         0.483963  5.00274  0.106101        5.855310e+05
# 4         0.483963  5.00274  0.114555        6.327953e+05
#
#    expectedLossPercent expectedLossRating  annualizedRecovery1Y  \
# 0             0.017635               Baa3              0.732528
# 1             0.038041                Ba2              0.425421
# 2             0.154093              Caa-C              0.409755
# 3             0.058553                 B1              0.423535
# 4             0.063280                 B1              0.423090
#
#    annualizedRecovery2Y  ...  cumulativePd1Y  cumulativePd2Y  cumulativePd3Y  \
# 0              0.736724  ...        0.011392        0.024630        0.038542
# 1              0.446424  ...        0.013650        0.027615        0.041572
# 2              0.436380  ...        0.126198        0.176936        0.214436
# 3              0.445215  ...        0.027195        0.049194        0.069308
# 4              0.444930  ...        0.030393        0.054185        0.075679
#
#    cumulativePd4Y  cumulativePd5Y  cumulativePd6Y  cumulativePd7Y  \
# 0        0.052836        0.067349        0.081640        0.095714
# 1        0.055456        0.069234        0.082807        0.096183
# 2        0.245023        0.271172        0.296416        0.320787
# 3        0.088165        0.106052        0.123590        0.140783
# 4        0.095663        0.114504        0.132955        0.151019
#
#    cumulativePd8Y  cumulativePd9Y  cumulativePd10Y
# 0        0.109573        0.123222         0.136658
# 1        0.109363        0.122348         0.135150
# 2        0.344311        0.367023         0.388949
# 3        0.157639        0.174166         0.190367
# 4        0.168707        0.186025         0.202987
#
# [5 rows x 81 columns]
