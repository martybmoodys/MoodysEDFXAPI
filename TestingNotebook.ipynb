# %%
import os
import sys
import pandas as pd
import numpy as np
import requests
import json
import matplotlib.pyplot as plt
import seaborn as sns
import time
import moodys_keys as mk
from EDFXAuthentication import EDFXClient
from EDFXPrime import EDFXEndpoints, OutputFormat, FinancialTemplate
public  = mk.EDF_X()['Client'],# EDFX public key
private = mk.EDF_X()['Client_Secret'], # EDFX private key.
# testing Endpoint class instantiation 
endpoints = EDFXEndpoints(public,private)
print(endpoints)
# Out:
# <EDFXPrime.EDFXEndpoints object at 0x00000226D52B11F0>

# %%
#  This is how this method works In [3]:  # testing client class Instantiation
public  = mk.EDF_X()['Client'],# EDFX public key
private = mk.EDF_X()['Client_Secret'], # EDFX private key.
#test instantiation
client = EDFXClient(public,private)
# print(client)
# print(public)
# print(private)

# %% [markdown]
# ## Test Headers

# %%
# this works. feel free to test.
endpoints.EDFXHeaders(process_id='processIdTest')['ModelInputsUploadProcess']['headers']
# Out:
# 2023-09-14 10:28:44,996 [INFO] Security token has been generated.
# 2023-09-14 10:28:44,996 [INFO] Security token has been generated.
# 2023-09-14 10:28:44,996 [INFO] Security token has been generated.
# 2023-09-14 10:28:44,996 [INFO] Security token has been generated.
# {'x-amz-tagging': 'edfx_process_id=processIdTest', 'content-type': 'text/csv'}

# %% [markdown]
# # Search Endpoints
#
# Within this package, just as the guide describes you feed the params.
# you have to at least provide a query. Example with all params,
#
# payload = {
#     "query": "Apple Inc",
#     "limit": 20,
#     "offset": 0
# }
#
# ### I PLACE DOCSTRING ON ALL MY METHODS SO CHECK THEM SO YOU KNOW THE PARAMS

# %%
#check2
response = endpoints.EDFXEntitySearchEndpoint("AAPL")
df = endpoints.EDFXSearchParse(response)
df
# Out:
# 2023-09-22 14:25:49,554 [INFO] Security token has been generated.
# 2023-09-22 14:25:49,554 [INFO] Security token has been generated.
# 2023-09-22 14:25:49,554 [INFO] Security token has been generated.
# 2023-09-22 14:25:49,554 [INFO] Security token has been generated.
#              entityId                         internationalName  \
# 0         US942404110                               APPLE, INC.
# 1        CALEI2287956                 Apple (AAPL) Yield Shares
# 2        USLEI2193308      Direxion Daily AAPL Bull 1.5X Shares
# 3        USLEI2147862   GraniteShares 1.75x Long AAPL Daily ETF
# 4        US133469770L                            Aapliance Care
# 5        USLEI2193126        Direxion Daily AAPL Bear 1X Shares
# 6        USLEI2239545  YieldMax AAPL Option Income Strategy ETF
# 7         FR834680399                                      Aapl
# 8        US375810203L                                  Aapl LLC
# 9        INA002415745                                Aapl Dukan
# 10       US368689301L                                  Aapl INC
# 11       US369922082L                   Aapl International, LLC
# 12      US112181067GN                    Aapl International LLC
# 13       US266512271L                           Aapl 75987, LLC
# 14        PL242869992                     Andrzej Luszczak Aapl
# 15  AU620693816-B0005                              Aapl Pty Ltd
# 16       US318351866L                        Aapl Logistics LLC
# 17        AU620693816                              Aapl Pty Ltd
# 18       INA001812396                 Aapl Consulting Engineers
# 19       US362179391L                      Aapl Management, LLC
#
#                  countryName                                     entityType  \
# 0   United States of America                                      Corporate
# 1                     Canada  Mutual and pension fund/Nominee/Trust/Trustee
# 2   United States of America  Mutual and pension fund/Nominee/Trust/Trustee
# 3   United States of America  Mutual and pension fund/Nominee/Trust/Trustee
# 4   United States of America                                      Corporate
# 5   United States of America  Mutual and pension fund/Nominee/Trust/Trustee
# 6   United States of America  Mutual and pension fund/Nominee/Trust/Trustee
# 7                     France                                      Corporate
# 8   United States of America                                      Corporate
# 9                      India                                      Corporate
# 10  United States of America                                      Corporate
# 11  United States of America                                      Corporate
# 12  United States of America                                      Corporate
# 13  United States of America                                      Corporate
# 14                    Poland                                      Corporate
# 15                 Australia                                      Corporate
# 16  United States of America                                      Corporate
# 17                 Australia                                      Corporate
# 18                     India                                      Corporate
# 19  United States of America                                      Corporate
#
#    primaryIndustryNACE primaryIndustryNAICS          contactCity  \
# 0                 2630               334220            Cupertino
# 1                                                        Toronto
# 2                                                     Wilmington
# 3                                                     Wilmington
# 4                                                          Vista
# 5                                                     Wilmington
# 6                                                     Wilmington
# 7                68.20               531190  Issy Les Moulineaux
# 8                                                       Wheeling
# 9                87.90               623990               Sangli
# 10                                                    Wilmington
# 11                                                         Lewes
# 12               82.99               561499          Chevy Chase
# 13               52.22               488390              Lakeway
# 14               33.14               811412             Katowice
# 15                                                  Notting Hill
# 16               49.39               485999                Doral
# 17                                                  Burwood East
# 18               71.11               541310            Ernakulam
# 19                                                      Glendale
#
#         entitySize latestPdModel          isin  ... entityIdentifierCortera  \
# 0   4 - Very Large         lna31  US0378331005  ...                     NaN
# 1        1 - Small         ben10           NaN  ...                     NaN
# 2        1 - Small                         NaN  ...                     NaN
# 3        1 - Small                         NaN  ...                     NaN
# 4        1 - Small                         NaN  ...               133469770
# 5        1 - Small                         NaN  ...                     NaN
# 6        1 - Small         ben10           NaN  ...                     NaN
# 7        1 - Small         ben10           NaN  ...                     NaN
# 8        1 - Small         ben10           NaN  ...                     NaN
# 9        1 - Small         ben10           NaN  ...                     NaN
# 10       1 - Small         ben10           NaN  ...                     NaN
# 11       1 - Small         ben10           NaN  ...                     NaN
# 12       1 - Small         ben10           NaN  ...                     NaN
# 13       1 - Small         ben10           NaN  ...                     NaN
# 14       1 - Small         ben10           NaN  ...                     NaN
# 15       1 - Small                         NaN  ...                     NaN
# 16       1 - Small         ben10           NaN  ...                     NaN
# 17       1 - Small         ben10           NaN  ...                     NaN
# 18       1 - Small         ben10           NaN  ...                     NaN
# 19       1 - Small         ben10           NaN  ...                     NaN
#
#    entityIdentifierEuropeanVatNumber entityIdentifierSirenNumber  \
# 0                                NaN                         NaN
# 1                                NaN                         NaN
# 2                                NaN                         NaN
# 3                                NaN                         NaN
# 4                                NaN                         NaN
# 5                                NaN                         NaN
# 6                                NaN                         NaN
# 7                     FR80 834680399                   834680399
# 8                                NaN                         NaN
# 9                                NaN                         NaN
# 10                               NaN                         NaN
# 11                               NaN                         NaN
# 12                               NaN                         NaN
# 13                               NaN                         NaN
# 14                      PL9541233418                         NaN
# 15                               NaN                         NaN
# 16                               NaN                         NaN
# 17                               NaN                         NaN
# 18                               NaN                         NaN
# 19                               NaN                         NaN
#
#    entityIdentifierTaxNumber entityIdentifierVatNumber  \
# 0                        NaN                       NaN
# 1                        NaN                       NaN
# 2                        NaN                       NaN
# 3                        NaN                       NaN
# 4                        NaN                       NaN
# 5                        NaN                       NaN
# 6                        NaN                       NaN
# 7                  834680399            FR80 834680399
# 8                        NaN                       NaN
# 9                        NaN                       NaN
# 10                       NaN                       NaN
# 11                       NaN                       NaN
# 12                       NaN                       NaN
# 13                       NaN                       NaN
# 14                9541233418                       NaN
# 15                       NaN                       NaN
# 16                81-1388575                       NaN
# 17                       NaN                       NaN
# 18                       NaN                       NaN
# 19                       NaN                       NaN
#
#    entityIdentifierSiretNumber entityIdentifierMadeUniqueId  \
# 0                          NaN                          NaN
# 1                          NaN                          NaN
# 2                          NaN                          NaN
# 3                          NaN                          NaN
# 4                          NaN                          NaN
# 5                          NaN                          NaN
# 6                          NaN                          NaN
# 7              834680399-00013                          NaN
# 8                          NaN                          NaN
# 9                          NaN                          NaN
# 10                         NaN                          NaN
# 11                         NaN                          NaN
# 12                         NaN                US112181067GN
# 13                         NaN                          NaN
# 14                         NaN                          NaN
# 15                         NaN                          NaN
# 16                         NaN                          NaN
# 17                         NaN                          NaN
# 18                         NaN                          NaN
# 19                         NaN                          NaN
#
#    entityIdentifierNip entityIdentifierRegonNumber entityIdentifierAcn
# 0                  NaN                         NaN                 NaN
# 1                  NaN                         NaN                 NaN
# 2                  NaN                         NaN                 NaN
# 3                  NaN                         NaN                 NaN
# 4                  NaN                         NaN                 NaN
# 5                  NaN                         NaN                 NaN
# 6                  NaN                         NaN                 NaN
# 7                  NaN                         NaN                 NaN
# 8                  NaN                         NaN                 NaN
# 9                  NaN                         NaN                 NaN
# 10                 NaN                         NaN                 NaN
# 11                 NaN                         NaN                 NaN
# 12                 NaN                         NaN                 NaN
# 13                 NaN                         NaN                 NaN
# 14          9541233418                   242869992                 NaN
# 15                 NaN                         NaN                 NaN
# 16                 NaN                         NaN                 NaN
# 17                 NaN                         NaN         620 693 816
# 18                 NaN                         NaN                 NaN
# 19                 NaN                         NaN                 NaN
#
# [20 rows x 27 columns]

# %% [markdown]
# # Batch Endpoints

# %%
##DOLLARDAY2023!
 # print(dir(endpoints))
query = [{ "entityIdentifierPartitaIva": 1959680388 }, { "entityIdentifierCodiceFiscale": 860340157 }, { "lei": "549300CRVT18MXX0AG93" }, { "cusip": 594918 }, { "isin": "US3453708600" }, { "entityInternationalName": "FORD MOTOR CO." }, { "pid": "34537A" }]
print("Query Object Example:")
print(query)
print("\n")
print("BATCHOUTPUT Below ")
# Send the query style object to batch call for your scripts
batch = endpoints.EDFXBatchEntitySearch(query)
print(batch)
df = endpoints.EDFXBatchParse(batch)
df
# Out:
# Query Object Example:
# [{'entityIdentifierPartitaIva': 1959680388}, {'entityIdentifierCodiceFiscale': 860340157}, {'lei': '549300CRVT18MXX0AG93'}, {'cusip': 594918}, {'isin': 'US3453708600'}, {'entityInternationalName': 'FORD MOTOR CO.'}, {'pid': '34537A'}]
#
#
# BATCHOUTPUT Below
# 2023-10-04 16:03:43.736 | INFO     | EDFXAuthentication:get_bearer_token:55 - Security token has been generated.
# {'entities': [{'entityId': 'GB01290444', 'pid': None, 'identifierOrbis': '004051381', 'identifierBvd': 'GB01290444', 'primaryIndustryNACE': '64.92', 'primaryIndustryNAICS': '522299', 'primaryIndustryNDY': 'N32', 'primaryIndustrySIC': '', 'primaryIndustryNDYDescription': 'LESSORS', 'type': 'Bank', 'entityType': 'Bank', 'internationalName': 'BP Capital Markets P.L.C.', 'contactAddressLine': '', 'contactCountryCode': 'GBR', 'contactPostalCode': 'TW16 7BP', 'contactStateProvince': '', 'contactCity': 'Sunbury-On-Thames', 'countryName': 'United Kingdom of Great Britain and Northern Ireland', 'entityInternationalName': 'BP Capital Markets P.L.C.', 'entityContactAddressLine': '', 'entityContactCountryCode': 'GBR', 'entityContactPostalCode': 'TW16 7BP', 'entityContactStateProvince': '', 'entityContactCity': 'Sunbury-On-Thames', 'entityCountryName': 'United Kingdom of Great Britain and Northern Ireland', 'entityOverviewDesc': "This company is engaged in the provision of financial services in the United Kingdom. The company has its registered office located in Sunbury-on-Thames, United Kingdom. It was incorporated in 1976.<br>The company primarily provides various financial intermediation services, such as short term business credit, depository credit intermediation, other forms of credit granting, miscellaneous intermediation, and other activities related to credit/financial intermediation. In addition, the company offers other service lines, such as sales financing, consumer lending, real estate credit, loan brokerage, mortgage banking, and other credit granting. In addition, the company employs a team of experts to help achieve its goals.<br>It is controlled by BP P.L.C., BP International Limited, and Kenilworth Oil Company Limited. BP P.L.C. (formerly known as BP Amoco P.L.C.) is one of the world's largest energy companies, providing its customers with fuel for transportation, energy for heat and light, retail services and petrochemicals products for everyday items. BP International Limited (formerly known as BP Trading Limited) is engaged internationally in oil, chemicals and other related financing activities.", 'entityStatus': '', 'size': '4 - Very Large', 'entitySize': '4 - Very Large', 'ticker': '', 'peerGroupId1': '1f33d9d9-57e3-43a6-8368-04c39be2535f', 'peerGroupId2': 'cedd7198-1b21-4c95-8a30-2bbb643462e6', 'peerGroupId3': '2942db6b-462d-4460-bd73-13e5561717d8', 'peerGroupId4': 'a820002c-fe30-4305-a208-1691596f4f77', 'peerGroupId5': 'ef5a16a8-20cd-4c15-9572-518f1da32931', 'globalParentIdentifier': 'GB00102498', 'globalParentName': 'BP PLC', 'domesticParentName': 'BP PLC', 'domesticParentIdentifier': 'GB00102498', 'headquartersIdentifier': '', 'headquartersName': '', 'replacementIdentifier': '', 'latestPdModel': 'bnk40', 'isBankFlag': 'true', 'rank': '', 'nationalId': [{'idName': 'lei', 'idValue': '549300CRVT18MXX0AG93'}, {'idName': 'entityIdentifierCompanyNumber', 'idValue': '01290444'}], 'hasFinancials': 'Has Full Financials', 'isPublic': False, 'isCustom': False, 'timestamp': 0, 'updated': 0, 'entityContactAddressLine1': 'Chertsey Road', 'entityContactAddressLine2': '', 'entityContactAddressLine3': '', 'entityContactAddressLine4': '', 'entityWebsite': '', 'entityLongtitude': '', 'entityLatitude': '', 'entityEmailAddress': '', 'entityTwitterLink': '', 'entityLinkedinLink': '', 'entityFacebookLink': '', 'entityPinterestLink': '', 'entityYoutubeLink': 'https://youtube.com/user/BPplc', 'entityFoursquareLink': '', 'entityIncorporationDate': '1976-12-14', 'tenantId': '', 'entityidentifierbvd': '', 'customEntityIdentifier': None}, {'entityId': 'US911144442', 'pid': '594918', 'identifierOrbis': '000507951', 'identifierBvd': 'US911144442', 'primaryIndustryNACE': '5829', 'primaryIndustryNAICS': '513210', 'primaryIndustryNDY': 'N12', 'primaryIndustrySIC': '7372', 'primaryIndustryNDYDescription': 'COMPUTER SOFTWARE', 'type': 'Corporate', 'entityType': 'Corporate', 'internationalName': 'MICROSOFT CORP.', 'contactAddressLine': '', 'contac ...
#       entityId     pid identifierOrbis identifierBvd primaryIndustryNACE  \
# 0   GB01290444    None       004051381    GB01290444               64.92
# 1  US911144442  594918       000507951   US911144442                5829
# 2  US380549190  34537A       058618674   US380549190                2920
#
#   primaryIndustryNAICS primaryIndustryNDY primaryIndustrySIC  \
# 0               522299                N32
# 1               513210                N12               7372
# 2               336110                N05               3711
#
#   primaryIndustryNDYDescription       type  ...  \
# 0                       LESSORS       Bank  ...
# 1             COMPUTER SOFTWARE  Corporate  ...
# 2                    AUTOMOTIVE  Corporate  ...
#
#   nationalId_entityIdentifierCompanyNumber nationalId_cusip  \
# 0                                 01290444              NaN
# 1                                      NaN           594918
# 2                                      NaN           345370
#
#       nationalId_figi nationalId_ticker nationalId_entityIdentifierCik  \
# 0                 NaN               NaN                            NaN
# 1  EQ0010174300001000              MSFT                     0000789019
# 2  EQ0010060200001000                 F                     0000037996
#
#   nationalId_entityIdentifierRssdId nationalId_entityIdentifierTaxNumber  \
# 0                               NaN                                  NaN
# 1                           1650121                           91-1144442
# 2                               NaN                           38-0549190
#
#   nationalId_isin nationalId_entityIdentifierEin nationalId_sedol
# 0             NaN                            NaN              NaN
# 1    US5949181045                     91-1144442          2588173
# 2    US3453708600                     38-0549190          2615468
#
# [3 rows x 79 columns]

# %%
# Static batch to .csv->Works on  local machine
csv = endpoints.EDFXBatchParse(batch, "Csv")
# Out:
# Data Saved to batchoutput.csv

# %%
# StaticBatch to .excel -> works on local machine
excel = endpoints.EDFXBatchParse(batch, 'excel')
# Out:
# Data saved to batchoutput.xlsx

# %% [markdown]
# # Client Financial Template xlsx to csv:
# - Bryan make this in October

# %% [markdown]
# # PD Endpoints:
# - 1 entity with no history
# - 1 entity with timeseries interval
# - multiple entities all with current term structure
# - multiple entities all with time series intervals
# - Parsing via static methods

# %%
# works
pd_single_check = endpoints.EDFXPD_Endpoint([{ "entityId": "AT9110116332" }], endDate='2023-05-19', historyFrequency="monthly")
pd_single_check

# %%
#Works
pd_singlehistory = endpoints.EDFXPD_Endpoint([{ "entityId": "AT9110116332" }], startDate = "2022-01-01", endDate = "2023-05-19")
single_pdParsehistory = endpoints.EDFXPDParse(pd_singlehistory,TimeSeries=True)
single_pdParsehistory.head()
# Out:
#        entityId    asOfDate        pd impliedRating                legalForm  \
# 0  AT9110116332  2023-05-01  0.002234          Baa1  LimitedLiabilityCompany
# 1  AT9110116332  2023-05-01  0.002234          Baa1  LimitedLiabilityCompany
# 2  AT9110116332  2023-05-01  0.002234          Baa1  LimitedLiabilityCompany
# 3  AT9110116332  2023-05-01  0.002234          Baa1  LimitedLiabilityCompany
# 4  AT9110116332  2023-05-01  0.002234          Baa1  LimitedLiabilityCompany
#
#   legalStatus legalStatusDate     confidence  \
# 0                        None  PF-X-R-FLAG_S
# 1                        None  PF-X-R-FLAG_S
# 2                        None  PF-X-R-FLAG_S
# 3                        None  PF-X-R-FLAG_S
# 4                        None  PF-X-R-FLAG_S
#
#                                confidenceDescription forward_forward1y  ...  \
# 0  Private firm, RiskCalc model with full financi...          0.002234  ...
# 1  Private firm, RiskCalc model with full financi...          0.002234  ...
# 2  Private firm, RiskCalc model with full financi...          0.002234  ...
# 3  Private firm, RiskCalc model with full financi...          0.002234  ...
# 4  Private firm, RiskCalc model with full financi...          0.002234  ...
#
#   history_impliedRating_impliedRating1y history_impliedRating_impliedRating2y  \
# 0                                  Baa1                                    A3
# 1                                    A3                                    A3
# 2                                  Baa1                                    A3
# 3                                  Baa1                                  Baa1
# 4                                  Baa1                                  Baa1
#
#   history_impliedRating_impliedRating3y history_impliedRating_impliedRating4y  \
# 0                                    A3                                    A3
# 1                                    A3                                    A3
# 2                                    A3                                    A3
# 3                                    A3                                    A3
# 4                                    A3                                    A3
#
#   history_impliedRating_impliedRating5y history_impliedRating_impliedRating6y  \
# 0                                    A3                                    A3
# 1                                    A3                                    A3
# 2                                    A3                                    A3
# 3                                    A3                                  Baa1
# 4                                    A3                                  Baa1
#
#   history_impliedRating_impliedRating7y history_impliedRating_impliedRating8y  \
# 0                                  Baa1                                  Baa1
# 1                                  Baa1                                  Baa1
# 2                                  Baa1                                  Baa1
# 3                                  Baa1                                  Baa1
# 4                                  Baa1                                  Baa1
#
#   history_impliedRating_impliedRating9y history_impliedRating_impliedRating10y
# 0                                  Baa1                                   Baa2
# 1                                  Baa1                                   Baa2
# 2                                  Baa1                                   Baa2
# 3                                  Baa1                                   Baa2
# 4                                  Baa1                                   Baa2
#
# [5 rows x 98 columns]

# %%
# Multiple PDs: Works
MultiplePDCheck = endpoints.EDFXPD_Endpoint( [{ "entityId": "DELEI421244" }, { "entityId": "US800890963" }, { "entityId": "FR813755949" }],startDate='2022-01-01', endDate='2023-05-19', historyFrequency="monthly")
# Parse: I need to Add the Time Series COmponent
widedf=endpoints.EDFXPDParse(MultiplePDCheck,FormatType='wide', TimeSeries=True)
widedf.head()
# Out:
#       entityId    asOfDate        pd impliedRating   legalForm legalStatus  \
# 0  DELEI421244  2023-05-01  0.010603           Ba1  Government      Active
# 1  FR813755949  2023-05-01  0.011675           Ba2  Government      Active
# 2  US800890963  2023-04-30  0.034359            B1         NaN         NaN
#
#       confidence                              confidenceDescription  \
# 0  PN-X-X-FLAG_T  Private firm benchmark model with no financial...
# 1  PN-X-X-FLAG_S  Private firm benchmark model with no financial...
# 2          P-G-R  Public firm, CreditEdge model. Based on recent...
#
#   forward_forward1y forward_forward2y  ... history_15_confidence  \
# 0          0.010603          0.010287  ...         PN-X-X-FLAG_T
# 1          0.011675          0.011641  ...         PN-X-X-FLAG_S
# 2          0.033807          0.045718  ...                 P-G-R
#
#                     history_15_confidenceDescription history_16_modelId  \
# 0  Private firm benchmark model with no financial...              hmark
# 1  Private firm benchmark model with no financial...              hmark
# 2  Public firm, CreditEdge model. Based on recent...                NaN
#
#   history_16_asOfDate history_16_pd history_16_impliedRating  \
# 0          2023-05-01      0.010603                      Ba1
# 1          2023-05-01      0.011675                      Ba2
# 2                 NaN           NaN                      NaN
#
#   history_16_legalForm history_16_legalStatus history_16_confidence  \
# 0           Government                 Active         PN-X-X-FLAG_T
# 1           Government                 Active         PN-X-X-FLAG_S
# 2                  NaN                    NaN                   NaN
#
#                     history_16_confidenceDescription
# 0  Private firm benchmark model with no financial...
# 1  Private firm benchmark model with no financial...
# 2                                                NaN
#
# [3 rows x 184 columns]

# %%
#Multiple PDs TimeSeries: Works
MultiplePDTimeSeriesCheck = endpoints.EDFXPD_Endpoint( [{ "entityId": "DELEI421244" }, { "entityId": "US800890963" }, { "entityId": "FR813755949" }], startDate = '2022-01-01',endDate='2023-05-19', historyFrequency="monthly")
MultiplePDTimeSeriesCheck
# Out:
# {'entities': [{'entityId': 'FR813755949',
#    'asOfDate': '2023-05-01',
#    'pd': 0.011675,
#    'impliedRating': 'Ba2',
#    'legalForm': 'Government',
#    'legalStatus': 'Active',
#    'confidence': 'PN-X-X-FLAG_S',
#    'confidenceDescription': 'Private firm benchmark model with no financials. Entity sector was not included in the model development sample.',
#    'termStructure': {'forward': {'forward1y': '0.011675',
#      'forward2y': '0.011641',
#      'forward3y': '0.011625',
#      'forward4y': '0.011618',
#      'forward5y': '0.01161',
#      'forward6y': '0.01161',
#      'forward7y': '0.01161',
#      'forward8y': '0.01161',
#      'forward9y': '0.01161',
#      'forward10y': '0.01161'},
#     'annualized': {'annualized1y': '0.011675',
#      'annualized2y': '0.011658',
#      'annualized3y': '0.011647',
#      'annualized4y': '0.01164',
#      'annualized5y': '0.011634',
#      'annualized6y': '0.01163',
#      'annualized7y': '0.011627',
#      'annualized8y': '0.011625',
#      'annualized9y': '0.011624',
#      'annualized10y': '0.011622'},
#     'cumulative': {'cumulative1y': '0.011675',
#      'cumulative2y': '0.02318',
#      'cumulative3y': '0.034536',
#      'cumulative4y': '0.045753',
#      'cumulative5y': '0.056832',
#      'cumulative6y': '0.067782',
#      'cumulative7y': '0.078604',
#      'cumulative8y': '0.089303',
#      'cumulative9y': '0.099881',
#      'cumulative10y': '0.110326'},
#     'impliedRating': {'impliedRating1y': 'Ba2',
#      'impliedRating2y': 'Ba2',
#      'impliedRating3y': 'Ba1',
#      'impliedRating4y': 'Ba1',
#      'impliedRating5y': 'Ba1',
#      'impliedRating6y': 'Ba2',
#      'impliedRating7y': 'Ba3',
#      'impliedRating8y': 'Ba3',
#      'impliedRating9y': 'B1',
#      'impliedRating10y': 'B1'}},
#    'history': [{'modelId': 'hmark',
#      'asOfDate': '2022-01-01',
#      'pd': 0.007887,
#      'impliedRating': 'Ba1',
#      'legalForm': 'Government',
#      'legalStatus': '',
#      'confidence': 'PN-X-X',
#      'confidenceDescription': 'Private firm benchmark model with no financials available.',
#      'termStructure': {'forward': {'forward1y': '0.007887',
#        'forward2y': '0.009766',
#        'forward3y': '0.010629',
#        'forward4y': '0.011231',
#        'forward5y': '0.011703',
#        'forward6y': '0.011703',
#        'forward7y': '0.011703',
#        'forward8y': '0.011703',
#        'forward9y': '0.011703',
#        'forward10y': '0.011703'},
#       'annualized': {'annualized1y': '0.007887',
#        'annualized2y': '0.008827',
#        'annualized3y': '0.009428',
#        'annualized4y': '0.009879',
#        'annualized5y': '0.010244',
#        'annualized6y': '0.010487',
#        'annualized7y': '0.010661',
#        'annualized8y': '0.010791',
#        'annualized9y': '0.010892',
#        'annualized10y': '0.010973'},
#       'cumulative': {'cumulative1y': '0.007887',
#        'cumulative2y': '0.017576',
#        'cumulative3y': '0.028018',
#        'cumulative4y': '0.038934',
#        'cumulative5y': '0.050181',
#        'cumulative6y': '0.061295',
#        'cumulative7y': '0.072282',
#        'cumulative8y': '0.083137',
#        'cumulative9y': '0.093864',
#        'cumulative10y': '0.104467'},
#       'impliedRating': {'impliedRating1y': 'Ba1',
#        'impliedRating2y': 'Ba1',
#        'impliedRating3y': 'Ba1',
#        'impliedRating4y': 'Ba1',
#        'impliedRating5y': 'Ba1',
#        'impliedRating6y': 'Ba2',
#        'impliedRating7y': 'Ba2',
#        'impliedRating8y': 'Ba3',
#        'impliedRating9y': 'Ba3',
#        'impliedRating10y': 'B1'}}},
#     {'modelId': 'hmark',
#      'asOfDate': '2022-02-01',
#      'pd': 0.007938,
#      'impliedRating': 'Ba1',
#      'legalForm': 'Government',
#      'legalStatus': '',
#      'confidence': 'PN-X-X',
#      'confidenceDescription': 'Private firm benchmark model with no financials available.',
#      'termStructure': {'forward': {'forward1y': '0.007938',
#        'forward2y': '0.009797',
#        'forward3y': '0.010646',
#        'forward4y': '0.01124',
#        'forward5y': '0.0117',
#        'forward6y': '0.0117',
#        'forward7y': '0.0117',
#        'forward8y': '0.0117',
#        'forward9y': '0.0117',
#        'forward10y': '0.0117'},
#       'annualized': {'annualized1y': '0.007938',
#        'annualized2y': '0.008868',
#        'annualized3y': '0.009461',
#        'annualized4y': '0.009906',
#        'annualized5y': '0.010265',
#        'annualized6y': '0.010505',
#        'annualized7y': '0.010676',
#        'annualized8y': '0.010804',
#        'annualized9y': '0.010904',
#        'annualized10y': '0.010984'},
#       'cumulative': {'cumulative1y': '0.007938',
#        'cumulative2y': '0.017657',
#        'cumulative3y': '0.028115',
#        'cumulative4y': '0.039039',
#        'cumulative5y': '0.050282',
#        'cumulative6y': '0.061398',
#        'cumulative7y': '0.072381',
#        'cumulative8y': '0.083233',
#        'cumulative9y': '0.093963',
#        'cumulative10y': '0.104567'},
#       'impliedRating': {'impliedRating1y': 'Ba1',
#        'impliedRating2y': 'Ba1',
#        'impliedRating3y': 'Ba1',
#        'impliedRating4y': 'Ba1',
#        'impliedRating5y': 'Ba1',
#        'impliedRating6y': 'Ba2',
#        'impliedRating7y': 'Ba2',
#        'impliedRating8y': 'Ba3',
#        'impliedRating9y': 'Ba3',
#        'impliedRating10y': 'B1'}}},
#     {'modelId': 'hmark',
#      'asOfDate': '2022-03-01',
#      'pd': 0.008039,
#      'impliedRating': 'Ba1',
#      'legalForm': 'Government',
#      'legalStatus': '',
#      'confidence': 'PN-X-X',
#      'confidenceDescription': 'Private firm benchmark model with no financials available.',
#      'termStructure': {'forward': {'forward1y': '0.008039',
#        'forward2y': '0.009854',
#        'forward3y': '0.01068',
#        'forward4y': '0.011256',
#        'forward5y': '0.011697',
#        'forward6y': '0.011697',
#        'forward7y': '0.011697',
#        'forward8y': '0.011697',
#        'forward9y': '0.011697',
#        'forward10y': '0.011697'},
#       'annualized': {'annualized1y': '0.008039',
#        'annualized2y': '0.008947',
#        'annualized3y': '0.009525',
#        'annualized4y': '0.009958',
#        'annualized5y': '0.010306',
#        'annualized6y': '0.010539',
#        'annualized7y': '0.010705',
#        'annualized8y': '0.01083',
#        'annualized9y': '0.010926',
#        'annualized10y': '0.011004'},
#       'cumulative': {'cumulative1y': '0.008039',
#        'cumulative2y': '0.017814',
#        'cumulative3y': '0.028304',
#        'cumulative4y': '0.039241',
#        'cumulative5y': '0.050479',
#        'cumulative6y': '0.061591',
#        'cumulative7y': '0.072571',
#        'cumulative8y': '0.083426',
#        'cumulative9y': '0.094144',
#        'cumulative10y': '0.104748'},
#       'impliedRating': {'impliedRating1y': 'Ba1',
#        'impliedRating2y': 'Ba1',
#        'impliedRating3y': 'Ba1',
#        'impliedRating4y': 'Ba1',
#        'impliedRating5y': 'Ba1',
#        'impliedRating6y': 'Ba2',
#        'impliedRating7y': 'Ba2',
#        'impliedRating8y': 'Ba3',
#        'impliedRating9y': 'Ba3',
#        'impliedRating10y': 'B1'}}},
#     {'modelId': 'hmark',
#      'asOfDate': '2022-04-01',
#      'pd': 0.009106,
#      'impliedRating': 'Ba1',
#      'legalForm': 'Government',
#      'legalStatus': '',
#      'confidence': 'PN-X-X',
#      'confidenceDescription': 'Private firm benchmark model with no financials available.',
#      'termStructure': {'forward': {'forward1y': '0.009106',
#        'forward2y': '0.010438',
#        'forward3y': '0.011004',
#        'forward4y': '0.011395',
#        'forward5y': '0.011691',
#        'forward6y': '0.011691',
#        'forward7y': '0.011691',
#        'forward8y': '0.011691',
#        'forward9y': '0.011691',
#        'forward10y': '0.011691'},
#       'annualized': {'annualized1y': '0.009106',
#        'annualized2y': '0.009772',
#        'annualized3y': '0.010183',
#        'annualized4y': '0.010486',
#        'annualized5y': '0.010727',
#        'annualized6y': '0.010887',
#        'annualized7y': '0.011002',
#        'annualized8y': '0.011088',
#        'annualized9y': '0.011155',
#        'annualized10y': '0.011208'},
#       'cumulative': {'cumulative1y': '0.009106',
#        'cumulative2y': '0.019449',
#        'cumulative3y': '0.030239',
#        'cumulative4y': '0.041289',
#        'cumulative5y': '0.052497',
#        'cumulative6y': '0.06357',
#        'cumulative7y': '0.074518',
#        'cumulative8y': '0.085337',
#        'cumulative9y': '0.09603',
#        'cumulative10y': '0.106593'},
#       'impliedRating': {'impliedRating1y': 'Ba1',
#        'impliedRating2y': 'Ba1',
#        'impliedRating3y': 'Ba1',
#        'impliedRating4y': 'Ba1',
#        'impliedRating5y': 'Ba1',
#        'impliedRating6y': 'Ba2',
#        'impliedRating7y': 'Ba2',
#        'impliedRating8y': 'Ba3',
#        'impliedRating9y': 'Ba3',
#        'impliedRating10y': 'B1'}}},
#     {'modelId': 'hmark',
#      'asOfDate': '2022-05-01',
#      'pd': 0.009457,
#      'impliedRating': 'Ba1',
#      'legalForm': 'Government',
#      'legalStatus': '',
#      'confidence': 'PN-X-X',
#      'confidenceDescription': 'Private firm benchmark model with no financials available.',
#      'termStructure': {'forward': {'forward1y': '0.009457',
#        'forward2y': '0.010616',
#        'forward3y': '0.011105',
#        'forward4y': '0.011433',
#        'forward5y': '0.011683',
#        'forward6y': '0.011683',
#        'forward7y': '0.011683',
#        'forward8y': '0.011683',
#        'forward9y': '0.011683',
#        'forward10y': '0.011683'},
#       'annualized': {'annualized1y': '0.009457',
#        'annualized2y': '0.010037',
#        'annualized3y': '0.010393',
#        'annualized4y': '0.010653',
#        'annualized5y': '0.010859',
#        'annualized6y': '0.010997',
#        'annualized7y': '0.011095',
#        'annualized8y': '0.011169',
#        'annualized9y': '0.011226',
#        'annualized10y': '0.011272'},
#       'cumulative': {'cumulative1y': '0.009457',
#        'cumulative2y': '0.019973',
#        'cumulative3y': '0.030856',
#        'cumulative4y': '0.041936',
#        'cumulative5y': '0.053129',
#        'cumulative6y': '0.064194',
#        'cumulative7y': '0.075127',
#        'cumulative8y': '0.085936',
#        'cumulative9y': '0.096614',
#        'cumulative10y': '0.107171'},
#       'impliedRating': {'impliedRating1y': 'Ba1',
#        'impliedRating2y': 'Ba1',
#        'impliedRating3y': 'Ba1',
#        'impliedRating4y': 'Ba1',
#        'impliedRating5y': 'Ba1',
#        'impliedRating6y': 'Ba2',
#        'impliedRating7y': 'Ba2',
#        'impliedRating8y': 'Ba3',
#        'impliedRating9y': 'Ba3',
#        'impliedRating10y': 'B1'}}},
#     {'modelId': 'hmark',
#      'asOfDate': '2022-06-01',
#      'pd': 0.009456,
#      'impliedRating': 'Ba1',
#      'legalForm': 'Government',
#      'legalStatus': '',
#      'confidence': 'PN-X-X',
#      'confidenceDescription': 'Private firm benchmark model with no financials available.',
#      'termStructure': {'forward': {'forward1y': '0.009456',
#        'forward2y': '0.010617',
#        'forward3y': '0.011105',
#        'forward4y': '0.011433',
#        'forward5y': '0.011683',
#        'forward6y': '0.011683',
#        'forward7y': '0.011683',
#        'forward8y': '0.011683',
#        'forward9y': '0.011683',
#        'forward10y': '0.011683'},
#       'annualized': {'annualized1y': '0.009456',
#        'annualized2y': '0.010037',
#        'annualized3y': '0.010393',
#        'annualized4y': '0.010653',
#        'annualized5y': '0.010859',
#        'annualized6y': '0.010997',
#        'annualized7y': '0.011095',
#        'annualized8y': '0.011169',
#        'annualized9y': '0.011226',
#        'annualized10y': '0.011272'},
#       'cumulative': {'cumulative1y': '0.009456',
#        'cumulative2y': '0.019973',
#        'cumulative3y': '0.030856',
#        'cumulative4y': '0.041936',
#        'cumulative5y': '0.053129',
#        'cumulative6y': '0.064194',
#        'cumulative7y': '0.075127',
#        'cumulative8y': '0.085936',
#        'cumulative9y': '0.096614',
#        'cumulative10y': '0.107171'},
#       'impliedRating': {'impliedRating1y': 'Ba1',
#        'impliedRating2y': 'Ba1',
#        'impliedRating3y': 'Ba1',
#        'impliedRating4y': 'Ba1',
#        'impliedRating5y': 'Ba1',
#        'impliedRating6y': 'Ba2',
#        'impliedRating7y': 'Ba2',
#        'impliedRating8y': 'Ba3',
#        'impliedRating9y': 'Ba3',
#        'impliedRating10y': 'B1'}}},
#     {'modelId': 'hmark',
#      'asOfDate': '2022-07-01',
#      'pd': 0.010951,
#      'impliedRating': 'Ba1',
#      'legalForm': 'Government',
#      'legalStatus': '',
#      'confidence': 'PN-X-X',
#      'confidenceDescription': 'Private firm benchmark model with no financials available.',
#      'termStructure': {'forward': {'forward1y': '0.010951',
#        'forward2y': '0.011323',
#        'forward3y': '0.01147',
#        'forward4y': '0.011564',
#        'forward5y': '0.011637',
#        'forward6y': '0.011637',
#        'forward7y': '0.011637',
#        'forward8y': '0.011637',
#        'forward9y': '0.011637',
#        'forward10y': '0.011637'},
#       'annualized': {'annualized1y': '0.010951',
#        'annualized2y': '0.011137',
#        'annualized3y': '0.011248',
#        'annualized4y': '0.011327',
#        'annualized5y': '0.011389',
#        'annualized6y': '0.01143',
#        'annualized7y': '0.01146',
#        'annualized8y': '0.011482',
#        'annualized9y': '0.011499',
#        'annualized10y': '0.011513'},
#       'cumulative': {'cumulative1y': '0.010951',
#        'cumulative2y': '0.02215',
#        'cumulative3y': '0.033366',
#        'cumulative4y': '0.044544',
#        'cumulative5y': '0.055663',
#        'cumulative6y': '0.06665',
#        'cumulative7y': '0.077514',
#        'cumulative8y': '0.088248',
#        'cumulative9y': '0.098856',
#        'cumulative10y': '0.109345'},
#       'impliedRating': {'impliedRating1y': 'Ba1',
#        'impliedRating2y': 'Ba1',
#        'impliedRating3y': 'Ba1',
#        'impliedRating4y': 'Ba1',
#        'impliedRating5y': 'Ba1',
#        'impliedRating6y': 'Ba2',
#        'impliedRating7y': 'Ba3',
#        'impliedRating8y': 'Ba3',
#        'impliedRating9y': 'Ba3',
#        'impliedRating10y': 'B1'}}},
#     {'modelId': 'hmark',
#      'asOfDate': '2022-08-01',
#      'pd': 0.010799,
#      'impliedRating': 'Ba1',
#      'legalForm': 'Government',
#      'legalStatus': 'Active',
#      'confidence': 'PN-X-X',
#      'confidenceDescription': 'Private firm benchmark model with no financials available.',
#      'termStructure': {'forward': {'forward1y': '0.010799',
#        'forward2y': '0.011255',
#        'forward3y': '0.011436',
#        'forward4y': '0.011551',
#        'forward5y': '0.011639',
#        'forward6y': '0.011639',
#        'forward7y': '0.011639',
#        'forward8y': '0.011639',
#        'forward9y': '0.011639',
#        'forward10y': '0.011639'},
#       'annualized': {'annualized1y': '0.010799',
#        'annualized2y': '0.011027',
#        'annualized3y': '0.011163',
#        'annualized4y': '0.01126',
#        'annualized5y': '0.011336',
#        'annualized6y': '0.011387',
#        'annualized7y': '0.011423',
#        'annualized8y': '0.01145',
#        'annualized9y': '0.011471',
#        'annualized10y': '0.011488'},
#       'cumulative': {'cumulative1y': '0.010799',
#        'cumulative2y': '0.021932',
#        'cumulative3y': '0.033117',
#        'cumulative4y': '0.044285',
#        'cumulative5y': '0.055409',
#        'cumulative6y': '0.066406',
#        'cumulative7y': '0.077272',
#        'cumulative8y': '0.088012',
#        'cumulative9y': '0.098627',
#        'cumulative10y': '0.109119'},
#       'impliedRating': {'impliedRating1y': 'Ba1',
#        'impliedRating2y': 'Ba1',
#        'impliedRating3y': 'Ba1',
#        'impliedRating4y': 'Ba1',
#        'impliedRating5y': 'Ba1',
#        'impliedRating6y': 'Ba2',
#        'impliedRating7y': 'Ba3',
#        'impliedRating8y': 'Ba3',
#        'impliedRating9y': 'Ba3',
#        'impliedRating10y': 'B1'}}},
#     {'modelId': 'hmark',
#      'asOfDate': '2022-09-01',
#      'pd': 0.010897,
#      'impliedRating': 'Ba1',
#      'legalForm': 'Government',
#      'legalStatus': 'Active',
#      'confidence': 'PN-X-X',
#      'confidenceDescription': 'Private firm benchmark model with no financials available.',
#      'termStructure': {'forward': {'forward1y': '0.010897',
#        'forward2y': '0.011301',
#        'forward3y': '0.011456',
#        'forward4y': '0.011562',
#        'forward5y': '0.011639',
#        'forward6y': '0.011639',
#        'forward7y': '0.011639',
#        'forward8y': '0.011639',
#        'forward9y': '0.011639',
#        'forward10y': '0.011639'},
#       'annualized': {'annualized1y': '0.010897',
#        'annualized2y': '0.011099',
#        'annualized3y': '0.011218',
#        'annualized4y': '0.011304',
#        'annualized5y': '0.011371',
#        'annualized6y': '0.011415',
#        'annualized7y': '0.011447',
#        'annualized8y': '0.011471',
#        'annualized9y': '0.011489',
#        'annualized10y': '0.011504'},
#       'cumulative': {'cumulative1y': '0.010897',
#        'cumulative2y': '0.022075',
#        'cumulative3y': '0.033278',
#        'cumulative4y': '0.044455',
#        'cumulative5y': '0.055577',
#        'cumulative6y': '0.066565',
#        'cumulative7y': '0.077429',
#        'cumulative8y': '0.088167',
#        'cumulative9y': '0.098774',
#        'cumulative10y': '0.109264'},
#       'impliedRating': {'impliedRating1y': 'Ba1',
#        'impliedRating2y': 'Ba1',
#        'impliedRating3y': 'Ba1',
#        'impliedRating4y': 'Ba1',
#        'impliedRating5y': 'Ba1',
#        'impliedRating6y': 'Ba2',
#        'impliedRating7y': 'Ba3',
#        'impliedRating8y': 'Ba3',
#        'impliedRating9y': 'Ba3',
#        'impliedRating10y': 'B1'}}},
#     {'modelId': 'hmark',
#      'asOfDate': '2022-10-01',
#      'pd': 0.01211,
#      'impliedRating': 'Ba2',
#      'legalForm': 'Government',
#      'legalStatus': 'Active',
#      'confidence': 'PN-X-X',
#      'confidenceDescription': 'Private firm benchmark model with no financials available.',
#      'termStructure': {'forward': {'forward1y': '0.01211',
#        'forward2y': '0.011818',
#        'forward3y': '0.011712',
#        'forward4y': '0.01164',
#        'forward5y': '0.01159',
#        'forward6y': '0.01159',
#        'forward7y': '0.01159',
#        'forward8y': '0.01159',
#        'forward9y': '0.01159',
#        'forward10y': '0.01159'},
#       'annualized': {'annualized1y': '0.01211',
#        'annualized2y': '0.011964',
#        'annualized3y': '0.01188',
#        'annualized4y': '0.01182',
#        'annualized5y': '0.011774',
#        'annualized6y': '0.011743',
#        'annualized7y': '0.011721',
#        'annualized8y': '0.011705',
#        'annualized9y': '0.011692',
#        'annualized10y': '0.011682'},
#       'cumulative': {'cumulative1y': '0.01211',
#        'cumulative2y': '0.023785',
#        'cumulative3y': '0.035218',
#        'cumulative4y': '0.046448',
#        'cumulative5y': '0.0575',
#        'cumulative6y': '0.068422',
#        'cumulative7y': '0.079218',
#        'cumulative8y': '0.089892',
#        'cumulative9y': '0.100439',
#        'cumulative10y': '0.110866'},
#       'impliedRating': {'impliedRating1y': 'Ba2',
#        'impliedRating2y': 'Ba2',
#        'impliedRating3y': 'Ba2',
#        'impliedRating4y': 'Ba1',
#        'impliedRating5y': 'Ba1',
#        'impliedRating6y': 'Ba2',
#        'impliedRating7y': 'Ba3',
#        'impliedRating8y': 'Ba3',
#        'impliedRating9y': 'B1',
#        'impliedRating10y': 'B1'}}},
#     {'modelId': 'hmark',
#      'asOfDate': '2022-11-01',
#      'pd': 0.01341,
#      'impliedRating': 'Ba2',
#      'legalForm': 'Government',
#      'legalStatus': 'Active',
#      'confidence': 'PN-X-X',
#      'confidenceDescription': 'Private firm benchmark model with no financials available.',
#      'termStructure': {'forward': {'forward1y': '0.01341',
#        'forward2y': '0.012318',
#        'forward3y': '0.011936',
#        'forward4y': '0.011695',
#        'forward5y': '0.011515',
#        'forward6y': '0.011515',
#        'forward7y': '0.011515',
#        'forward8y': '0.011515',
#        'forward9y': '0.011515',
#        'forward10y': '0.011515'},
#       'annualized': {'annualized1y': '0.01341',
#        'annualized2y': '0.012864',
#        'annualized3y': '0.012555',
#        'annualized4y': '0.01234',
#        'annualized5y': '0.012175',
#        'annualized6y': '0.012066',
#        'annualized7y': '0.011988',
#        'annualized8y': '0.011929',
#        'annualized9y': '0.011883',
#        'annualized10y': '0.011847'},
#       'cumulative': {'cumulative1y': '0.01341',
#        'cumulative2y': '0.025563',
#        'cumulative3y': '0.037194',
#        'cumulative4y': '0.048454',
#        'cumulative5y': '0.059411',
#        'cumulative6y': '0.070247',
#        'cumulative7y': '0.080958',
#        'cumulative8y': '0.091541',
#        'cumulative9y': '0.102002',
#        'cumulative10y': '0.11235'},
#       'impliedRating': {'impliedRating1y': 'Ba2',
#        'impliedRating2y': 'Ba2',
#        'impliedRating3y': 'Ba2',
#        'impliedRating4y': 'Ba2',
#        'impliedRating5y': 'Ba2',
#        'impliedRating6y': 'Ba2',
#        'impliedRating7y': 'Ba3',
#        'impliedRating8y': 'Ba3',
#        'impliedRating9y': 'B1',
#        'impliedRating10y': 'B1'}}},
#     {'modelId': 'hmark',
#      'asOfDate': '2022-12-01',
#      'pd': 0.013753,
#      'impliedRating': 'Ba2',
#      'legalForm': 'Government',
#      'legalStatus': 'Active',
#      'confidence': 'PN-X-X',
#      'confidenceDescription': 'Private firm benchmark model with no financials available.',
#      'termStructure': {'forward': {'forward1y': '0.013753',
#        'forward2y': '0.012444',
#        'forward3y': '0.011995',
#        'forward4y': '0.011711',
#        'forward5y': '0.011506',
#        'forward6y': '0.011506',
#        'forward7y': '0.011506',
#        'forward8y': '0.011506',
#        'forward9y': '0.011506',
#        'forward10y': '0.011506'},
#       'annualized': {'annualized1y': '0.013753',
#        'annualized2y': '0.013099',
#        'annualized3y': '0.012731',
#        'annualized4y': '0.012476',
#        'annualized5y': '0.012282',
#        'annualized6y': '0.012152',
#        'annualized7y': '0.012059',
#        'annualized8y': '0.01199',
#        'annualized9y': '0.011936',
#        'annualized10y': '0.011893'},
#       'cumulative': {'cumulative1y': '0.013753',
#        'cumulative2y': '0.026026',
#        'cumulative3y': '0.037709',
#        'cumulative4y': '0.048978',
#        'cumulative5y': '0.05992',
#        'cumulative6y': '0.070732',
#        'cumulative7y': '0.08142',
#        'cumulative8y': '0.09199',
#        'cumulative9y': '0.102435',
#        'cumulative10y': '0.112763'},
#       'impliedRating': {'impliedRating1y': 'Ba2',
#        'impliedRating2y': 'Ba2',
#        'impliedRating3y': 'Ba2',
#        'impliedRating4y': 'Ba2',
#        'impliedRating5y': 'Ba2',
#        'impliedRating6y': 'Ba2',
#        'impliedRating7y': 'Ba3',
#        'impliedRating8y': 'Ba3',
#        'impliedRating9y': 'B1',
#        'impliedRating10y': 'B1'}}},
#     {'modelId': 'hmark',
#      'asOfDate': '2023-01-01',
#      'pd': 0.013038,
#      'impliedRating': 'Ba2',
#      'legalForm': 'Government',
#      'legalStatus': 'Active',
#      'confidence': 'PN-X-X',
#      'confidenceDescription': 'Private firm benchmark model with no financials available.',
#      'termStructure': {'forward': {'forward1y': '0.013038',
#        'forward2y': '0.01218',
#        'forward3y': '0.011877',
#        'forward4y': '0.011681',
#        'forward5y': '0.011544',
#        'forward6y': '0.011544',
#        'forward7y': '0.011544',
#        'forward8y': '0.011544',
#        'forward9y': '0.011544',
#        'forward10y': '0.011544'},
#       'annualized': {'annualized1y': '0.013038',
#        'annualized2y': '0.012609',
#        'annualized3y': '0.012365',
#        'annualized4y': '0.012194',
#        'annualized5y': '0.012064',
#        'annualized6y': '0.011976',
#        'annualized7y': '0.011914',
#        'annualized8y': '0.011868',
#        'annualized9y': '0.011831',
#        'annualized10y': '0.011802'},
#       'cumulative': {'cumulative1y': '0.013038',
#        'cumulative2y': '0.025059',
#        'cumulative3y': '0.036638',
#        'cumulative4y': '0.047891',
#        'cumulative5y': '0.058882',
#        'cumulative6y': '0.069739',
#        'cumulative7y': '0.080476',
#        'cumulative8y': '0.091092',
#        'cumulative9y': '0.101577',
#        'cumulative10y': '0.111945'},
#       'impliedRating': {'impliedRating1y': 'Ba2',
#        'impliedRating2y': 'Ba2',
#        'impliedRating3y': 'Ba2',
#        'impliedRating4y': 'Ba2',
#        'impliedRating5y': 'Ba1',
#        'impliedRating6y': 'Ba2',
#        'impliedRating7y': 'Ba3',
#        'impliedRating8y': 'Ba3',
#        'impliedRating9y': 'B1',
#        'impliedRating10y': 'B1'}}},
#     {'modelId': 'hmark',
#      'asOfDate': '2023-02-01',
#      'pd': 0.011766,
#      'impliedRating': 'Ba2',
#      'legalForm': 'Government',
#      'legalStatus': 'Active',
#      'confidence': 'PN-X-X',
#      'confidenceDescription': 'Private firm benchmark model with no financials available.',
#      'termStructure': {'forward': {'forward1y': '0.011766',
#        'forward2y': '0.011678',
#        'forward3y': '0.011643',
#        'forward4y': '0.011624',
#        'forward5y': '0.011604',
#        'forward6y': '0.011604',
#        'forward7y': '0.011604',
#        'forward8y': '0.011604',
#        'forward9y': '0.011604',
#        'forward10y': '0.011604'},
#       'annualized': {'annualized1y': '0.011766',
#        'annualized2y': '0.011722',
#        'annualized3y': '0.011696',
#        'annualized4y': '0.011678',
#        'annualized5y': '0.011663',
#        'annualized6y': '0.011654',
#        'annualized7y': '0.011647',
#        'annualized8y': '0.011642',
#        'annualized9y': '0.011638',
#        'annualized10y': '0.011635'},
#       'cumulative': {'cumulative1y': '0.011766',
#        'cumulative2y': '0.023307',
#        'cumulative3y': '0.034679',
#        'cumulative4y': '0.0459',
#        'cumulative5y': '0.056971',
#        'cumulative6y': '0.067918',
#        'cumulative7y': '0.078735',
#        'cumulative8y': '0.089428',
#        'cumulative9y': '0.099996',
#        'cumulative10y': '0.110443'},
#       'impliedRating': {'impliedRating1y': 'Ba2',
#        'impliedRating2y': 'Ba2',
#        'impliedRating3y': 'Ba1',
#        'impliedRating4y': 'Ba1',
#        'impliedRating5y': 'Ba1',
#        'impliedRating6y': 'Ba2',
#        'impliedRating7y': 'Ba3',
#        'impliedRating8y': 'Ba3',
#        'impliedRating9y': 'B1',
#        'impliedRating10y': 'B1'}}},
#     {'modelId': 'hmark',
#      'asOfDate': '2023-03-01',
#      'pd': 0.012307,
#      'impliedRating': 'Ba2',
#      'legalForm': 'Government',
#      'legalStatus': 'Active',
#      'confidence': 'PN-X-X-FLAG_S',
#      'confidenceDescription': 'Private firm benchmark model with no financials. Entity sector was not included in the model development sample.',
#      'termStructure': {'forward': {'forward1y': '0.012307',
#        'forward2y': '0.011897',
#        'forward3y': '0.011745',
#        'forward4y': '0.011651',
#        'forward5y': '0.01158',
#        'forward6y': '0.01158',
#        'forward7y': '0.01158',
#        'forward8y': '0.01158',
#        'forward9y': '0.01158',
#        'forward10y': '0.01158'},
#       'annualized': {'annualized1y': '0.012307',
#        'annualized2y': '0.012102',
#        'annualized3y': '0.011983',
#        'annualized4y': '0.0119',
#        'annualized5y': '0.011836',
#        'annualized6y': '0.011793',
#        'annualized7y': '0.011762',
#        'annualized8y': '0.011739',
#        'annualized9y': '0.011721',
#        'annualized10y': '0.011707'},
#       'cumulative': {'cumulative1y': '0.012307',
#        'cumulative2y': '0.024058',
#        'cumulative3y': '0.03552',
#        'cumulative4y': '0.046757',
#        'cumulative5y': '0.057796',
#        'cumulative6y': '0.068704',
#        'cumulative7y': '0.079485',
#        'cumulative8y': '0.090143',
#        'cumulative9y': '0.100676',
#        'cumulative10y': '0.111091'},
#       'impliedRating': {'impliedRating1y': 'Ba2',
#        'impliedRating2y': 'Ba2',
#        'impliedRating3y': 'Ba2',
#        'impliedRating4y': 'Ba1',
#        'impliedRating5y': 'Ba1',
#        'impliedRating6y': 'Ba2',
#        'impliedRating7y': 'Ba3',
#        'impliedRating8y': 'Ba3',
#        'impliedRating9y': 'B1',
#        'impliedRating10y': 'B1'}}},
#     {'modelId': 'hmark',
#      'asOfDate': '2023-04-01',
#      'pd': 0.012916,
#      'impliedRating': 'Ba2',
#      'legalForm': 'Government',
#      'legalStatus': 'Active',
#      'confidence': 'PN-X-X-FLAG_S',
#      'confidenceDescription': 'Private firm benchmark model with no financials. Entity sector was not included in the model development sample.',
#      'termStructure': {'forward': {'forward1y': '0.012916',
#        'forward2y': '0.012136',
#        'forward3y': '0.011857',
#        'forward4y': '0.011679',
#        'forward5y': '0.011547',
#        'forward6y': '0.011547',
#        'forward7y': '0.011547',
#        'forward8y': '0.011547',
#        'forward9y': '0.011547',
#        'forward10y': '0.011547'},
#       'annualized': {'annualized1y': '0.012916',
#        'annualized2y': '0.012526',
#        'annualized3y': '0.012303',
#        'annualized4y': '0.012147',
#        'annualized5y': '0.012027',
#        'annualized6y': '0.011948',
#        'annualized7y': '0.011891',
#        'annualized8y': '0.011848',
#        'annualized9y': '0.011815',
#        'annualized10y': '0.011788'},
#       'cumulative': {'cumulative1y': '0.012916',
#        'cumulative2y': '0.024895',
#        'cumulative3y': '0.036457',
#        'cumulative4y': '0.04771',
#        'cumulative5y': '0.058706',
#        'cumulative6y': '0.06958',
#        'cumulative7y': '0.080326',
#        'cumulative8y': '0.090945',
#        'cumulative9y': '0.101446',
#        'cumulative10y': '0.11182'},
#       'impliedRating': {'impliedRating1y': 'Ba2',
#        'impliedRating2y': 'Ba2',
#        'impliedRating3y': 'Ba2',
#        'impliedRating4y': 'Ba2',
#        'impliedRating5y': 'Ba1',
#        'impliedRating6y': 'Ba2',
#        'impliedRating7y': 'Ba3',
#        'impliedRating8y': 'Ba3',
#        'impliedRating9y': 'B1',
#        'impliedRating10y': 'B1'}}},
#     {'modelId': 'hmark',
#      'asOfDate': '2023-05-01',
#      'pd': 0.011675,
#      'impliedRating': 'Ba2',
#      'legalForm': 'Government',
#      'legalStatus': 'Active',
#      'confidence': 'PN-X-X-FLAG_S',
#      'confidenceDescription': 'Private firm benchmark model with no financials. Entity sector was not included in the model development sample.',
#      'termStructure': {'forward': {'forward1y': '0.011675',
#        'forward2y': '0.011641',
#        'forward3y': '0.011625',
#        'forward4y': '0.011618',
#        'forward5y': '0.01161',
#        'forward6y': '0.01161',
#        'forward7y': '0.01161',
#        'forward8y': '0.01161',
#        'forward9y': '0.01161',
#        'forward10y': '0.01161'},
#       'annualized': {'annualized1y': '0.011675',
#        'annualized2y': '0.011658',
#        'annualized3y': '0.011647',
#        'annualized4y': '0.01164',
#        'annualized5y': '0.011634',
#        'annualized6y': '0.01163',
#        'annualized7y': '0.011627',
#        'annualized8y': '0.011625',
#        'annualized9y': '0.011624',
#        'annualized10y': '0.011622'},
#       'cumulative': {'cumulative1y': '0.011675',
#        'cumulative2y': '0.02318',
#        'cumulative3y': '0.034536',
#        'cumulative4y': '0.045753',
#        'cumulative5y': '0.056832',
#        'cumulative6y': '0.067782',
#        'cumulative7y': '0.078604',
#        'cumulative8y': '0.089303',
#        'cumulative9y': '0.099881',
#        'cumulative10y': '0.110326'},
#       'impliedRating': {'impliedRating1y': 'Ba2',
#        'impliedRating2y': 'Ba2',
#        'impliedRating3y': 'Ba1',
#        'impliedRating4y': 'Ba1',
#        'impliedRating5y': 'Ba1',
#        'impliedRating6y': 'Ba2',
#        'impliedRating7y': 'Ba3',
#        'impliedRating8y': 'Ba3',
#        'impliedRating9y': 'B1',
#        'impliedRating10y': 'B1'}}}]},
#   {'entityId': 'DELEI421244',
#    'asOfDate': '2023-05-01',
#    'pd': 0.010603,
#    'impliedRating': 'Ba1',
#    'legalForm': 'Government',
#    'legalStatus': 'Active',
#    'confidence': 'PN-X-X-FLAG_T',
#    'confidenceDescription': 'Private firm benchmark model with no financials. Entity type was not included in the model development sample.',
#    'termStructure': {'forward': {'forward1y': '0.010603',
#      'forward2y': '0.010287',
#      'forward3y': '0.010171',
#      'forward4y': '0.010098',
#      'forward5y': '0.01004',
#      'forward6y': '0.01004',
#      'forward7y': '0.01004',
#      'forward8y': '0.01004',
#      'forward9y': '0.01004',
#      'forward10y': '0.01004'},
#     'annualized': {'annualized1y': '0.010603',
#      'annualized2y': '0.010445',
#      'annualized3y': '0.010354',
#      'annualized4y': '0.01029',
#      'annualized5y': '0.01024',
#      'annualized6y': '0.010207',
#      'annualized7y': '0.010183',
#      'annualized8y': '0.010165',
#      'annualized9y': '0.010152',
#      'annualized10y': '0.010141'},
#     'cumulative': {'cumulative1y': '0.010603',
#      'cumulative2y': '0.020781',
#      'cumulative3y': '0.030741',
#      'cumulative4y': '0.040529',
#      'cumulative5y': '0.050162',
#      'cumulative6y': '0.0597',
#      'cumulative7y': '0.06914',
#      'cumulative8y': '0.078485',
#      'cumulative9y': '0.087744',
#      'cumulative10y': '0.096905'},
#     'impliedRating': {'impliedRating1y': 'Ba1',
#      'impliedRating2y': 'Ba1',
#      'impliedRating3y': 'Ba1',
#      'impliedRating4y': 'Ba1',
#      'impliedRating5y': 'Ba1',
#      'impliedRating6y': 'Ba2',
#      'impliedRating7y': 'Ba2',
#      'impliedRating8y': 'Ba3',
#      'impliedRating9y': 'Ba3',
#      'impliedRating10y': 'Ba3'}},
#    'history': [{'modelId': 'hmark',
#      'asOfDate': '2022-01-01',
#      'pd': 0.008924,
#      'impliedRating': 'Ba1',
#      'legalForm': 'Government',
#      'legalStatus': '',
#      'confidence': 'PN-X-X-FLAG_T',
#      'confidenceDescription': 'Private firm benchmark model with no financials available. Entity type was not included in the model development sample.',
#      'termStructure': {'forward': {'forward1y': '0.008924',
#        'forward2y': '0.009816',
#        'forward3y': '0.010186',
#        'forward4y': '0.01043',
#        'forward5y': '0.010614',
#        'forward6y': '0.010614',
#        'forward7y': '0.010614',
#        'forward8y': '0.010614',
#        'forward9y': '0.010614',
#        'forward10y': '0.010614'},
#       'annualized': {'annualized1y': '0.008924',
#        'annualized2y': '0.00937',
#        'annualized3y': '0.009642',
#        'annualized4y': '0.009839',
#        'annualized5y': '0.009994',
#        'annualized6y': '0.010098',
#        'annualized7y': '0.010172',
#        'annualized8y': '0.010228',
#        'annualized9y': '0.010271',
#        'annualized10y': '0.010306'},
#       'cumulative': {'cumulative1y': '0.008924',
#        'cumulative2y': '0.018652',
#        'cumulative3y': '0.028648',
#        'cumulative4y': '0.038779',
#        'cumulative5y': '0.048981',
#        'cumulative6y': '0.059079',
#        'cumulative7y': '0.069068',
#        'cumulative8y': '0.078954',
#        'cumulative9y': '0.088731',
#        'cumulative10y': '0.098409'},
#       'impliedRating': {'impliedRating1y': 'Ba1',
#        'impliedRating2y': 'Ba1',
#        'impliedRating3y': 'Ba1',
#        'impliedRating4y': 'Ba1',
#        'impliedRating5y': 'Ba1',
#        'impliedRating6y': 'Ba2',
#        'impliedRating7y': 'Ba2',
#        'impliedRating8y': 'Ba3',
#        'impliedRating9y': 'Ba3',
#        'impliedRating10y': 'Ba3'}}},
#     {'modelId': 'hmark',
#      'asOfDate': '2022-02-01',
#      'pd': 0.00893,
#      'impliedRating': 'Ba1',
#      'legalForm': 'Government',
#      'legalStatus': '',
#      'confidence': 'PN-X-X-FLAG_T',
#      'confidenceDescription': 'Private firm benchmark model with no financials available. Entity type was not included in the model development sample.',
#      'termStructure': {'forward': {'forward1y': '0.00893',
#        'forward2y': '0.009818',
#        'forward3y': '0.010187',
#        'forward4y': '0.010429',
#        'forward5y': '0.010616',
#        'forward6y': '0.010616',
#        'forward7y': '0.010616',
#        'forward8y': '0.010616',
#        'forward9y': '0.010616',
#        'forward10y': '0.010616'},
#       'annualized': {'annualized1y': '0.00893',
#        'annualized2y': '0.009374',
#        'annualized3y': '0.009645',
#        'annualized4y': '0.009841',
#        'annualized5y': '0.009996',
#        'annualized6y': '0.010099',
#        'annualized7y': '0.010173',
#        'annualized8y': '0.010229',
#        'annualized9y': '0.010272',
#        'annualized10y': '0.010306'},
#       'cumulative': {'cumulative1y': '0.00893',
#        'cumulative2y': '0.01866',
#        'cumulative3y': '0.028657',
#        'cumulative4y': '0.038787',
#        'cumulative5y': '0.048991',
#        'cumulative6y': '0.059085',
#        'cumulative7y': '0.069074',
#        'cumulative8y': '0.078961',
#        'cumulative9y': '0.088739',
#        'cumulative10y': '0.098409'},
#       'impliedRating': {'impliedRating1y': 'Ba1',
#        'impliedRating2y': 'Ba1',
#        'impliedRating3y': 'Ba1',
#        'impliedRating4y': 'Ba1',
#        'impliedRating5y': 'Ba1',
#        'impliedRating6y': 'Ba2',
#        'impliedRating7y': 'Ba2',
#        'impliedRating8y': 'Ba3',
#        'impliedRating9y': 'Ba3',
#        'impliedRating10y': 'Ba3'}}},
#     {'modelId': 'hmark',
#      'asOfDate': '2022-03-01',
#      'pd': 0.0091,
#      'impliedRating': 'Ba1',
#      'legalForm': 'Government',
#      'legalStatus': '',
#      'confidence': 'PN-X-X-FLAG_T',
#      'confidenceDescription': 'Private firm benchmark model with no financials available. Entity type was not included in the model development sample.',
#      'termStructure': {'forward': {'forward1y': '0.0091',
#        'forward2y': '0.00989',
#        'forward3y': '0.010212',
#        'forward4y': '0.010425',
#        'forward5y': '0.010586',
#        'forward6y': '0.010586',
#        'forward7y': '0.010586',
#        'forward8y': '0.010586',
#        'forward9y': '0.010586',
#        'forward10y': '0.010586'},
#       'annualized': {'annualized1y': '0.0091',
#        'annualized2y': '0.009495',
#        'annualized3y': '0.009734',
#        'annualized4y': '0.009907',
#        'annualized5y': '0.010043',
#        'annualized6y': '0.010134',
#        'annualized7y': '0.010199',
#        'annualized8y': '0.010248',
#        'annualized9y': '0.010286',
#        'annualized10y': '0.010316'},
#       'cumulative': {'cumulative1y': '0.0091',
#        'cumulative2y': '0.0189',
#        'cumulative3y': '0.028919',
#        'cumulative4y': '0.039043',
#        'cumulative5y': '0.049216',
#        'cumulative6y': '0.059284',
#        'cumulative7y': '0.069245',
#        'cumulative8y': '0.079103',
#        'cumulative9y': '0.088855',
#        'cumulative10y': '0.0985'},
#       'impliedRating': {'impliedRating1y': 'Ba1',
#        'impliedRating2y': 'Ba1',
#        'impliedRating3y': 'Ba1',
#        'impliedRating4y': 'Ba1',
#        'impliedRating5y': 'Ba1',
#        'impliedRating6y': 'Ba2',
#        'impliedRating7y': 'Ba2',
#        'impliedRating8y': 'Ba3',
#        'impliedRating9y': 'Ba3',
#        'impliedRating10y': 'Ba3'}}},
#     {'modelId': 'hmark',
#      'asOfDate': '2022-04-01',
#      'pd': 0.009411,
#      'impliedRating': 'Ba1',
#      'legalForm': 'Government',
#      'legalStatus': '',
#      'confidence': 'PN-X-X-FLAG_T',
#      'confidenceDescription': 'Private firm benchmark model with no financials available. Entity type was not included in the model development sample.',
#      'termStructure': {'forward': {'forward1y': '0.009411',
#        'forward2y': '0.009981',
#        'forward3y': '0.010209',
#        'forward4y': '0.010359',
#        'forward5y': '0.010475',
#        'forward6y': '0.010475',
#        'forward7y': '0.010475',
#        'forward8y': '0.010475',
#        'forward9y': '0.010475',
#        'forward10y': '0.010475'},
#       'annualized': {'annualized1y': '0.009411',
#        'annualized2y': '0.009696',
#        'annualized3y': '0.009867',
#        'annualized4y': '0.00999',
#        'annualized5y': '0.010087',
#        'annualized6y': '0.010151',
#        'annualized7y': '0.010197',
#        'annualized8y': '0.010232',
#        'annualized9y': '0.010258',
#        'annualized10y': '0.01028'},
#       'cumulative': {'cumulative1y': '0.009411',
#        'cumulative2y': '0.019298',
#        'cumulative3y': '0.02931',
#        'cumulative4y': '0.039365',
#        'cumulative5y': '0.049428',
#        'cumulative6y': '0.059381',
#        'cumulative7y': '0.069232',
#        'cumulative8y': '0.078984',
#        'cumulative9y': '0.088623',
#        'cumulative10y': '0.098173'},
#       'impliedRating': {'impliedRating1y': 'Ba1',
#        'impliedRating2y': 'Ba1',
#        'impliedRating3y': 'Ba1',
#        'impliedRating4y': 'Ba1',
#        'impliedRating5y': 'Ba1',
#        'impliedRating6y': 'Ba2',
#        'impliedRating7y': 'Ba2',
#        'impliedRating8y': 'Ba3',
#        'impliedRating9y': 'Ba3',
#        'impliedRating10y': 'Ba3'}}},
#     {'modelId': 'hmark',
#      'asOfDate': '2022-05-01',
#      'pd': 0.009926,
#      'impliedRating': 'Ba1',
#      'legalForm': 'Government',
#      'legalStatus': '',
#      'confidence': 'PN-X-X-FLAG_T',
#      'confidenceDescription': 'Private firm benchmark model with no financials available. Entity type was not included in the model development sample.',
#      'termStructure': {'forward': {'forward1y': '0.009926',
#        'forward2y': '0.010108',
#        'forward3y': '0.010176',
#        'forward4y': '0.010222',
#        'forward5y': '0.010259',
#        'forward6y': '0.010259',
#        'forward7y': '0.010259',
#        'forward8y': '0.010259',
#        'forward9y': '0.010259',
#        'forward10y': '0.010259'},
#       'annualized': {'annualized1y': '0.009926',
#        'annualized2y': '0.010017',
#        'annualized3y': '0.01007',
#        'annualized4y': '0.010108',
#        'annualized5y': '0.010138',
#        'annualized6y': '0.010158',
#        'annualized7y': '0.010172',
#        'annualized8y': '0.010182',
#        'annualized9y': '0.010191',
#        'annualized10y': '0.010197'},
#       'cumulative': {'cumulative1y': '0.009926',
#        'cumulative2y': '0.019934',
#        'cumulative3y': '0.029907',
#        'cumulative4y': '0.039823',
#        'cumulative5y': '0.049673',
#        'cumulative6y': '0.059421',
#        'cumulative7y': '0.069068',
#        'cumulative8y': '0.078612',
#        'cumulative9y': '0.088068',
#        'cumulative10y': '0.097416'},
#       'impliedRating': {'impliedRating1y': 'Ba1',
#        'impliedRating2y': 'Ba1',
#        'impliedRating3y': 'Ba1',
#        'impliedRating4y': 'Ba1',
#        'impliedRating5y': 'Ba1',
#        'impliedRating6y': 'Ba2',
#        'impliedRating7y': 'Ba2',
#        'impliedRating8y': 'Ba3',
#        'impliedRating9y': 'Ba3',
#        'impliedRating10y': 'Ba3'}}},
#     {'modelId': 'hmark',
#      'asOfDate': '2022-06-01',
#      'pd': 0.010586,
#      'impliedRating': 'Ba1',
#      'legalForm': 'Government',
#      'legalStatus': '',
#      'confidence': 'PN-X-X-FLAG_T',
#      'confidenceDescription': 'Private firm benchmark model with no financials available. Entity type was not included in the model development sample.',
#      'termStructure': {'forward': {'forward1y': '0.010586',
#        'forward2y': '0.010282',
#        'forward3y': '0.01017',
#        'forward4y': '0.010098',
#        'forward5y': '0.010044',
#        'forward6y': '0.010044',
#        'forward7y': '0.010044',
#        'forward8y': '0.010044',
#        'forward9y': '0.010044',
#        'forward10y': '0.010044'},
#       'annualized': {'annualized1y': '0.010586',
#        'annualized2y': '0.010434',
#        'annualized3y': '0.010346',
#        'annualized4y': '0.010284',
#        'annualized5y': '0.010236',
#        'annualized6y': '0.010204',
#        'annualized7y': '0.010181',
#        'annualized8y': '0.010164',
#        'annualized9y': '0.010151',
#        'annualized10y': '0.01014'},
#       'cumulative': {'cumulative1y': '0.010586',
#        'cumulative2y': '0.020759',
#        'cumulative3y': '0.030718',
#        'cumulative4y': '0.040506',
#        'cumulative5y': '0.050143',
#        'cumulative6y': '0.059683',
#        'cumulative7y': '0.069127',
#        'cumulative8y': '0.078477',
#        'cumulative9y': '0.087736',
#        'cumulative10y': '0.096896'},
#       'impliedRating': {'impliedRating1y': 'Ba1',
#        'impliedRating2y': 'Ba1',
#        'impliedRating3y': 'Ba1',
#        'impliedRating4y': 'Ba1',
#        'impliedRating5y': 'Ba1',
#        'impliedRating6y': 'Ba2',
#        'impliedRating7y': 'Ba2',
#        'impliedRating8y': 'Ba3',
#        'impliedRating9y': 'Ba3',
#        'impliedRating10y': 'Ba3'}}},
#     {'modelId': 'hmark',
#      'asOfDate': '2022-07-01',
#      'pd': 0.011054,
#      'impliedRating': 'Ba2',
#      'legalForm': 'Government',
#      'legalStatus': '',
#      'confidence': 'PN-X-X-FLAG_T',
#      'confidenceDescription': 'Private firm benchmark model with no financials available. Entity type was not included in the model development sample.',
#      'termStructure': {'forward': {'forward1y': '0.011054',
#        'forward2y': '0.010404',
#        'forward3y': '0.010174',
#        'forward4y': '0.010024',
#        'forward5y': '0.009914',
#        'forward6y': '0.009914',
#        'forward7y': '0.009914',
#        'forward8y': '0.009914',
#        'forward9y': '0.009914',
#        'forward10y': '0.009914'},
#       'annualized': {'annualized1y': '0.011054',
#        'annualized2y': '0.010729',
#        'annualized3y': '0.010544',
#        'annualized4y': '0.010414',
#        'annualized5y': '0.010314',
#        'annualized6y': '0.010248',
#        'annualized7y': '0.0102',
#        'annualized8y': '0.010165',
#        'annualized9y': '0.010137',
#        'annualized10y': '0.010115'},
#       'cumulative': {'cumulative1y': '0.011054',
#        'cumulative2y': '0.021343',
#        'cumulative3y': '0.0313',
#        'cumulative4y': '0.04101',
#        'cumulative5y': '0.050517',
#        'cumulative6y': '0.059934',
#        'cumulative7y': '0.069252',
#        'cumulative8y': '0.078485',
#        'cumulative9y': '0.08762',
#        'cumulative10y': '0.096668'},
#       'impliedRating': {'impliedRating1y': 'Ba2',
#        'impliedRating2y': 'Ba1',
#        'impliedRating3y': 'Ba1',
#        'impliedRating4y': 'Ba1',
#        'impliedRating5y': 'Ba1',
#        'impliedRating6y': 'Ba2',
#        'impliedRating7y': 'Ba2',
#        'impliedRating8y': 'Ba3',
#        'impliedRating9y': 'Ba3',
#        'impliedRating10y': 'Ba3'}}},
#     {'modelId': 'hmark',
#      'asOfDate': '2022-08-01',
#      'pd': 0.01116,
#      'impliedRating': 'Ba2',
#      'legalForm': 'Government',
#      'legalStatus': '',
#      'confidence': 'PN-X-X-FLAG_T',
#      'confidenceDescription': 'Private firm benchmark model with no financials available. Entity type was not included in the model development sample.',
#      'termStructure': {'forward': {'forward1y': '0.01116',
#        'forward2y': '0.010426',
#        'forward3y': '0.010165',
#        'forward4y': '0.01',
#        'forward5y': '0.009878',
#        'forward6y': '0.009878',
#        'forward7y': '0.009878',
#        'forward8y': '0.009878',
#        'forward9y': '0.009878',
#        'forward10y': '0.009878'},
#       'annualized': {'annualized1y': '0.01116',
#        'annualized2y': '0.010793',
#        'annualized3y': '0.010584',
#        'annualized4y': '0.010438',
#        'annualized5y': '0.010326',
#        'annualized6y': '0.010252',
#        'annualized7y': '0.010198',
#        'annualized8y': '0.010158',
#        'annualized9y': '0.010127',
#        'annualized10y': '0.010102'},
#       'cumulative': {'cumulative1y': '0.01116',
#        'cumulative2y': '0.02147',
#        'cumulative3y': '0.031417',
#        'cumulative4y': '0.041103',
#        'cumulative5y': '0.050575',
#        'cumulative6y': '0.059957',
#        'cumulative7y': '0.069239',
#        'cumulative8y': '0.078433',
#        'cumulative9y': '0.087537',
#        'cumulative10y': '0.096549'},
#       'impliedRating': {'impliedRating1y': 'Ba2',
#        'impliedRating2y': 'Ba1',
#        'impliedRating3y': 'Ba1',
#        'impliedRating4y': 'Ba1',
#        'impliedRating5y': 'Ba1',
#        'impliedRating6y': 'Ba2',
#        'impliedRating7y': 'Ba2',
#        'impliedRating8y': 'Ba3',
#        'impliedRating9y': 'Ba3',
#        'impliedRating10y': 'Ba3'}}},
#     {'modelId': 'hmark',
#      'asOfDate': '2022-09-01',
#      'pd': 0.011088,
#      'impliedRating': 'Ba2',
#      'legalForm': 'Government',
#      'legalStatus': '',
#      'confidence': 'PN-X-X-FLAG_T',
#      'confidenceDescription': 'Private firm benchmark model with no financials available. Entity type was not included in the model development sample.',
#      'termStructure': {'forward': {'forward1y': '0.011088',
#        'forward2y': '0.010411',
#        'forward3y': '0.010168',
#        'forward4y': '0.010016',
#        'forward5y': '0.009905',
#        'forward6y': '0.009905',
#        'forward7y': '0.009905',
#        'forward8y': '0.009905',
#        'forward9y': '0.009905',
#        'forward10y': '0.009905'},
#       'annualized': {'annualized1y': '0.011088',
#        'annualized2y': '0.01075',
#        'annualized3y': '0.010556',
#        'annualized4y': '0.010421',
#        'annualized5y': '0.010318',
#        'annualized6y': '0.010249',
#        'annualized7y': '0.0102',
#        'annualized8y': '0.010163',
#        'annualized9y': '0.010134',
# ...
#        'forward4y': '0.025819',
#        'forward5y': '0.021464',
#        'forward6y': '0.018238',
#        'forward7y': '0.01568',
#        'forward8y': '0.0136',
#        'forward9y': '0.011866',
#        'forward10y': '0.010395'},
#       'annualized': {'annualized1y': '0.051836',
#        'annualized2y': '0.048126',
#        'annualized3y': '0.042924',
#        'annualized4y': '0.038676',
#        'annualized5y': '0.035258',
#        'annualized6y': '0.032442',
#        'annualized7y': '0.030065',
#        'annualized8y': '0.028022',
#        'annualized9y': '0.02624',
#        'annualized10y': '0.024667'},
#       'cumulative': {'cumulative1y': '0.051836',
#        'cumulative2y': '0.093936',
#        'cumulative3y': '0.123324',
#        'cumulative4y': '0.145958',
#        'cumulative5y': '0.164289',
#        'cumulative6y': '0.179531',
#        'cumulative7y': '0.192396',
#        'cumulative8y': '0.203379',
#        'cumulative9y': '0.212832',
#        'cumulative10y': '0.221015'},
#       'impliedRating': {'impliedRating1y': 'B2',
#        'impliedRating2y': 'B2',
#        'impliedRating3y': 'B2',
#        'impliedRating4y': 'B2',
#        'impliedRating5y': 'B1',
#        'impliedRating6y': 'B1',
#        'impliedRating7y': 'B1',
#        'impliedRating8y': 'B1',
#        'impliedRating9y': 'B1',
#        'impliedRating10y': 'Ba3'}}},
#     {'asOfDate': '2022-09-30',
#      'pd': 0.062391,
#      'impliedRating': 'B3',
#      'confidence': 'P-G-R',
#      'confidenceDescription': 'Public firm, CreditEdge model. Based on recent and good quality inputs.',
#      'termStructure': {'forward': {'forward1y': '0.062391',
#        'forward2y': '0.049968',
#        'forward3y': '0.036641',
#        'forward4y': '0.028916',
#        'forward5y': '0.023726',
#        'forward6y': '0.01987',
#        'forward7y': '0.016844',
#        'forward8y': '0.014402',
#        'forward9y': '0.012406',
#        'forward10y': '0.010736'},
#       'annualized': {'annualized1y': '0.062391',
#        'annualized2y': '0.0562',
#        'annualized3y': '0.049725',
#        'annualized4y': '0.044565',
#        'annualized5y': '0.040433',
#        'annualized6y': '0.037036',
#        'annualized7y': '0.034177',
#        'annualized8y': '0.031727',
#        'annualized9y': '0.029599',
#        'annualized10y': '0.027729'},
#       'cumulative': {'cumulative1y': '0.062391',
#        'cumulative2y': '0.109242',
#        'cumulative3y': '0.14188',
#        'cumulative4y': '0.166694',
#        'cumulative5y': '0.186464',
#        'cumulative6y': '0.202629',
#        'cumulative7y': '0.21606',
#        'cumulative8y': '0.22735',
#        'cumulative9y': '0.236936',
#        'cumulative10y': '0.245128'},
#       'impliedRating': {'impliedRating1y': 'B3',
#        'impliedRating2y': 'B3',
#        'impliedRating3y': 'B2',
#        'impliedRating4y': 'B2',
#        'impliedRating5y': 'B2',
#        'impliedRating6y': 'B1',
#        'impliedRating7y': 'B1',
#        'impliedRating8y': 'B1',
#        'impliedRating9y': 'B1',
#        'impliedRating10y': 'B1'}}},
#     {'asOfDate': '2022-08-31',
#      'pd': 0.042612,
#      'impliedRating': 'B2',
#      'confidence': 'P-G-R',
#      'confidenceDescription': 'Public firm, CreditEdge model. Based on recent and good quality inputs.',
#      'termStructure': {'forward': {'forward1y': '0.042612',
#        'forward2y': '0.042646',
#        'forward3y': '0.033546',
#        'forward4y': '0.027308',
#        'forward5y': '0.022924',
#        'forward6y': '0.019557',
#        'forward7y': '0.016855',
#        'forward8y': '0.014638',
#        'forward9y': '0.012788',
#        'forward10y': '0.011226'},
#       'annualized': {'annualized1y': '0.042612',
#        'annualized2y': '0.042629',
#        'annualized3y': '0.039611',
#        'annualized4y': '0.03655',
#        'annualized5y': '0.03384',
#        'annualized6y': '0.031474',
#        'annualized7y': '0.029399',
#        'annualized8y': '0.027566',
#        'annualized9y': '0.025935',
#        'annualized10y': '0.024474'},
#       'cumulative': {'cumulative1y': '0.042612',
#        'cumulative2y': '0.083441',
#        'cumulative3y': '0.114188',
#        'cumulative4y': '0.138378',
#        'cumulative5y': '0.15813',
#        'cumulative6y': '0.174594',
#        'cumulative7y': '0.188506',
#        'cumulative8y': '0.200385',
#        'cumulative9y': '0.21061',
#        'cumulative10y': '0.219472'},
#       'impliedRating': {'impliedRating1y': 'B2',
#        'impliedRating2y': 'B2',
#        'impliedRating3y': 'B2',
#        'impliedRating4y': 'B1',
#        'impliedRating5y': 'B1',
#        'impliedRating6y': 'B1',
#        'impliedRating7y': 'B1',
#        'impliedRating8y': 'B1',
#        'impliedRating9y': 'B1',
#        'impliedRating10y': 'Ba3'}}},
#     {'asOfDate': '2022-07-31',
#      'pd': 0.032121,
#      'impliedRating': 'B1',
#      'confidence': 'P-G-R',
#      'confidenceDescription': 'Public firm, CreditEdge model. Based on recent and good quality inputs.',
#      'termStructure': {'forward': {'forward1y': '0.032121',
#        'forward2y': '0.036584',
#        'forward3y': '0.028978',
#        'forward4y': '0.024541',
#        'forward5y': '0.021003',
#        'forward6y': '0.01821',
#        'forward7y': '0.01594',
#        'forward8y': '0.014044',
#        'forward9y': '0.01244',
#        'forward10y': '0.011072'},
#       'annualized': {'annualized1y': '0.032121',
#        'annualized2y': '0.034355',
#        'annualized3y': '0.032566',
#        'annualized4y': '0.030566',
#        'annualized5y': '0.028661',
#        'annualized6y': '0.026927',
#        'annualized7y': '0.025365',
#        'annualized8y': '0.023957',
#        'annualized9y': '0.022684',
#        'annualized10y': '0.021529'},
#       'cumulative': {'cumulative1y': '0.032121',
#        'cumulative2y': '0.06753',
#        'cumulative3y': '0.094551',
#        'cumulative4y': '0.116772',
#        'cumulative5y': '0.135323',
#        'cumulative6y': '0.151069',
#        'cumulative7y': '0.164601',
#        'cumulative8y': '0.176333',
#        'cumulative9y': '0.18658',
#        'cumulative10y': '0.195586'},
#       'impliedRating': {'impliedRating1y': 'B1',
#        'impliedRating2y': 'B1',
#        'impliedRating3y': 'B1',
#        'impliedRating4y': 'B1',
#        'impliedRating5y': 'B1',
#        'impliedRating6y': 'B1',
#        'impliedRating7y': 'B1',
#        'impliedRating8y': 'Ba3',
#        'impliedRating9y': 'Ba3',
#        'impliedRating10y': 'Ba3'}}},
#     {'asOfDate': '2022-06-30',
#      'pd': 0.030738,
#      'impliedRating': 'B1',
#      'confidence': 'P-G-R',
#      'confidenceDescription': 'Public firm, CreditEdge model. Based on recent and good quality inputs.',
#      'termStructure': {'forward': {'forward1y': '0.030738',
#        'forward2y': '0.038036',
#        'forward3y': '0.031334',
#        'forward4y': '0.026834',
#        'forward5y': '0.023108',
#        'forward6y': '0.019936',
#        'forward7y': '0.017341',
#        'forward8y': '0.01518',
#        'forward9y': '0.013369',
#        'forward10y': '0.01184'},
#       'annualized': {'annualized1y': '0.030738',
#        'annualized2y': '0.034394',
#        'annualized3y': '0.033375',
#        'annualized4y': '0.031744',
#        'annualized5y': '0.030023',
#        'annualized6y': '0.028349',
#        'annualized7y': '0.026784',
#        'annualized8y': '0.025341',
#        'annualized9y': '0.024018',
#        'annualized10y': '0.022807'},
#       'cumulative': {'cumulative1y': '0.030738',
#        'cumulative2y': '0.067605',
#        'cumulative3y': '0.096821',
#        'cumulative4y': '0.121057',
#        'cumulative5y': '0.141368',
#        'cumulative6y': '0.158485',
#        'cumulative7y': '0.173078',
#        'cumulative8y': '0.18563',
#        'cumulative9y': '0.196518',
#        'cumulative10y': '0.206031'},
#       'impliedRating': {'impliedRating1y': 'B1',
#        'impliedRating2y': 'B1',
#        'impliedRating3y': 'B1',
#        'impliedRating4y': 'B1',
#        'impliedRating5y': 'B1',
#        'impliedRating6y': 'B1',
#        'impliedRating7y': 'B1',
#        'impliedRating8y': 'B1',
#        'impliedRating9y': 'Ba3',
#        'impliedRating10y': 'Ba3'}}},
#     {'asOfDate': '2022-05-31',
#      'pd': 0.027973,
#      'impliedRating': 'B1',
#      'confidence': 'P-G-R',
#      'confidenceDescription': 'Public firm, CreditEdge model. Based on recent and good quality inputs.',
#      'termStructure': {'forward': {'forward1y': '0.027973',
#        'forward2y': '0.035433',
#        'forward3y': '0.029744',
#        'forward4y': '0.025744',
#        'forward5y': '0.022614',
#        'forward6y': '0.019627',
#        'forward7y': '0.017154',
#        'forward8y': '0.015079',
#        'forward9y': '0.01333',
#        'forward10y': '0.011844'},
#       'annualized': {'annualized1y': '0.027973',
#        'annualized2y': '0.03171',
#        'annualized3y': '0.031055',
#        'annualized4y': '0.02973',
#        'annualized5y': '0.028311',
#        'annualized6y': '0.026869',
#        'annualized7y': '0.025487',
#        'annualized8y': '0.024192',
#        'annualized9y': '0.022991',
#        'annualized10y': '0.021882'},
#       'cumulative': {'cumulative1y': '0.027973',
#        'cumulative2y': '0.062414',
#        'cumulative3y': '0.090302',
#        'cumulative4y': '0.113721',
#        'cumulative5y': '0.133764',
#        'cumulative6y': '0.150765',
#        'cumulative7y': '0.165333',
#        'cumulative8y': '0.177918',
#        'cumulative9y': '0.188876',
#        'cumulative10y': '0.198483'},
#       'impliedRating': {'impliedRating1y': 'B1',
#        'impliedRating2y': 'B1',
#        'impliedRating3y': 'B1',
#        'impliedRating4y': 'B1',
#        'impliedRating5y': 'B1',
#        'impliedRating6y': 'B1',
#        'impliedRating7y': 'B1',
#        'impliedRating8y': 'Ba3',
#        'impliedRating9y': 'Ba3',
#        'impliedRating10y': 'Ba3'}}},
#     {'asOfDate': '2022-04-30',
#      'pd': 0.029087,
#      'impliedRating': 'B1',
#      'confidence': 'P-G-R',
#      'confidenceDescription': 'Public firm, CreditEdge model. Based on recent and good quality inputs.',
#      'termStructure': {'forward': {'forward1y': '0.029087',
#        'forward2y': '0.038822',
#        'forward3y': '0.033361',
#        'forward4y': '0.02896',
#        'forward5y': '0.025174',
#        'forward6y': '0.021652',
#        'forward7y': '0.01875',
#        'forward8y': '0.01634',
#        'forward9y': '0.014317',
#        'forward10y': '0.012621'},
#       'annualized': {'annualized1y': '0.029087',
#        'annualized2y': '0.033967',
#        'annualized3y': '0.033765',
#        'annualized4y': '0.032566',
#        'annualized5y': '0.031092',
#        'annualized6y': '0.029525',
#        'annualized7y': '0.027993',
#        'annualized8y': '0.026544',
#        'annualized9y': '0.025193',
#        'annualized10y': '0.023943'},
#       'cumulative': {'cumulative1y': '0.029087',
#        'cumulative2y': '0.06678',
#        'cumulative3y': '0.097913',
#        'cumulative4y': '0.124038',
#        'cumulative5y': '0.146089',
#        'cumulative6y': '0.164578',
#        'cumulative7y': '0.180242',
#        'cumulative8y': '0.193637',
#        'cumulative9y': '0.205182',
#        'cumulative10y': '0.215213'},
#       'impliedRating': {'impliedRating1y': 'B1',
#        'impliedRating2y': 'B1',
#        'impliedRating3y': 'B1',
#        'impliedRating4y': 'B1',
#        'impliedRating5y': 'B1',
#        'impliedRating6y': 'B1',
#        'impliedRating7y': 'B1',
#        'impliedRating8y': 'B1',
#        'impliedRating9y': 'B1',
#        'impliedRating10y': 'Ba3'}}},
#     {'asOfDate': '2022-03-31',
#      'pd': 0.02667,
#      'impliedRating': 'B1',
#      'confidence': 'P-G-R',
#      'confidenceDescription': 'Public firm, CreditEdge model. Based on recent and good quality inputs.',
#      'termStructure': {'forward': {'forward1y': '0.02667',
#        'forward2y': '0.036151',
#        'forward3y': '0.031242',
#        'forward4y': '0.027292',
#        'forward5y': '0.024105',
#        'forward6y': '0.020918',
#        'forward7y': '0.018231',
#        'forward8y': '0.015964',
#        'forward9y': '0.014075',
#        'forward10y': '0.012454'},
#       'annualized': {'annualized1y': '0.02667',
#        'annualized2y': '0.031422',
#        'annualized3y': '0.031362',
#        'annualized4y': '0.030346',
#        'annualized5y': '0.029101',
#        'annualized6y': '0.027742',
#        'annualized7y': '0.026389',
#        'annualized8y': '0.025092',
#        'annualized9y': '0.023874',
#        'annualized10y': '0.022738'},
#       'cumulative': {'cumulative1y': '0.02667',
#        'cumulative2y': '0.061857',
#        'cumulative3y': '0.091166',
#        'cumulative4y': '0.11597',
#        'cumulative5y': '0.137279',
#        'cumulative6y': '0.155326',
#        'cumulative7y': '0.170726',
#        'cumulative8y': '0.183964',
#        'cumulative9y': '0.19545',
#        'cumulative10y': '0.20547'},
#       'impliedRating': {'impliedRating1y': 'B1',
#        'impliedRating2y': 'B1',
#        'impliedRating3y': 'B1',
#        'impliedRating4y': 'B1',
#        'impliedRating5y': 'B1',
#        'impliedRating6y': 'B1',
#        'impliedRating7y': 'B1',
#        'impliedRating8y': 'B1',
#        'impliedRating9y': 'Ba3',
#        'impliedRating10y': 'Ba3'}}},
#     {'asOfDate': '2022-02-28',
#      'pd': 0.038629,
#      'impliedRating': 'B2',
#      'confidence': 'P-G-R',
#      'confidenceDescription': 'Public firm, CreditEdge model. Based on recent and good quality inputs.',
#      'termStructure': {'forward': {'forward1y': '0.038629',
#        'forward2y': '0.045835',
#        'forward3y': '0.039621',
#        'forward4y': '0.033386',
#        'forward5y': '0.028095',
#        'forward6y': '0.023802',
#        'forward7y': '0.02029',
#        'forward8y': '0.017419',
#        'forward9y': '0.015058',
#        'forward10y': '0.013101'},
#       'annualized': {'annualized1y': '0.038629',
#        'annualized2y': '0.042239',
#        'annualized3y': '0.041367',
#        'annualized4y': '0.039378',
#        'annualized5y': '0.037132',
#        'annualized6y': '0.034923',
#        'annualized7y': '0.032846',
#        'annualized8y': '0.030931',
#        'annualized9y': '0.02918',
#        'annualized10y': '0.027584'},
#       'cumulative': {'cumulative1y': '0.038629',
#        'cumulative2y': '0.082694',
#        'cumulative3y': '0.119038',
#        'cumulative4y': '0.14845',
#        'cumulative5y': '0.172375',
#        'cumulative6y': '0.192074',
#        'cumulative7y': '0.208466',
#        'cumulative8y': '0.222254',
#        'cumulative9y': '0.233965',
#        'cumulative10y': '0.244001'},
#       'impliedRating': {'impliedRating1y': 'B2',
#        'impliedRating2y': 'B2',
#        'impliedRating3y': 'B2',
#        'impliedRating4y': 'B2',
#        'impliedRating5y': 'B2',
#        'impliedRating6y': 'B1',
#        'impliedRating7y': 'B1',
#        'impliedRating8y': 'B1',
#        'impliedRating9y': 'B1',
#        'impliedRating10y': 'B1'}}},
#     {'asOfDate': '2022-01-31',
#      'pd': 0.033807,
#      'impliedRating': 'B1',
#      'confidence': 'P-G-R',
#      'confidenceDescription': 'Public firm, CreditEdge model. Based on recent and good quality inputs.',
#      'termStructure': {'forward': {'forward1y': '0.033807',
#        'forward2y': '0.045718',
#        'forward3y': '0.040177',
#        'forward4y': '0.034723',
#        'forward5y': '0.029277',
#        'forward6y': '0.02481',
#        'forward7y': '0.021149',
#        'forward8y': '0.018152',
#        'forward9y': '0.015682',
#        'forward10y': '0.013642'},
#       'annualized': {'annualized1y': '0.033807',
#        'annualized2y': '0.039781',
#        'annualized3y': '0.039913',
#        'annualized4y': '0.038618',
#        'annualized5y': '0.036757',
#        'annualized6y': '0.034776',
#        'annualized7y': '0.032841',
#        'annualized8y': '0.031017',
#        'annualized9y': '0.029325',
#        'annualized10y': '0.027768'},
#       'cumulative': {'cumulative1y': '0.033807',
#        'cumulative2y': '0.077979',
#        'cumulative3y': '0.115023',
#        'cumulative4y': '0.145752',
#        'cumulative5y': '0.170762',
#        'cumulative6y': '0.191335',
#        'cumulative7y': '0.208438',
#        'cumulative8y': '0.222806',
#        'cumulative9y': '0.234994',
#        'cumulative10y': '0.245431'},
#       'impliedRating': {'impliedRating1y': 'B1',
#        'impliedRating2y': 'B2',
#        'impliedRating3y': 'B2',
#        'impliedRating4y': 'B2',
#        'impliedRating5y': 'B1',
#        'impliedRating6y': 'B1',
#        'impliedRating7y': 'B1',
#        'impliedRating8y': 'B1',
#        'impliedRating9y': 'B1',
#        'impliedRating10y': 'B1'}}}]}]}

# %%
# to Excel. wide version, .xlsx vile. 
endpoints.EDFXPDParse(MultiplePDCheck,FormatType='wide',output_format='Excel')

# %% [markdown]
# # Process ID example
# ## CLient Provides us 100 IDS and would like to See how PD's from the id list on EDF-X API.
#
# - This is a quick and dirty way we can accomplish this task.

# %%
path = r"C:\Users\martyb\OneDrive - moodys.com\Documents\Development\EDF_X_Development\EDFXAPI_OOP"
# Take the first 100 IDs from a .csv file a client gives us
ids = pd.read_csv('TESTBvD_ID_Bulk_Upload.csv')['Identifier*'][:100]
# these are params: Run time is awful on this. 
entities = [{"entityId": i } for i in ids]
print(entities)
try:
    pd_multiple_check = endpoints.EDFXPD_Endpoint(entities=entities, startDate = '2022-01-01',endDate='2023-05-19', historyFrequency="monthly")
    if pd_multiple_check['processId']:
        print(f"Process ID:, {pd_multiple_check['processId']}")
        print("Using EDFX's Files endpoints")
        processId2 = pd_multiple_check['processId']
        response = endpoints.EDFXModelInputsGetFiles(processId2)
        data = json.loads(response)
        download_url = data['downloadLink']

        # Extract only the file name without query parameters
        filename_without_params = os.path.basename(download_url.split('?')[0])
        filename = os.path.join(path, filename_without_params)

        with open(filename, 'w') as f:
            json.dump(data, f, indent=4) # Note: You'll need to adjust this line to actually get the binary content
        print(f"File {filename} downloaded successfully!")
    else:
        print(pd_multiple_check)  # Print the response if 'processId' isn't present
except Exception as e:
    print(f'An error occurred: {e}.')
# Out:
# [{'entityId': 'US323860652L'}, {'entityId': 'US160292205L'}, {'entityId': 'US123417067L'}, {'entityId': 'US174025515L'}, {'entityId': 'US245243012L'}, {'entityId': 'US250123655L'}, {'entityId': 'US150238251L'}, {'entityId': 'US123854753L'}, {'entityId': 'US149111951L'}, {'entityId': 'US131874864L'}, {'entityId': 'US240402245L'}, {'entityId': 'US296645003L'}, {'entityId': 'US149207136L'}, {'entityId': 'US292929686L'}, {'entityId': 'US127922266L'}, {'entityId': 'US127420802L'}, {'entityId': 'US134001297L'}, {'entityId': 'US132101398L'}, {'entityId': 'US349185794L'}, {'entityId': 'US132912437L'}, {'entityId': 'US187108254L'}, {'entityId': 'US295894427L'}, {'entityId': 'US295708856L'}, {'entityId': 'US295708856L'}, {'entityId': 'US276599246L'}, {'entityId': 'US241497443L'}, {'entityId': 'US317725418L'}, {'entityId': 'US248669717L'}, {'entityId': 'US305054801L'}, {'entityId': 'US320056778L'}, {'entityId': 'US620516475'}, {'entityId': 'US168302388L'}, {'entityId': 'US290586179L'}, {'entityId': 'US128433974L'}, {'entityId': 'US165114066L'}, {'entityId': 'US860419443'}, {'entityId': 'US303406514L'}, {'entityId': 'US203195377'}, {'entityId': 'US229443509L'}, {'entityId': 'US149203124L'}, {'entityId': 'US731371046'}, {'entityId': 'US298478474L'}, {'entityId': 'US353578319L'}, {'entityId': 'US160881279L'}, {'entityId': 'US130407758L'}, {'entityId': 'US281154515L'}, {'entityId': 'US303255965L'}, {'entityId': 'US132097597L'}, {'entityId': 'US305289449L'}, {'entityId': 'US133958143L'}, {'entityId': 'US*956128886'}, {'entityId': 'US292929686L'}, {'entityId': 'US292929686L'}, {'entityId': 'US258114980L'}, {'entityId': 'US236793965L'}, {'entityId': 'US353868665L'}, {'entityId': 'US127217228L'}, {'entityId': 'US130852772L'}, {'entityId': 'US042723701'}, {'entityId': 'US731371046'}, {'entityId': 'US120030488L'}, {'entityId': 'US256726814L'}, {'entityId': 'US127691052L'}, {'entityId': 'US304447139L'}, {'entityId': 'US132417855L'}, {'entityId': 'US125665023L'}, {'entityId': 'US231087389L'}, {'entityId': 'US331322033L'}, {'entityId': 'US276184001L'}, {'entityId': 'US292707566L'}, {'entityId': 'US263011769L'}, {'entityId': 'US125818286L'}, {'entityId': 'US127450608L'}, {'entityId': 'US277422008L'}, {'entityId': 'US352244297L'}, {'entityId': 'US126428172L'}, {'entityId': 'US296991302L'}, {'entityId': 'US161337126L'}, {'entityId': 'US120262238L'}, {'entityId': 'US354202433L'}, {'entityId': 'US128084908L'}, {'entityId': 'US232056557L'}, {'entityId': 'US145441072L'}, {'entityId': 'US258364691L'}, {'entityId': 'US348732422L'}, {'entityId': 'US114501133GN'}, {'entityId': 'US329171489L'}, {'entityId': 'US161542712'}, {'entityId': 'US166166097L'}, {'entityId': 'US294713162L'}, {'entityId': 'US293955011L'}, {'entityId': 'US128440384L'}, {'entityId': 'US125648064L'}, {'entityId': 'US164235033L'}, {'entityId': 'US275500499L'}, {'entityId': 'US324242168L'}, {'entityId': 'US316320377L'}, {'entityId': 'US280696730L'}, {'entityId': 'US129275666L'}, {'entityId': 'US127691052L'}]
# Process ID:, 6b3579d4-62f5-11ee-900f-beef270a1a10
# Using EDFX's Files endpoints
# {"downloadLink":"https://uswe2-edfx-clientfinancials-shared-101.s3.amazonaws.com/batch/6b3579d4-62f5-11ee-900f-beef270a1a10_pdsdata.json?response-content-disposition=attachment&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=ASIA4VIHTIBMB6O5RQUW%2F20231004%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Date=20231004T203432Z&X-Amz-Expires=180&X-Amz-SignedHeaders=host&X-Amz-Security-Token=IQoJb3JpZ2luX2VjEEQaCXVzLXdlc3QtMiJIMEYCIQCuMYytbMrxrnrDY6WIWVj77HwlboOSAaUyscPuewyGzQIhAKIn4PCORrT5ittxzGc4WoCLI5BYJ7fJohySiMPWctj6KpUDCE0QAhoMODcwMjgzNjkwMDcyIgwWNgbhUwnNQw8M1GMq8gIC1Gloes80pJRJdVNU1BFMm%2Bm2QaVuva%2FD%2Fj%2Fqb00h8NpXdQTPpRMNcGTdDhuZQQhegz2nTYldpTt%2BY8pJsRnHjVh2pgvmTMRCHbSfGDeo36vJCWds9xG34WjhfvWZPC0dQhcSYcJr9N50USSYeaOygbsdl95puHG7PQI05MFrdWHBx0IPzFw5id%2FGp2jERClEmJnKyvmxsp5vU7cg4p%2BIeTkiJ6Nzfxs4bO6tLN%2Fw8AS1vWne374s6gyOLRWZmzNE8dNrzlmUX8QZ4Le6GjQntQjRvD5lwZASHDTDYWhKh33ZdvzeYaISqCwWax5l2nKwzhqcCGFucJ7uDnGsfoyKy3DUHLITfccZ1TSftgXL5naTSFlsKbH9V5gwy%2Bm8m%2BufBsRTp3Gy1Jjddg3As1cUk2cGXZV49dLeOAsN3vPpvhoAUhqCX3yba5712EwpyrcXUKFklwOBkkxzSH%2Bygg2GU0nIMf5vFVZzRO3TFfhm%2FfuPMNGF96gGOpwBEwlRc%2FClYIRGXkkXn1QpjscVAIauN2UQo3%2BFnxISQ4pFgoXrx1h8t2dTj%2FkDpobFpvnQWjMtW9vn1JU3NTRcKmwm%2BMEs1TW7SgAj%2BLAvsjvBgwRlOyFJW3pVeSKNXiL9HGLqasaV6rymEMg5lYqdkQzC2Pw2QDnBG3oKbz7xI108ofJjqJyiPoAdOFIECt%2FnszJReFWu6l9993UI&X-Amz-Signature=f5bc24ebbf00b0dbfb18126f678b3c7b4902bc196fe67406d77bea2ebd2b67f5"}
# File C:\Users\martyb\OneDrive - moodys.com\Documents\Development\EDF_X_Development\EDFXAPI_OOP\6b3579d4-62f5-11ee-900f-beef270a1a10_pdsdata.json downloaded successfully!

# %% [markdown]
# # Upload Statement
# ### EDFXAPI_Example

# %% [markdown]
# # Financial Template Download + Parse
# endpoint

# %%
import csv
universal = endpoints.EDFXTemplateDownload(financialtemplate = 'Universal',output_format='Csv', )
afile = open(r'C:\Users\martyb\OneDrive - moodys.com\Documents\Development\EDF_X_Development\EDFXAPI_OOP\SearchOutput.csv')
csvReader1 = csv.reader(afile)
for ii in csvReader1:
    print(ii)
# Out:
# Data Saved to SearchOutput.csv
# ['entityInternationalName', 'entityIdentifierbvd', 'financialStatementDate', 'asOfDate', 'primaryIndustryClassification', 'primaryIndustry', 'primaryCountry', 'primaryStateProvince', 'currency', 'entityLegalForm', 'auditQuality', 'entityType', 'entityStatus', 'entityStatusDate', 'cashAndMarketableSecurities', 'cashAndMarketableSecuritiesPreviousYear', 'totalAccountsReceivable', 'totalAccountsReceivablePreviousYear', 'totalInventory', 'totalInventoryPreviousYear', 'totalCurrentAssets', 'totalCurrentAssetsPreviousYear', 'totalAccumulatedDepreciation', 'totalAccumulatedDepreciationPreviousYear', 'totalFixedAssets', 'totalFixedAssetsPreviousYear', 'totalIntangibleAssets', 'totalAssets', 'totalAssetsPreviousYear', 'notesPayable', 'debtCurrentMaturities', 'shortTermDebt', 'shortTermDebtPreviousYear', 'totalAccountsPayable', 'totalAccountsPayablePreviousYear', 'totalCurrentLiabilities', 'totalCurrentLiabilitiesPreviousYear', 'totalLongTermDebt', 'totalLongTermDebtPreviousYear', 'totalNonCurrentLiabilities', 'totalNonCurrentLiabilitiesPreviousYear', 'totalProvisions', 'totalLiabilities', 'totalLiabilitiesPreviousYear', 'retainedEarnings', 'netWorth', 'netSales', 'netSalesPreviousYear', 'totalCostOfGoodsSold', 'grossIncome', 'totalWageExpense', 'totalAmortizationAndDepreciation', 'totalOperatingExpense', 'totalOperatingProfit', 'totalOperatingProfitPreviousYear', 'financeCosts', 'profitBeforeTaxesAndExtraordinaryExpenses', 'profitBeforeTaxesAndExtraordinaryExpensesPreviousYear', 'currentIncomeTaxExpense', 'totalExtraordinaryItems', 'netIncome', 'netIncomePreviousYear', 'ebitda', 'numberOfEmployees']

# %% [markdown]
# # Test Upload
#
# ## Synchronous

# %%
token = "eyJraWQiOiJaRGMyWmpkbE1XSTFaRGczWkRFM1lUVXlZbVE1TWpVNU9EQmpOemcyTW1RMU5XUmlOV015WXpjNU1tTmpZbUUyTldZMlpEZzNPR00wTkRKak5UazNNQV9SUzI1NiIsImFsZyI6IlJTMjU2In0.....jrBhAxsnmRXaVY1E8cT8pKEBgVtbHBLGLLAb9TjFRPdjeMg5sxMTr2ySPjOIhoHasJQ2zBTdOS0rJvn2_OYQ9u7z_FbiN4wHvklZwbmquZmkAIyvgt2IsFS6_xH3d9iVY0U5w_wDT4-6lht_gjC3DMGI8KHxi3dZrSlr9JjbRKmzbQFZAhcHCPJcE6b3UqJKvq85gjFqLgRY2XzRJH0K7WPkMDxG9XXaB4GT0Q5C0F-2JCq4D0yvO-2LhpWRNTVnewR8thZ_IdEa7qqcp9fQnj8ztV3KWMQCxqyCd2g_HqKA5dZ_bx-gEgDphZZ_wdCgCvUAUaOGM0JtXDe-4KPFRw"
file_name = "EDFXAPI_EXAMPLE.csv"
file_path = r"C:\Users\martyb\OneDrive - moodys.com\Documents\Development\EDF_X_Development\EDFXAPI_OOP\\"

## call model input profile
model_input_endpoint = "https://api.edfx.moodysanalytics.com/edfx/v1/entities/modelInputs"
payload = "-----011000010111000001101001\r\nContent-Disposition: form-data; name=\"uploadFilename\"\r\n\r\n" + file_name + "\r\n-----011000010111000001101001\r\nContent-Disposition: form-data; name=\"largeFile\"\r\n\r\ntrue\r\n-----011000010111000001101001--\r\n\r\n"
headers = {
    "accept": "application/json",
    "content-type": "multipart/form-data; boundary=---011000010111000001101001",
    "authorization": "Bearer " + token
}
response = requests.post(model_input_endpoint, data=payload, headers=headers)

process_id = response.json()['processId']
upload_link = response.json()['uploadLink']

print(upload_link)
print(process_id)

upload_headers = {
    'x-amz-tagging': 'edfx_process_id=' + process_id,
    'content-type': 'text/csv'
}

full_path = os.path.join(file_path, file_name)

with open(full_path, 'rb') as file:
    response = requests.put(upload_link, headers=upload_headers, data=file)


print(response.status_code)

status_endpoint = f"https://api.edfx.moodysanalytics.com/edfx/v1/processes/{process_id}/status"

while True:
# wait till server finishes processing
    status_headers = {
        "accept": "application/json",
        "authorization": "Bearer " + token
    }
    response = requests.get(status_endpoint, headers=status_headers)
    print("processing status: " + response.text)
    if response.text == "Completed":
        print("Server finished processing custom financials!")
        break
    print("Server is processing, wait 60 seconds.")
    time.sleep(60)

pd_headers = {
    "accept": "application/json",
    "content-type": "application/json",
    "authorization": "Bearer " + token
}

payload = {
    "endDate": "2023-05-19",
    "historyFrequency": "annual",
    "asyncResponse": False,
    "asReported": False,
    "modelParameters": { "fso": False },
    "includeDetail": {
        "resultDetail": True,
        "inputDetail": False,
        "modelDetail": True,
        "includeTermStructure": True
    },
    "processId": process_id,
    "startDate": "2018-01-01"
}
pds_endpoint = "https://api.edfx.moodysanalytics.com/edfx/v1/entities/pds"
pd_response = requests.post(pds_endpoint, json=payload, headers=pd_headers)
print(pd_response.text)

# %%
# make sure to import this if you haven't

file_path= r"C:\Users\martyb\OneDrive - moodys.com\Documents\Development\EDF_X_Development\EDFXAPI_OOP"
file = 'EDFXAPI_EXAMPLE.csv'
full_file_path = os.path.join(file_path, file)  # combine directory and file name
# Create model inputs process
model_inputs_response = endpoints.EDFXModelInputs(uploadFilename='EDFXAPI_EXAMPLE.csv', localFilename='EDFXAPI_EXAMPLE.csv')
model_inputs_response
# Out:
# 2023-10-05 16:40:54.721 | INFO     | EDFXAuthentication:get_bearer_token:55 - Security token has been generated.
# 200
# {'processId': '623363a7-6512-4c93-90ed-2bd9797a207d',
#  'uploadLink': 'https://uswe2-edfx-clientfinancials-shared-101.s3.amazonaws.com/prd/input/validate/EDFXAPI_EXAMPLE.csv?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=ASIA4VIHTIBMPTOWE253%2F20231005%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Date=20231005T204055Z&X-Amz-Expires=300&X-Amz-SignedHeaders=content-type%3Bhost%3Bx-amz-tagging&X-Amz-Security-Token=IQoJb3JpZ2luX2VjEFwaCXVzLXdlc3QtMiJHMEUCIBv8COxLMQwJR5mi72Aydp817TIep28HB9lbl7402GmiAiEAgCt5oqRpxf457aRLXNZIeUbgf%2FFlWHxAFJCmWA6IRbwqlQMIZBACGgw4NzAyODM2OTAwNzIiDOIX4owHxpwMglpF3SryAoyefnNdC1szILCAWqMCBSLxjCC2OEWeUJ3B4xM1w8AZdAtywUBwYi0lo2drr7jWODCB4%2FVq0drdL1m04SMmPRzWBLEAwu%2B1XMPt6%2BrlKPzj6YlYJPw4OBK6CUsSRfKKOpnFbuluBtfriC5QW8pRy9DXJQ6Mw2XDFFFOfblQPzQ42jpwnekdmlD7rdX%2FA1XPJIfSyG4V%2Fir2GmdoUv%2BFBnMYkN5vSASp1sERWzbEL4PKLTK13Lbjq6dZfOVhPAyz9IycgTcT3aBSGz6bqgf9d2P8MP5812en0%2FP5KEPugj%2B4e44AFUiMnGcbU7AWtPVtCm%2BL3%2BCXfSv3JxzSPkfB5wb%2BH12K3sktcrOABVcpHD5GJNCUiibtEZsqyAwk1aqezFQ6CJ4wKKn4QQdSZ7TNee3nsbmDFGO2Gpe6f76dMpb%2BxuFUvTf7LW%2Bq%2B3%2FP6DgZNYnlKwE0u2W0BZJZx6SngxSgBC8xUIwZgRi7wiLzfvesAE4woJj8qAY6nQHf0JpPtaEzkYMDnpDnqCjj59%2B9l%2BrJ%2BjiAUPViumHvaJSgHIbs5Zx3QbzM5OD8PUgm0%2BrweBX33O40ncZ8NBdUUFdJctLU%2FDHa47ETpMbnNwLni5%2FIcQ4Kp6xtUg%2FhndJEUSQQAYGUyx0Zw%2FDH0V2C2J5FNcd7USC1i4%2B7MZ8cO7iqNZW%2BqbpOt039bmy0U7X0r6qBN5i%2ByBh%2F9ixz&X-Amz-Signature=676afe4d3137ec8de82fd8ecf62e109e1647b694f60815b8048d6e0503c16c3b'}

# %%
processId = model_inputs_response['processId']
upload_link = model_inputs_response['uploadLink']
upload_headers = endpoints.EDFXHeaders()['ModelInputsUploadProcess']['headers']

with open(full_file_path, 'rb') as file:
    response = requests.put(upload_link, headers=upload_headers, data=file)

print(response.status_code)
# Out:
# 403

# %% [markdown]
# ## Asychronous

# %% [markdown]
# # Retrieving LImits for Trade Credit

# %%
# test1 = endpoints.EDFXRetrievinglimtsfortradecredit([{ "entityId": "AT9110116332" }])
# test1
# when I include all params it works.  
trade_credit = endpoints.EDFXRetrievinglimtsfortradecredit([{ "entityId": "DELEI421244" }, { "entityId": "US800890963" }, { "entityId": "FR813755949" }], startDate='2021-01-01', endDate="2021-06-09")
trade_parse = endpoints.EDFXParseTradeCredit(trade_credit)
trade_parse
# Out:
# Unfortunately: FR813755949 has no credit information.
# Unfortunately: DELEI421244 has no credit information.
#       entityId    asOfDate        pd     balanced   aggressive  conservative  \
# 0  US800890963  2021-06-01  0.041134  11348809.97  17673627.57    5023992.37
# 1  US800890963  2021-05-01  0.043073  10941912.39  17073089.00    4810735.77
# 2  US800890963  2021-04-01  0.039239  11783526.56  18316121.02    5250932.09
# 3  US800890963  2021-03-01  0.040737  11436683.37  17803430.50    5069936.24
# 4  US800890963  2021-02-01  0.047307  10164754.69  15928835.46    4400673.92
# 5  US800890963  2021-01-01  0.063793   8085690.15  12895637.68    3275742.62
#
#   currency  unit
# 0      USD     1
# 1      USD     1
# 2      USD     1
# 3      USD     1
# 4      USD     1
# 5      USD     1

# %%
# trade_parse = endpoints.EDFXParseTradeCredit(trade_credit, output_format = 'csv')
# trade_parse = endpoints.EDFXParseTradeCredit(trade_credit, output_format = 'excel')
# Out:
# Unfortunately: DELEI421244 has no credit information.
# Unfortunately: FR813755949 has no credit information.
# Data Saved to PDs.csv
# Unfortunately: DELEI421244 has no credit information.
# Unfortunately: FR813755949 has no credit information.
# Data saved to PDs.xlsx

# %% [markdown]
# # Retrieving Peer Groups

# %%
# Does not work,  {'message': 'Internal server error'}
# endpoints.EDFXRetrievingpeergroups_IDS(peerRegion='WESTEUR', ownershipType='LISTED')
# This worked. THis is bullshit.  they need industryCode and Industry CLassification
endpoints.EDFXRetrievingpeergroups_IDS(peerRegion='WESTEUR', ownershipType='LISTED',industryCode="N55", industryClassification='NDY')
# Out:
# {'results': [{'peerId': 'c45ac44c-14cc-4e07-87f7-08fefa10f788'}]}

# %%
# works with all variables.
json = endpoints.EDFXRetrievingpeergroups_Metrics(peerId="832ec933-28e0-47c9-85a2-a8b5c2ca02b5",metrics=["P025", "P050"], 
                                                    variables=["annualizedcumulativepd1y"],startDate="2022-11-01", endDate="2023-01-01")

# Metrics_csv = endpoints.ParsePeerGroupMetrics(json, output_format= "csv")
# Metrics_xlsx = endpoints.ParsePeerGroupMetrics(json, output_format= "excel")
Metrics = endpoints.EDFXParsePeerGroupMetrics(json)
Metrics
# Out:
#       P025      P050    asOfDate              variableName  unit currency
# 0  0.00316  0.011863  2022-11-01  annualizedcumulativepd1y  0.01     None
# 1  0.00297  0.014730  2022-12-01  annualizedcumulativepd1y  0.01     None
# 2  0.00361  0.016065  2023-01-01  annualizedcumulativepd1y  0.01     None

# %%
json = endpoints.EDFXRetrievingpeergroups_Percentile("832ec933-28e0-47c9-85a2-a8b5c2ca02b5",["annualizedcumulativepd1y"],[.025] )
percentile_parse = endpoints.EDFXParsePeerGroupPercentile(json)
percentile_parse
# Out:
#                variableName percentile
# 0  annualizedcumulativepd1y       P065

# %%
json = endpoints.EDFXRetrievingpeergroups_Metadata("6cef0ad5-5f1b-40bc-85a9-0a071143fd3b")
# Out:
#                                  peerId  \
# 0  6cef0ad5-5f1b-40bc-85a9-0a071143fd3b
#
#                                             peerName  count country region  \
# 0  UNITED KINGDOM OF GREAT BRITAIN AND NORTHERN I...  73554     GBR   None
#
#   industryCode ownershipType
# 0          N09      UNLISTED

# %%
json = endpoints.EDFXRetrievingpeergroups_Recommended(industryClassification='NDY', industryCode="N17",ownershipType="UNLISTED", country="USA")
df
# Out:
#   peerId_name                          peerId_value
# 0      peerId  e618741f-c297-43f2-8a86-916920ce21c1
# 1     peerId2  58e79456-390a-482f-bd8a-a7fe515cf9c8
# 2     peerId3  7bf6fd00-66f6-4643-b02c-08b04d52a256
# 3     peerId4  302a04c3-3223-4f65-b93d-fe4da81ca00a
# 4     peerId5  f472b9f5-94e1-485a-8dd0-4405d10dff36

# %% [markdown]
# # Retrieving Risk Category

# %%
# Get the risk category for specific entity or list of entities
risk_categories = endpoints.EDFXRetrievingRiskCategory(entities=[{"entityId":"US911144442"}])
print(risk_categories)

# Parse the retrieved risk category into Pandas Dataframe
parsed_risk_categories = endpoints.EDFXRiskCategoryParse(risk_categories)
print(parsed_risk_categories)
# Out:
# 2023-09-07 13:12:36,007 [INFO] Security token has been generated.
# 2023-09-07 13:12:36,007 [INFO] Security token has been generated.
# 2023-09-07 13:12:36,007 [INFO] Security token has been generated.
# 2023-09-07 13:12:36,007 [INFO] Security token has been generated.
# [{'entityId': 'US911144442', 'peerId': 'a9c9eef1-8986-429c-9d09-16c36735ee13', 'asOfDate': '2023-09-01', 'prevAsOfDate': '2022-09-01', 'irChange': 0, 'trigger': 0.05362249881692241, 'pd': 0.000221, 'riskCategory': 'Low', 'distanceToTrigger': -5.491561311516115}]
#       entityId                                peerId    asOfDate prevAsOfDate  \
# 0  US911144442  a9c9eef1-8986-429c-9d09-16c36735ee13  2023-09-01   2022-09-01
#
#    irChange   trigger        pd riskCategory  distanceToTrigger
# 0         0  0.053622  0.000221          Low          -5.491561
